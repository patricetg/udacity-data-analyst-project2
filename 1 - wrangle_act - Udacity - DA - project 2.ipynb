# %% [markdown]
# # Project: Wrangling and Analyze Data
#
# ## Table of Contents
#
#
# * [Introduction](#intro)
# * [Gathering](#gathering)
# * [Assessing](#assessing)
# * [Cleaning](#cleaning)
# * [Storing](#storing)
# * [Analyzing and Visualizing Data](#analyzing-visualizing)
# * [Conclusions](#conclusions)

# %% [markdown]
# <a id='intro'></a>
# ## Introduction
#
# This is my [Udacity Data Analyst Nanodegree](https://www.udacity.com/course/data-analyst-nanodegree--nd002) second project. The goal here is to demonstrate my Data Wrangling ability. I am required to retrieve piece of data through different sources, put them together to form a whole, assess and clean them, before gaining valuable insights from them.

# %%
import pandas as pd
import numpy as np

import requests
import os

import tweepy
from tweepy import OAuthHandler
import json
from timeit import default_timer as timer

# regular expression
import re

import matplotlib.pyplot as plt
import seaborn as sb

from dateutil.parser import parse
from datetime import datetime

# %matplotlib inline

# %%
def extract_urls_from_str(value)->str:
    """
    Extract urls the given string
    Return : urls, separated by comma
    
    References : 
        - https://www.digitalocean.com/community/tutorials/pandas-dataframe-apply-examples
        - https://stackoverflow.com/questions/499345/regular-expression-to-extract-url-from-an-html-link
    """
    string = str(value)
    urls = re.findall(r'href=[\'"]?([^\'" >]+)', string)
    return ', '.join(urls)

# %%
def operate_datetime_feature_engineering(df:pd.DataFrame, datetime_column:str, verbose=False)->pd.DataFrame:
    """
        Generate new features for our samples, in order to answer questions related to :
            - day periods (morning, miday, evening, afternoon, ...)
            - day (monday, tuesday, ...)
            - month (Jan, Feb, ...)

        Code based on the courses given by Prof @Stanley Omeike on OneCampus Academy.
        
        @param df:pd.DataFrame : the dataframe in which to do the feature engineering
        @param datetime_column:str : column based on which to do the feature engineering
        
        @return : the new dataframe, containing the generated columns
        
        References :
            - Code based on a course given by Prof @Stanley Omeike on OneCampus Academy
            - https://sparkbyexamples.com/pandas/how-to-format-pandas-datetime/
            - https://stackoverflow.com/questions/1759455/how-can-i-account-for-period-am-pm-using-strftime
    """

    # standardize the format of the column, and parse it to str in order to allow further work on it
    dCol = tweets_master_df[datetime_column].dt.strftime("%Y-%m-%d %I:%M:%S %p").astype(str) #tweets_master_df["timestamp"].astype(str)
    #dCol

    # print(dates[:2] ) will give something like : [('Sat Jul 26 02:30:00 2008', 'PM'), ('Tue Jul 31 10:57:00 2018', 'AM')]
    dates = [( datetime.ctime(parse(x[0:-3])), x[-2:] ) for x in dCol]

#     print("dates[:2] : ")
#     print(dates[:2])
    
    days = []
    months = []
    periods = []

    unprocesseds = []

    for row in dates:
        day = row[0][0:4]
        month = row[0][4:7]
        time = int(row[0][11:13])

        if row[1]=='AM' and time<=4:
            period = 'Night (after midnight)'
        elif row[1]=='AM' and time<=7:
            period = "Morning"
        elif row[1]=='AM' and time>7:
            period = "Day Time"
        elif row[1] =='PM' and time<=4:
            period = 'Afternoon'
        elif row[1] =='PM' and time<=6:
            period = 'Evening' 
        elif row[1] =='PM' and (time>6 and time<=10):
            period = 'Night (start)'
        elif row[1] =='PM' and time>10:
            period = 'Near Midnight'
        else:
            period = "TODO"
            unprocesseds.append(row[0]+" "+row[1])

        days.append(day)
        months.append(month)
        periods.append(period)
    
    if(len(unprocesseds)>0):
        print("unprocesseds")
        print(unprocesseds)
        print("len(unprocesseds)")
        print(len(unprocesseds))
    
    df['month'] = months
    df['day'] = days
    df['period']= periods
    
    if(verbose):
        df.sample(3).T
        
    return df

# %% [markdown]
# <a href="gathering"> </a>
#
# ## Data Gathering
# In the cells below, I will gather all three pieces of data for this project and load them in the notebook.
# **Note:** the methods required to gather each data are different.
#
#
# **1. 1st piece of data** : Download the WeRateDogs Twitter archive data through a link.
# *Here, the dataset come from my Udacity account. It is to be consired directly sent to me by email.*

# %%
twitter_archive_df = pd.read_csv("twitter-archive-enhanced.csv")
twitter_archive_df.head(3).T
# Out:
#                                                                             0  \
# tweet_id                                                   892420643555336193
# in_reply_to_status_id                                                     NaN
# in_reply_to_user_id                                                       NaN
# timestamp                                           2017-08-01 16:23:56 +0000
# source                      <a href="http://twitter.com/download/iphone" r...
# text                        This is Phineas. He's a mystical boy. Only eve...
# retweeted_status_id                                                       NaN
# retweeted_status_user_id                                                  NaN
# retweeted_status_timestamp                                                NaN
# expanded_urls               https://twitter.com/dog_rates/status/892420643...
# rating_numerator                                                           13
# rating_denominator                                                         10
# name                                                                  Phineas
# doggo                                                                    None
# floofer                                                                  None
# pupper                                                                   None
# puppo                                                                    None
#
#                                                                             1  \
# tweet_id                                                   892177421306343426
# in_reply_to_status_id                                                     NaN
# in_reply_to_user_id                                                       NaN
# timestamp                                           2017-08-01 00:17:27 +0000
# source                      <a href="http://twitter.com/download/iphone" r...
# text                        This is Tilly. She's just checking pup on you....
# retweeted_status_id                                                       NaN
# retweeted_status_user_id                                                  NaN
# retweeted_status_timestamp                                                NaN
# expanded_urls               https://twitter.com/dog_rates/status/892177421...
# rating_numerator                                                           13
# rating_denominator                                                         10
# name                                                                    Tilly
# doggo                                                                    None
# floofer                                                                  None
# pupper                                                                   None
# puppo                                                                    None
#
#                                                                             2
# tweet_id                                                   891815181378084864
# in_reply_to_status_id                                                     NaN
# in_reply_to_user_id                                                       NaN
# timestamp                                           2017-07-31 00:18:03 +0000
# source                      <a href="http://twitter.com/download/iphone" r...
# text                        This is Archie. He is a rare Norwegian Pouncin...
# retweeted_status_id                                                       NaN
# retweeted_status_user_id                                                  NaN
# retweeted_status_timestamp                                                NaN
# expanded_urls               https://twitter.com/dog_rates/status/891815181...
# rating_numerator                                                           12
# rating_denominator                                                         10
# name                                                                   Archie
# doggo                                                                    None
# floofer                                                                  None
# pupper                                                                   None
# puppo                                                                    None

# %% [markdown]
# **2. 2nd piece of data** : Download data through an API
# *I will use the Requests library to download through an API the tweet image prediction (image_predictions.tsv)*

# %%
# Create download folder if not exist
folder_name = "downloads"
folder_path = "./{}".format(folder_name)
if not os.path.exists(folder_path):
    os.makedirs(folder_path)

# %%
# Make the download request

# download's url provided in the project's instructions
image_url = "https://d17h27t6h515a5.cloudfront.net/topher/2017/August/599fd2ad_image-predictions/image-predictions.tsv"
image_response = requests.get(image_url)

if image_response.status_code != 200:
    raise Exception("Response status code != from 200")
else:
    print("Request successful")
# Out:
# Request successful

# %%
# Save downloaded file
file_name = image_url.split("/")[-1]
file_path = os.path.join(folder_path, file_name)
with open( file_path , mode="wb" ) as file:
    file.write(image_response.content)
    print("File saved on disk")
# Out:
# File saved on disk

# %%
# Import downloaded file in a dataframe
image_predictions_df = pd.read_csv(file_path, sep="\t")
image_predictions_df.head(3).T
# Out:
#                                                         0  \
# tweet_id                               666020888022790149
# jpg_url   https://pbs.twimg.com/media/CT4udn0WwAA0aMy.jpg
# img_num                                                 1
# p1                                 Welsh_springer_spaniel
# p1_conf                                          0.465074
# p1_dog                                               True
# p2                                                 collie
# p2_conf                                          0.156665
# p2_dog                                               True
# p3                                      Shetland_sheepdog
# p3_conf                                          0.061428
# p3_dog                                               True
#
#                                                         1  \
# tweet_id                               666029285002620928
# jpg_url   https://pbs.twimg.com/media/CT42GRgUYAA5iDo.jpg
# img_num                                                 1
# p1                                                redbone
# p1_conf                                          0.506826
# p1_dog                                               True
# p2                                     miniature_pinscher
# p2_conf                                          0.074192
# p2_dog                                               True
# p3                                    Rhodesian_ridgeback
# p3_conf                                           0.07201
# p3_dog                                               True
#
#                                                         2
# tweet_id                               666033412701032449
# jpg_url   https://pbs.twimg.com/media/CT4521TWwAEvMyu.jpg
# img_num                                                 1
# p1                                        German_shepherd
# p1_conf                                          0.596461
# p1_dog                                               True
# p2                                               malinois
# p2_conf                                          0.138584
# p2_dog                                               True
# p3                                             bloodhound
# p3_conf                                          0.116197
# p3_dog                                               True

# %% [markdown]
# **3. 3rd piece of data** : Download data through the Twitter API
# *I will use the Tweepy library to query additional data via the Twitter API (tweet_json.txt)*

# %%
tweet_ids = image_predictions_df["tweet_id"].values
tweet_ids
# Out:
# array([666020888022790149, 666029285002620928, 666033412701032449, ...,
#        891815181378084864, 892177421306343426, 892420643555336193],
#       dtype=int64)

# %%
# Signify that I have not put my own twitter api key in this notebook
have_put_my_own_api_key = False

# Query Twitter API for each tweet in the Twitter archive and save JSON in a text file
# These are hidden to comply with Twitter's API terms and conditions
consumer_key = "XXX"
consumer_secret = "XXX"
access_token = "XXX"
access_secret = "XXX"

tweet_json_file_name = "tweet_json.txt"
tweet_json_file_path = "./{}".format(tweet_json_file_name)

if have_put_my_own_api_key:
    """ The code below was taken from my Udacity's classroom """
    
    auth = OAuthHandler(consumer_key, consumer_secret)
    auth.set_access_token(access_token, access_secret)

    api = tweepy.API(auth, wait_on_rate_limit=True)

    # Query Twitter's API for JSON data for each tweet ID in the Twitter archive
    count = 0
    fails_dict = {}
    start = timer()
    # Save each tweet's returned JSON as a new line in a .txt file
    with open('tweet_json.txt', 'w') as outfile:
        # This loop will likely take 20-30 minutes to run because of Twitter's rate limit
        for tweet_id in tweet_ids:
            count += 1
            print(str(count) + ": " + str(tweet_id))
            try:
                tweet = api.get_status(tweet_id, tweet_mode='extended')
                print("Success")
                json.dump(tweet._json, outfile)
                outfile.write('\n')
            except tweepy.TweepError as e:
                print("Fail")
                fails_dict[tweet_id] = e
                pass
    end = timer()
    print(end - start)
    print(fails_dict)

# %% [markdown]
# Import json file into a dataframe

# %%
"""

References : 

- https://www.geeksforgeeks.org/read-json-file-using-python/
- https://www.pythontutorial.net/python-basics/python-read-text-file/
- https://www.freecodecamp.org/news/python-json-how-to-convert-a-string-to-json/

"""
df_list = []

# Open file
with open(tweet_json_file_path,"r") as file:
    #file_content = json.load(file)
    lines = file.readlines()
    #print(lines[0])
    #print(json.loads(lines[0])["created_at"])
    for line in lines:
         df_list.append(json.loads(line))

df_list[:2]
# Out:
# [{'created_at': 'Tue Aug 01 16:23:56 +0000 2017',
#   'id': 892420643555336193,
#   'id_str': '892420643555336193',
#   'full_text': "This is Phineas. He's a mystical boy. Only ever appears in the hole of a donut. 13/10 https://t.co/MgUWQ76dJU",
#   'truncated': False,
#   'display_text_range': [0, 85],
#   'entities': {'hashtags': [],
#    'symbols': [],
#    'user_mentions': [],
#    'urls': [],
#    'media': [{'id': 892420639486877696,
#      'id_str': '892420639486877696',
#      'indices': [86, 109],
#      'media_url': 'http://pbs.twimg.com/media/DGKD1-bXoAAIAUK.jpg',
#      'media_url_https': 'https://pbs.twimg.com/media/DGKD1-bXoAAIAUK.jpg',
#      'url': 'https://t.co/MgUWQ76dJU',
#      'display_url': 'pic.twitter.com/MgUWQ76dJU',
#      'expanded_url': 'https://twitter.com/dog_rates/status/892420643555336193/photo/1',
#      'type': 'photo',
#      'sizes': {'large': {'w': 540, 'h': 528, 'resize': 'fit'},
#       'thumb': {'w': 150, 'h': 150, 'resize': 'crop'},
#       'small': {'w': 540, 'h': 528, 'resize': 'fit'},
#       'medium': {'w': 540, 'h': 528, 'resize': 'fit'}}}]},
#   'extended_entities': {'media': [{'id': 892420639486877696,
#      'id_str': '892420639486877696',
#      'indices': [86, 109],
#      'media_url': 'http://pbs.twimg.com/media/DGKD1-bXoAAIAUK.jpg',
#      'media_url_https': 'https://pbs.twimg.com/media/DGKD1-bXoAAIAUK.jpg',
#      'url': 'https://t.co/MgUWQ76dJU',
#      'display_url': 'pic.twitter.com/MgUWQ76dJU',
#      'expanded_url': 'https://twitter.com/dog_rates/status/892420643555336193/photo/1',
#      'type': 'photo',
#      'sizes': {'large': {'w': 540, 'h': 528, 'resize': 'fit'},
#       'thumb': {'w': 150, 'h': 150, 'resize': 'crop'},
#       'small': {'w': 540, 'h': 528, 'resize': 'fit'},
#       'medium': {'w': 540, 'h': 528, 'resize': 'fit'}}}]},
#   'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#   'in_reply_to_status_id': None,
#   'in_reply_to_status_id_str': None,
#   'in_reply_to_user_id': None,
#   'in_reply_to_user_id_str': None,
#   'in_reply_to_screen_name': None,
#   'user': {'id': 4196983835,
#    'id_str': '4196983835',
#    'name': 'WeRateDogs™ (author)',
#    'screen_name': 'dog_rates',
#    'location': 'DM YOUR DOGS, WE WILL RATE',
#    'description': '#1 Source for Professional Dog Ratings | STORE: @ShopWeRateDogs | IG, FB & SC: WeRateDogs MOBILE APP: @GoodDogsGame | Business: dogratingtwitter@gmail.com',
#    'url': 'https://t.co/N7sNNHAEXS',
#    'entities': {'url': {'urls': [{'url': 'https://t.co/N7sNNHAEXS',
#        'expanded_url': 'http://weratedogs.com',
#        'display_url': 'weratedogs.com',
#        'indices': [0, 23]}]},
#     'description': {'urls': []}},
#    'protected': False,
#    'followers_count': 3200889,
#    'friends_count': 104,
#    'listed_count': 2784,
#    'created_at': 'Sun Nov 15 21:41:29 +0000 2015',
#    'favourites_count': 114031,
#    'utc_offset': None,
#    'time_zone': None,
#    'geo_enabled': True,
#    'verified': True,
#    'statuses_count': 5288,
#    'lang': 'en',
#    'contributors_enabled': False,
#    'is_translator': False,
#    'is_translation_enabled': False,
#    'profile_background_color': '000000',
#    'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_tile': False,
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/861415328504569856/R2xOOfwe_normal.jpg',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/861415328504569856/R2xOOfwe_normal.jpg',
#    'profile_banner_url': 'https://pbs.twimg.com/profile_banners/4196983835/1501129017',
#    'profile_link_color': 'F5ABB5',
#    'profile_sidebar_border_color': '000000',
#    'profile_sidebar_fill_color': '000000',
#    'profile_text_color': '000000',
#    'profile_use_background_image': False,
#    'has_extended_profile': True,
#    'default_profile': False,
#    'default_profile_image': False,
#    'following': True,
#    'follow_request_sent': False,
#    'notifications': False,
#    'translator_type': 'none'},
#   'geo': None,
#   'coordinates': None,
#   'place': None,
#   'contributors': None,
#   'is_quote_status': False,
#   'retweet_count': 8853,
#   'favorite_count': 39467,
#   'favorited': False,
#   'retweeted': False,
#   'possibly_sensitive': False,
#   'possibly_sensitive_appealable': False,
#   'lang': 'en'},
#  {'created_at': 'Tue Aug 01 00:17:27 +0000 2017',
#   'id': 892177421306343426,
#   'id_str': '892177421306343426',
#   'full_text': "This is Tilly. She's just checking pup on you. Hopes you're doing ok. If not, she's available for pats, snugs, boops, the whole bit. 13/10 https://t.co/0Xxu71qeIV",
#   'truncated': False,
#   'display_text_range': [0, 138],
#   'entities': {'hashtags': [],
#    'symbols': [],
#    'user_mentions': [],
#    'urls': [],
#    'media': [{'id': 892177413194625024,
#      'id_str': '892177413194625024',
#      'indices': [139, 162],
#      'media_url': 'http://pbs.twimg.com/media/DGGmoV4XsAAUL6n.jpg',
#      'media_url_https': 'https://pbs.twimg.com/media/DGGmoV4XsAAUL6n.jpg',
#      'url': 'https://t.co/0Xxu71qeIV',
#      'display_url': 'pic.twitter.com/0Xxu71qeIV',
#      'expanded_url': 'https://twitter.com/dog_rates/status/892177421306343426/photo/1',
#      'type': 'photo',
#      'sizes': {'large': {'w': 1407, 'h': 1600, 'resize': 'fit'},
#       'thumb': {'w': 150, 'h': 150, 'resize': 'crop'},
#       'small': {'w': 598, 'h': 680, 'resize': 'fit'},
#       'medium': {'w': 1055, 'h': 1200, 'resize': 'fit'}}}]},
#   'extended_entities': {'media': [{'id': 892177413194625024,
#      'id_str': '892177413194625024',
#      'indices': [139, 162],
#      'media_url': 'http://pbs.twimg.com/media/DGGmoV4XsAAUL6n.jpg',
#      'media_url_https': 'https://pbs.twimg.com/media/DGGmoV4XsAAUL6n.jpg',
#      'url': 'https://t.co/0Xxu71qeIV',
#      'display_url': 'pic.twitter.com/0Xxu71qeIV',
#      'expanded_url': 'https://twitter.com/dog_rates/status/892177421306343426/photo/1',
#      'type': 'photo',
#      'sizes': {'large': {'w': 1407, 'h': 1600, 'resize': 'fit'},
#       'thumb': {'w': 150, 'h': 150, 'resize': 'crop'},
#       'small': {'w': 598, 'h': 680, 'resize': 'fit'},
#       'medium': {'w': 1055, 'h': 1200, 'resize': 'fit'}}}]},
#   'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#   'in_reply_to_status_id': None,
#   'in_reply_to_status_id_str': None,
#   'in_reply_to_user_id': None,
#   'in_reply_to_user_id_str': None,
#   'in_reply_to_screen_name': None,
#   'user': {'id': 4196983835,
#    'id_str': '4196983835',
#    'name': 'WeRateDogs™ (author)',
#    'screen_name': 'dog_rates',
#    'location': 'DM YOUR DOGS, WE WILL RATE',
#    'description': '#1 Source for Professional Dog Ratings | STORE: @ShopWeRateDogs | IG, FB & SC: WeRateDogs MOBILE APP: @GoodDogsGame | Business: dogratingtwitter@gmail.com',
#    'url': 'https://t.co/N7sNNHAEXS',
#    'entities': {'url': {'urls': [{'url': 'https://t.co/N7sNNHAEXS',
#        'expanded_url': 'http://weratedogs.com',
#        'display_url': 'weratedogs.com',
#        'indices': [0, 23]}]},
#     'description': {'urls': []}},
#    'protected': False,
#    'followers_count': 3200889,
#    'friends_count': 104,
#    'listed_count': 2784,
#    'created_at': 'Sun Nov 15 21:41:29 +0000 2015',
#    'favourites_count': 114031,
#    'utc_offset': None,
#    'time_zone': None,
#    'geo_enabled': True,
#    'verified': True,
#    'statuses_count': 5288,
#    'lang': 'en',
#    'contributors_enabled': False,
#    'is_translator': False,
#    'is_translation_enabled': False,
#    'profile_background_color': '000000',
#    'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_tile': False,
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/861415328504569856/R2xOOfwe_normal.jpg',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/861415328504569856/R2xOOfwe_normal.jpg',
#    'profile_banner_url': 'https://pbs.twimg.com/profile_banners/4196983835/1501129017',
#    'profile_link_color': 'F5ABB5',
#    'profile_sidebar_border_color': '000000',
#    'profile_sidebar_fill_color': '000000',
#    'profile_text_color': '000000',
#    'profile_use_background_image': False,
#    'has_extended_profile': True,
#    'default_profile': False,
#    'default_profile_image': False,
#    'following': True,
#    'follow_request_sent': False,
#    'notifications': False,
#    'translator_type': 'none'},
#   'geo': None,
#   'coordinates': None,
#   'place': None,
#   'contributors': None,
#   'is_quote_status': False,
#   'retweet_count': 6514,
#   'favorite_count': 33819,
#   'favorited': False,
#   'retweeted': False,
#   'possibly_sensitive': False,
#   'possibly_sensitive_appealable': False,
#   'lang': 'en'}]

# %%
tweets_df = pd.DataFrame(df_list)
tweets_df.head(3).T
# Out:
#                                                                                0  \
# created_at                                        Tue Aug 01 16:23:56 +0000 2017
# id                                                            892420643555336193
# id_str                                                        892420643555336193
# full_text                      This is Phineas. He's a mystical boy. Only eve...
# truncated                                                                  False
# display_text_range                                                       [0, 85]
# entities                       {'hashtags': [], 'symbols': [], 'user_mentions...
# extended_entities              {'media': [{'id': 892420639486877696, 'id_str'...
# source                         <a href="http://twitter.com/download/iphone" r...
# in_reply_to_status_id                                                        NaN
# in_reply_to_status_id_str                                                   None
# in_reply_to_user_id                                                          NaN
# in_reply_to_user_id_str                                                     None
# in_reply_to_screen_name                                                     None
# user                           {'id': 4196983835, 'id_str': '4196983835', 'na...
# geo                                                                         None
# coordinates                                                                 None
# place                                                                       None
# contributors                                                                None
# is_quote_status                                                            False
# retweet_count                                                               8853
# favorite_count                                                             39467
# favorited                                                                  False
# retweeted                                                                  False
# possibly_sensitive                                                         False
# possibly_sensitive_appealable                                              False
# lang                                                                          en
# retweeted_status                                                             NaN
# quoted_status_id                                                             NaN
# quoted_status_id_str                                                         NaN
# quoted_status                                                                NaN
#
#                                                                                1  \
# created_at                                        Tue Aug 01 00:17:27 +0000 2017
# id                                                            892177421306343426
# id_str                                                        892177421306343426
# full_text                      This is Tilly. She's just checking pup on you....
# truncated                                                                  False
# display_text_range                                                      [0, 138]
# entities                       {'hashtags': [], 'symbols': [], 'user_mentions...
# extended_entities              {'media': [{'id': 892177413194625024, 'id_str'...
# source                         <a href="http://twitter.com/download/iphone" r...
# in_reply_to_status_id                                                        NaN
# in_reply_to_status_id_str                                                   None
# in_reply_to_user_id                                                          NaN
# in_reply_to_user_id_str                                                     None
# in_reply_to_screen_name                                                     None
# user                           {'id': 4196983835, 'id_str': '4196983835', 'na...
# geo                                                                         None
# coordinates                                                                 None
# place                                                                       None
# contributors                                                                None
# is_quote_status                                                            False
# retweet_count                                                               6514
# favorite_count                                                             33819
# favorited                                                                  False
# retweeted                                                                  False
# possibly_sensitive                                                         False
# possibly_sensitive_appealable                                              False
# lang                                                                          en
# retweeted_status                                                             NaN
# quoted_status_id                                                             NaN
# quoted_status_id_str                                                         NaN
# quoted_status                                                                NaN
#
#                                                                                2
# created_at                                        Mon Jul 31 00:18:03 +0000 2017
# id                                                            891815181378084864
# id_str                                                        891815181378084864
# full_text                      This is Archie. He is a rare Norwegian Pouncin...
# truncated                                                                  False
# display_text_range                                                      [0, 121]
# entities                       {'hashtags': [], 'symbols': [], 'user_mentions...
# extended_entities              {'media': [{'id': 891815175371796480, 'id_str'...
# source                         <a href="http://twitter.com/download/iphone" r...
# in_reply_to_status_id                                                        NaN
# in_reply_to_status_id_str                                                   None
# in_reply_to_user_id                                                          NaN
# in_reply_to_user_id_str                                                     None
# in_reply_to_screen_name                                                     None
# user                           {'id': 4196983835, 'id_str': '4196983835', 'na...
# geo                                                                         None
# coordinates                                                                 None
# place                                                                       None
# contributors                                                                None
# is_quote_status                                                            False
# retweet_count                                                               4328
# favorite_count                                                             25461
# favorited                                                                  False
# retweeted                                                                  False
# possibly_sensitive                                                         False
# possibly_sensitive_appealable                                              False
# lang                                                                          en
# retweeted_status                                                             NaN
# quoted_status_id                                                             NaN
# quoted_status_id_str                                                         NaN
# quoted_status                                                                NaN

# %%
# # Keep useful columns while discarding the others, as per the project instructions
# tweets_df = tweets_df[ ["id","retweet_count","favorite_count","user","retweeted"] ]
# tweets_df.head(3)

# %% [markdown]
# <a href="assessing"> </a>
#
# ## Assessing Data
# In this section, I will detect and document quality issues and tidiness issue. I will use **both** visual assessment and
# programmatic assessement to assess the data.
#
# **Note:** There are few key points to pay attention to when accessing the data.
#
# * I only want original ratings (no retweets) that have images. Though there are 5000+ tweets in the dataset, not all are dog ratings and some are retweets.
# * Assessing and cleaning the entire dataset completely would require a lot of time, and is not necessary to practice and demonstrate my skills in data wrangling. Therefore, the requirements of this project are only to assess and clean at least 8 quality issues and at least 2 tidiness issues in this dataset.
# * The fact that the rating numerators are greater than the denominators does not need to be cleaned. This [unique rating system](http://knowyourmeme.com/memes/theyre-good-dogs-brent) is a big part of the popularity of WeRateDogs.
# * I do not need to gather the tweets beyond August 1st, 2017. I can, but I won't be able to gather the image predictions for these tweets since I don't have access to the algorithm used.

# %%
# Looking at the content of twitter_archive_df
twitter_archive_df.head(3).T
# Out:
#                                                                             0  \
# tweet_id                                                   892420643555336193
# in_reply_to_status_id                                                     NaN
# in_reply_to_user_id                                                       NaN
# timestamp                                           2017-08-01 16:23:56 +0000
# source                      <a href="http://twitter.com/download/iphone" r...
# text                        This is Phineas. He's a mystical boy. Only eve...
# retweeted_status_id                                                       NaN
# retweeted_status_user_id                                                  NaN
# retweeted_status_timestamp                                                NaN
# expanded_urls               https://twitter.com/dog_rates/status/892420643...
# rating_numerator                                                           13
# rating_denominator                                                         10
# name                                                                  Phineas
# doggo                                                                    None
# floofer                                                                  None
# pupper                                                                   None
# puppo                                                                    None
#
#                                                                             1  \
# tweet_id                                                   892177421306343426
# in_reply_to_status_id                                                     NaN
# in_reply_to_user_id                                                       NaN
# timestamp                                           2017-08-01 00:17:27 +0000
# source                      <a href="http://twitter.com/download/iphone" r...
# text                        This is Tilly. She's just checking pup on you....
# retweeted_status_id                                                       NaN
# retweeted_status_user_id                                                  NaN
# retweeted_status_timestamp                                                NaN
# expanded_urls               https://twitter.com/dog_rates/status/892177421...
# rating_numerator                                                           13
# rating_denominator                                                         10
# name                                                                    Tilly
# doggo                                                                    None
# floofer                                                                  None
# pupper                                                                   None
# puppo                                                                    None
#
#                                                                             2
# tweet_id                                                   891815181378084864
# in_reply_to_status_id                                                     NaN
# in_reply_to_user_id                                                       NaN
# timestamp                                           2017-07-31 00:18:03 +0000
# source                      <a href="http://twitter.com/download/iphone" r...
# text                        This is Archie. He is a rare Norwegian Pouncin...
# retweeted_status_id                                                       NaN
# retweeted_status_user_id                                                  NaN
# retweeted_status_timestamp                                                NaN
# expanded_urls               https://twitter.com/dog_rates/status/891815181...
# rating_numerator                                                           12
# rating_denominator                                                         10
# name                                                                   Archie
# doggo                                                                    None
# floofer                                                                  None
# pupper                                                                   None
# puppo                                                                    None

# %% [markdown]
# A quick remark here is that we have dog's stages as column names, which is a tidiness issue that must be dealt with.

# %%
# Looking at the structure of twitter_archive_df
twitter_archive_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2356 entries, 0 to 2355
# Data columns (total 17 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   tweet_id                    2356 non-null   int64
#  1   in_reply_to_status_id       78 non-null     float64
#  2   in_reply_to_user_id         78 non-null     float64
#  3   timestamp                   2356 non-null   object
#  4   source                      2356 non-null   object
#  5   text                        2356 non-null   object
#  6   retweeted_status_id         181 non-null    float64
#  7   retweeted_status_user_id    181 non-null    float64
#  8   retweeted_status_timestamp  181 non-null    object
#  9   expanded_urls               2297 non-null   object
#  10  rating_numerator            2356 non-null   int64
#  11  rating_denominator          2356 non-null   int64
#  12  name                        2356 non-null   object
#  13  doggo                       2356 non-null   object
#  14  floofer                     2356 non-null   object
#  15  pupper                      2356 non-null   object
#  16  puppo                       2356 non-null   object
# dtypes: float64(4), int64(3), object(10)
# memory usage: 313.0+ KB

# %% [markdown]
# We have wrong datatype in the timestamp column, it should be of type datetime

# %%
# Checking null values in twitter_archive_df
twitter_archive_df.isnull().sum()
# Out:
# tweet_id                         0
# in_reply_to_status_id         2278
# in_reply_to_user_id           2278
# timestamp                        0
# source                           0
# text                             0
# retweeted_status_id           2175
# retweeted_status_user_id      2175
# retweeted_status_timestamp    2175
# expanded_urls                   59
# rating_numerator                 0
# rating_denominator               0
# name                             0
# doggo                            0
# floofer                          0
# pupper                           0
# puppo                            0
# dtype: int64

# %% [markdown]
# * There are too much null values in many columns (compared to the total number of samples we have) : `in_reply_to_status_id, in_reply_to_user_id, retweeted_status_id, retweeted_status_user_id, retweeted_status_timestamp`.
# * `expanded_urls` also have some null values.
#
# * The non-null value in the `retweeted_XXX` columns are marking that we we have retweet sample (we will further investivate this)

# %%
# Checking NaN (not a number) values in twitter_archive_df
twitter_archive_df.isna().sum()
# Out:
# tweet_id                         0
# in_reply_to_status_id         2278
# in_reply_to_user_id           2278
# timestamp                        0
# source                           0
# text                             0
# retweeted_status_id           2175
# retweeted_status_user_id      2175
# retweeted_status_timestamp    2175
# expanded_urls                   59
# rating_numerator                 0
# rating_denominator               0
# name                             0
# doggo                            0
# floofer                          0
# pupper                           0
# puppo                            0
# dtype: int64

# %% [markdown]
# The results for NaN check are the same as the results from null check, so there is nothing suspicious to investigate.

# %%
# Taking a look at the retweeted samples
twitter_archive_df[ ~ twitter_archive_df["retweeted_status_id"].isnull() ].T
# Out:
#                                                                          19    \
# tweet_id                                                   888202515573088257
# in_reply_to_status_id                                                     NaN
# in_reply_to_user_id                                                       NaN
# timestamp                                           2017-07-21 01:02:36 +0000
# source                      <a href="http://twitter.com/download/iphone" r...
# text                        RT @dog_rates: This is Canela. She attempted s...
# retweeted_status_id                                      887473957103951872.0
# retweeted_status_user_id                                         4196983835.0
# retweeted_status_timestamp                          2017-07-19 00:47:34 +0000
# expanded_urls               https://twitter.com/dog_rates/status/887473957...
# rating_numerator                                                           13
# rating_denominator                                                         10
# name                                                                   Canela
# doggo                                                                    None
# floofer                                                                  None
# pupper                                                                   None
# puppo                                                                    None
#
#                                                                          32    \
# tweet_id                                                   886054160059072513
# in_reply_to_status_id                                                     NaN
# in_reply_to_user_id                                                       NaN
# timestamp                                           2017-07-15 02:45:48 +0000
# source                      <a href="http://twitter.com/download/iphone" r...
# text                        RT @Athletics: 12/10 #BATP https://t.co/WxwJmv...
# retweeted_status_id                                      886053734421102592.0
# retweeted_status_user_id                                           19607400.0
# retweeted_status_timestamp                          2017-07-15 02:44:07 +0000
# expanded_urls               https://twitter.com/dog_rates/status/886053434...
# rating_numerator                                                           12
# rating_denominator                                                         10
# name                                                                     None
# doggo                                                                    None
# floofer                                                                  None
# pupper                                                                   None
# puppo                                                                    None
#
#                                                                          36    \
# tweet_id                                                   885311592912609280
# in_reply_to_status_id                                                     NaN
# in_reply_to_user_id                                                       NaN
# timestamp                                           2017-07-13 01:35:06 +0000
# source                      <a href="http://twitter.com/download/iphone" r...
# text                        RT @dog_rates: This is Lilly. She just paralle...
# retweeted_status_id                                      830583320585068544.0
# retweeted_status_user_id                                         4196983835.0
# retweeted_status_timestamp                          2017-02-12 01:04:29 +0000
# expanded_urls               https://twitter.com/dog_rates/status/830583320...
# rating_numerator                                                           13
# rating_denominator                                                         10
# name                                                                    Lilly
# doggo                                                                    None
# floofer                                                                  None
# pupper                                                                   None
# puppo                                                                    None
#
#                                                                          68    \
# tweet_id                                                   879130579576475649
# in_reply_to_status_id                                                     NaN
# in_reply_to_user_id                                                       NaN
# timestamp                                           2017-06-26 00:13:58 +0000
# source                      <a href="http://twitter.com/download/iphone" r...
# text                        RT @dog_rates: This is Emmy. She was adopted t...
# retweeted_status_id                                      878057613040115712.0
# retweeted_status_user_id                                         4196983835.0
# retweeted_status_timestamp                          2017-06-23 01:10:23 +0000
# expanded_urls               https://twitter.com/dog_rates/status/878057613...
# rating_numerator                                                           14
# rating_denominator                                                         10
# name                                                                     Emmy
# doggo                                                                    None
# floofer                                                                  None
# pupper                                                                   None
# puppo                                                                    None
#
#                                                                          73    \
# tweet_id                                                   878404777348136964
# in_reply_to_status_id                                                     NaN
# in_reply_to_user_id                                                       NaN
# timestamp                                           2017-06-24 00:09:53 +0000
# source                      <a href="http://twitter.com/download/iphone" r...
# text                        RT @dog_rates: Meet Shadow. In an attempt to r...
# retweeted_status_id                                      878281511006478336.0
# retweeted_status_user_id                                         4196983835.0
# retweeted_status_timestamp                          2017-06-23 16:00:04 +0000
# expanded_urls               https://www.gofundme.com/3yd6y1c,https://twitt...
# rating_numerator                                                           13
# rating_denominator                                                         10
# name                                                                   Shadow
# doggo                                                                    None
# floofer                                                                  None
# pupper                                                                   None
# puppo                                                                    None
#
#                                                                          74    \
# tweet_id                                                   878316110768087041
# in_reply_to_status_id                                                     NaN
# in_reply_to_user_id                                                       NaN
# timestamp                                           2017-06-23 18:17:33 +0000
# source                      <a href="http://twitter.com/download/iphone" r...
# text                        RT @dog_rates: Meet Terrance. He's being yelle...
# retweeted_status_id                                      669000397445533696.0
# retweeted_status_user_id                                         4196983835.0
# retweeted_status_timestamp                          2015-11-24 03:51:38 +0000
# expanded_urls               https://twitter.com/dog_rates/status/669000397...
# rating_numerator                                                           11
# rating_denominator                                                         10
# name                                                                 Terrance
# doggo                                                                    None
# floofer                                                                  None
# pupper                                                                   None
# puppo                                                                    None
#
#                                                                          78    \
# tweet_id                                                   877611172832227328
# in_reply_to_status_id                                                     NaN
# in_reply_to_user_id                                                       NaN
# timestamp                                           2017-06-21 19:36:23 +0000
# source                      <a href="http://twitter.com/download/iphone" r...
# text                        RT @rachel2195: @dog_rates the boyfriend and h...
# retweeted_status_id                                      876850772322988032.0
# retweeted_status_user_id                                          512804507.0
# retweeted_status_timestamp                          2017-06-19 17:14:49 +0000
# expanded_urls               https://twitter.com/rachel2195/status/87685077...
# rating_numerator                                                           14
# rating_denominator                                                         10
# name                                                                     None
# doggo                                                                    None
# floofer                                                                  None
# pupper                                                                 pupper
# puppo                                                                    None
#
#                                                                          91    \
# tweet_id                                                   874434818259525634
# in_reply_to_status_id                                                     NaN
# in_reply_to_user_id                                                       NaN
# timestamp                                           2017-06-13 01:14:41 +0000
# source                      <a href="http://twitter.com/download/iphone" r...
# text                        RT @dog_rates: This is Coco. At first I though...
# retweeted_status_id                                      866334964761202688.0
# retweeted_status_user_id                                         4196983835.0
# retweeted_status_timestamp                          2017-05-21 16:48:45 +0000
# expanded_urls               https://twitter.com/dog_rates/status/866334964...
# rating_numerator                                                           12
# rating_denominator                                                         10
# name                                                                     Coco
# doggo                                                                    None
# floofer                                                                  None
# pupper                                                                   None
# puppo                                                                    None
#
#                                                                          95    \
# tweet_id                                                   873697596434513921
# in_reply_to_status_id                                                     NaN
# in_reply_to_user_id                                                       NaN
# timestamp                                           2017-06-11 00:25:14 +0000
# source                      <a href="http://twitter.com/download/iphone" r...
# text                        RT @dog_rates: This is Walter. He won't start ...
# retweeted_status_id                                      868880397819494400.0
# retweeted_status_user_id                                         4196983835.0
# retweeted_status_timestamp                          2017-05-28 17:23:24 +0000
# expanded_urls               https://twitter.com/dog_rates/status/868880397...
# rating_numerator                                                           14
# rating_denominator                                                         10
# name                                                                   Walter
# doggo                                                                    None
# floofer                                                                  None
# pupper                                                                   None
# puppo                                                                    None
#
#                                                                          97    \
# tweet_id                                                   873337748698140672
# in_reply_to_status_id                                                     NaN
# in_reply_to_user_id                                                       NaN
# timestamp                                           2017-06-10 00:35:19 +0000
# source                      <a href="http://twitter.com/download/iphone" r...
# text                        RT @dog_rates: This is Sierra. She's one preci...
# retweeted_status_id                                      873213775632977920.0
# retweeted_status_user_id                                         4196983835.0
# retweeted_status_timestamp                          2017-06-09 16:22:42 +0000
# expanded_urls               https://www.gofundme.com/help-my-baby-sierra-g...
# rating_numerator                                                           12
# rating_denominator                                                         10
# name                                                                   Sierra
# doggo                                                                    None
# floofer                                                                  None
# pupper                                                                 pupper
# puppo                                                                    None
#
#                             ...  \
# tweet_id                    ...
# in_reply_to_status_id       ...
# in_reply_to_user_id         ...
# timestamp                   ...
# source                      ...
# text                        ...
# retweeted_status_id         ...
# retweeted_status_user_id    ...
# retweeted_status_timestamp  ...
# expanded_urls               ...
# rating_numerator            ...
# rating_denominator          ...
# name                        ...
# doggo                       ...
# floofer                     ...
# pupper                      ...
# puppo                       ...
#
#                                                                          926   \
# tweet_id                                                   754874841593970688
# in_reply_to_status_id                                                     NaN
# in_reply_to_user_id                                                       NaN
# timestamp                                           2016-07-18 03:06:01 +0000
# source                      <a href="http://twitter.com/download/iphone" r...
# text                        RT @dog_rates: This is Rubio. He has too much ...
# retweeted_status_id                                      679158373988876288.0
# retweeted_status_user_id                                         4196983835.0
# retweeted_status_timestamp                          2015-12-22 04:35:49 +0000
# expanded_urls               https://twitter.com/dog_rates/status/679158373...
# rating_numerator                                                           11
# rating_denominator                                                         10
# name                                                                    Rubio
# doggo                                                                    None
# floofer                                                                  None
# pupper                                                                   None
# puppo                                                                    None
#
#                                                                          937   \
# tweet_id                                                   753298634498793472
# in_reply_to_status_id                                                     NaN
# in_reply_to_user_id                                                       NaN
# timestamp                                           2016-07-13 18:42:44 +0000
# source                      <a href="http://twitter.com/download/iphone" r...
# text                        RT @dog_rates: This is Carly. She's actually 2...
# retweeted_status_id                                      681523177663676416.0
# retweeted_status_user_id                                         4196983835.0
# retweeted_status_timestamp                          2015-12-28 17:12:42 +0000
# expanded_urls               https://twitter.com/dog_rates/status/681523177...
# rating_numerator                                                           12
# rating_denominator                                                         10
# name                                                                    Carly
# doggo                                                                    None
# floofer                                                                  None
# pupper                                                                   None
# puppo                                                                    None
#
#                                                                          943   \
# tweet_id                                                   752701944171524096
# in_reply_to_status_id                                                     NaN
# in_reply_to_user_id                                                       NaN
# timestamp                                           2016-07-12 03:11:42 +0000
# source                      <a href="http://twitter.com/download/iphone" r...
# text                        RT @dog_rates: HEY PUP WHAT'S THE PART OF THE ...
# retweeted_status_id                                      683515932363329536.0
# retweeted_status_user_id                                         4196983835.0
# retweeted_status_timestamp                          2016-01-03 05:11:12 +0000
# expanded_urls               https://vine.co/v/ibvnzrauFuV,https://vine.co/...
# rating_numerator                                                           11
# rating_denominator                                                         10
# name                                                                     None
# doggo                                                                    None
# floofer                                                                  None
# pupper                                                                   None
# puppo                                                                    None
#
#                                                                          949   \
# tweet_id                                                   752309394570878976
# in_reply_to_status_id                                                     NaN
# in_reply_to_user_id                                                       NaN
# timestamp                                           2016-07-11 01:11:51 +0000
# source                      <a href="http://twitter.com/download/iphone" r...
# text                        RT @dog_rates: Everyone needs to watch this. 1...
# retweeted_status_id                                      675354435921575936.0
# retweeted_status_user_id                                         4196983835.0
# retweeted_status_timestamp                          2015-12-11 16:40:19 +0000
# expanded_urls               https://twitter.com/dog_rates/status/675354435...
# rating_numerator                                                           13
# rating_denominator                                                         10
# name                                                                     None
# doggo                                                                    None
# floofer                                                                  None
# pupper                                                                   None
# puppo                                                                    None
#
#                                                                          1012  \
# tweet_id                                                   747242308580548608
# in_reply_to_status_id                                                     NaN
# in_reply_to_user_id                                                       NaN
# timestamp                                           2016-06-27 01:37:04 +0000
# source                      <a href="http://twitter.com/download/iphone" r...
# text                        RT @dog_rates: This pupper killed this great w...
# retweeted_status_id                                      704761120771465216.0
# retweeted_status_user_id                                         4196983835.0
# retweeted_status_timestamp                          2016-03-01 20:11:59 +0000
# expanded_urls               https://twitter.com/dog_rates/status/704761120...
# rating_numerator                                                           13
# rating_denominator                                                         10
# name                                                                     None
# doggo                                                                    None
# floofer                                                                  None
# pupper                                                                 pupper
# puppo                                                                    None
#
#                                                                          1023  \
# tweet_id                                                   746521445350707200
# in_reply_to_status_id                                                     NaN
# in_reply_to_user_id                                                       NaN
# timestamp                                           2016-06-25 01:52:36 +0000
# source                      <a href="http://twitter.com/download/iphone" r...
# text                        RT @dog_rates: This is Shaggy. He knows exactl...
# retweeted_status_id                                      667866724293877760.0
# retweeted_status_user_id                                         4196983835.0
# retweeted_status_timestamp                          2015-11-21 00:46:50 +0000
# expanded_urls               https://twitter.com/dog_rates/status/667866724...
# rating_numerator                                                           10
# rating_denominator                                                         10
# name                                                                   Shaggy
# doggo                                                                    None
# floofer                                                                  None
# pupper                                                                   None
# puppo                                                                    None
#
#                                                                          1043  \
# tweet_id                                                   743835915802583040
# in_reply_to_status_id                                                     NaN
# in_reply_to_user_id                                                       NaN
# timestamp                                           2016-06-17 16:01:16 +0000
# source                      <a href="http://twitter.com/download/iphone" r...
# text                        RT @dog_rates: Extremely intelligent dog here....
# retweeted_status_id                                      667138269671505920.0
# retweeted_status_user_id                                         4196983835.0
# retweeted_status_timestamp                          2015-11-19 00:32:12 +0000
# expanded_urls               https://twitter.com/dog_rates/status/667138269...
# rating_numerator                                                           10
# rating_denominator                                                         10
# name                                                                     None
# doggo                                                                    None
# floofer                                                                  None
# pupper                                                                   None
# puppo                                                                    None
#
#                                                                          1242  \
# tweet_id                                                   711998809858043904
# in_reply_to_status_id                                                     NaN
# in_reply_to_user_id                                                       NaN
# timestamp                                           2016-03-21 19:31:59 +0000
# source                      <a href="http://twitter.com/download/iphone" r...
# text                        RT @twitter: @dog_rates Awesome Tweet! 12/10. ...
# retweeted_status_id                                      711998279773347840.0
# retweeted_status_user_id                                             783214.0
# retweeted_status_timestamp                          2016-03-21 19:29:52 +0000
# expanded_urls               https://twitter.com/twitter/status/71199827977...
# rating_numerator                                                           12
# rating_denominator                                                         10
# name                                                                     None
# doggo                                                                    None
# floofer                                                                  None
# pupper                                                                   None
# puppo                                                                    None
#
#                                                                          2259  \
# tweet_id                                                   667550904950915073
# in_reply_to_status_id                                                     NaN
# in_reply_to_user_id                                                       NaN
# timestamp                                           2015-11-20 03:51:52 +0000
# source                      <a href="http://twitter.com" rel="nofollow">Tw...
# text                        RT @dogratingrating: Exceptional talent. Origi...
# retweeted_status_id                                      667548695664070656.0
# retweeted_status_user_id                                         4296831739.0
# retweeted_status_timestamp                          2015-11-20 03:43:06 +0000
# expanded_urls               https://twitter.com/dogratingrating/status/667...
# rating_numerator                                                           12
# rating_denominator                                                         10
# name                                                                     None
# doggo                                                                    None
# floofer                                                                  None
# pupper                                                                   None
# puppo                                                                    None
#
#                                                                          2260
# tweet_id                                                   667550882905632768
# in_reply_to_status_id                                                     NaN
# in_reply_to_user_id                                                       NaN
# timestamp                                           2015-11-20 03:51:47 +0000
# source                      <a href="http://twitter.com" rel="nofollow">Tw...
# text                        RT @dogratingrating: Unoriginal idea. Blatant ...
# retweeted_status_id                                      667548415174144000.0
# retweeted_status_user_id                                         4296831739.0
# retweeted_status_timestamp                          2015-11-20 03:41:59 +0000
# expanded_urls               https://twitter.com/dogratingrating/status/667...
# rating_numerator                                                            5
# rating_denominator                                                         10
# name                                                                     None
# doggo                                                                    None
# floofer                                                                  None
# pupper                                                                   None
# puppo                                                                    None
#
# [17 rows x 181 columns]

# %% [markdown]
# Those retweeted samples should not be present in our dataset, as per the projec instruction.

# %%
# Taking a look at the samples which have value in expanded_urls column
twitter_archive_df[ ~ twitter_archive_df["expanded_urls"].isnull() ].T
# Out:
#                                                                          0     \
# tweet_id                                                   892420643555336193
# in_reply_to_status_id                                                     NaN
# in_reply_to_user_id                                                       NaN
# timestamp                                           2017-08-01 16:23:56 +0000
# source                      <a href="http://twitter.com/download/iphone" r...
# text                        This is Phineas. He's a mystical boy. Only eve...
# retweeted_status_id                                                       NaN
# retweeted_status_user_id                                                  NaN
# retweeted_status_timestamp                                                NaN
# expanded_urls               https://twitter.com/dog_rates/status/892420643...
# rating_numerator                                                           13
# rating_denominator                                                         10
# name                                                                  Phineas
# doggo                                                                    None
# floofer                                                                  None
# pupper                                                                   None
# puppo                                                                    None
#
#                                                                          1     \
# tweet_id                                                   892177421306343426
# in_reply_to_status_id                                                     NaN
# in_reply_to_user_id                                                       NaN
# timestamp                                           2017-08-01 00:17:27 +0000
# source                      <a href="http://twitter.com/download/iphone" r...
# text                        This is Tilly. She's just checking pup on you....
# retweeted_status_id                                                       NaN
# retweeted_status_user_id                                                  NaN
# retweeted_status_timestamp                                                NaN
# expanded_urls               https://twitter.com/dog_rates/status/892177421...
# rating_numerator                                                           13
# rating_denominator                                                         10
# name                                                                    Tilly
# doggo                                                                    None
# floofer                                                                  None
# pupper                                                                   None
# puppo                                                                    None
#
#                                                                          2     \
# tweet_id                                                   891815181378084864
# in_reply_to_status_id                                                     NaN
# in_reply_to_user_id                                                       NaN
# timestamp                                           2017-07-31 00:18:03 +0000
# source                      <a href="http://twitter.com/download/iphone" r...
# text                        This is Archie. He is a rare Norwegian Pouncin...
# retweeted_status_id                                                       NaN
# retweeted_status_user_id                                                  NaN
# retweeted_status_timestamp                                                NaN
# expanded_urls               https://twitter.com/dog_rates/status/891815181...
# rating_numerator                                                           12
# rating_denominator                                                         10
# name                                                                   Archie
# doggo                                                                    None
# floofer                                                                  None
# pupper                                                                   None
# puppo                                                                    None
#
#                                                                          3     \
# tweet_id                                                   891689557279858688
# in_reply_to_status_id                                                     NaN
# in_reply_to_user_id                                                       NaN
# timestamp                                           2017-07-30 15:58:51 +0000
# source                      <a href="http://twitter.com/download/iphone" r...
# text                        This is Darla. She commenced a snooze mid meal...
# retweeted_status_id                                                       NaN
# retweeted_status_user_id                                                  NaN
# retweeted_status_timestamp                                                NaN
# expanded_urls               https://twitter.com/dog_rates/status/891689557...
# rating_numerator                                                           13
# rating_denominator                                                         10
# name                                                                    Darla
# doggo                                                                    None
# floofer                                                                  None
# pupper                                                                   None
# puppo                                                                    None
#
#                                                                          4     \
# tweet_id                                                   891327558926688256
# in_reply_to_status_id                                                     NaN
# in_reply_to_user_id                                                       NaN
# timestamp                                           2017-07-29 16:00:24 +0000
# source                      <a href="http://twitter.com/download/iphone" r...
# text                        This is Franklin. He would like you to stop ca...
# retweeted_status_id                                                       NaN
# retweeted_status_user_id                                                  NaN
# retweeted_status_timestamp                                                NaN
# expanded_urls               https://twitter.com/dog_rates/status/891327558...
# rating_numerator                                                           12
# rating_denominator                                                         10
# name                                                                 Franklin
# doggo                                                                    None
# floofer                                                                  None
# pupper                                                                   None
# puppo                                                                    None
#
#                                                                          5     \
# tweet_id                                                   891087950875897856
# in_reply_to_status_id                                                     NaN
# in_reply_to_user_id                                                       NaN
# timestamp                                           2017-07-29 00:08:17 +0000
# source                      <a href="http://twitter.com/download/iphone" r...
# text                        Here we have a majestic great white breaching ...
# retweeted_status_id                                                       NaN
# retweeted_status_user_id                                                  NaN
# retweeted_status_timestamp                                                NaN
# expanded_urls               https://twitter.com/dog_rates/status/891087950...
# rating_numerator                                                           13
# rating_denominator                                                         10
# name                                                                     None
# doggo                                                                    None
# floofer                                                                  None
# pupper                                                                   None
# puppo                                                                    None
#
#                                                                          6     \
# tweet_id                                                   890971913173991426
# in_reply_to_status_id                                                     NaN
# in_reply_to_user_id                                                       NaN
# timestamp                                           2017-07-28 16:27:12 +0000
# source                      <a href="http://twitter.com/download/iphone" r...
# text                        Meet Jax. He enjoys ice cream so much he gets ...
# retweeted_status_id                                                       NaN
# retweeted_status_user_id                                                  NaN
# retweeted_status_timestamp                                                NaN
# expanded_urls               https://gofundme.com/ydvmve-surgery-for-jax,ht...
# rating_numerator                                                           13
# rating_denominator                                                         10
# name                                                                      Jax
# doggo                                                                    None
# floofer                                                                  None
# pupper                                                                   None
# puppo                                                                    None
#
#                                                                          7     \
# tweet_id                                                   890729181411237888
# in_reply_to_status_id                                                     NaN
# in_reply_to_user_id                                                       NaN
# timestamp                                           2017-07-28 00:22:40 +0000
# source                      <a href="http://twitter.com/download/iphone" r...
# text                        When you watch your owner call another dog a g...
# retweeted_status_id                                                       NaN
# retweeted_status_user_id                                                  NaN
# retweeted_status_timestamp                                                NaN
# expanded_urls               https://twitter.com/dog_rates/status/890729181...
# rating_numerator                                                           13
# rating_denominator                                                         10
# name                                                                     None
# doggo                                                                    None
# floofer                                                                  None
# pupper                                                                   None
# puppo                                                                    None
#
#                                                                          8     \
# tweet_id                                                   890609185150312448
# in_reply_to_status_id                                                     NaN
# in_reply_to_user_id                                                       NaN
# timestamp                                           2017-07-27 16:25:51 +0000
# source                      <a href="http://twitter.com/download/iphone" r...
# text                        This is Zoey. She doesn't want to be one of th...
# retweeted_status_id                                                       NaN
# retweeted_status_user_id                                                  NaN
# retweeted_status_timestamp                                                NaN
# expanded_urls               https://twitter.com/dog_rates/status/890609185...
# rating_numerator                                                           13
# rating_denominator                                                         10
# name                                                                     Zoey
# doggo                                                                    None
# floofer                                                                  None
# pupper                                                                   None
# puppo                                                                    None
#
#                                                                          9     \
# tweet_id                                                   890240255349198849
# in_reply_to_status_id                                                     NaN
# in_reply_to_user_id                                                       NaN
# timestamp                                           2017-07-26 15:59:51 +0000
# source                      <a href="http://twitter.com/download/iphone" r...
# text                        This is Cassie. She is a college pup. Studying...
# retweeted_status_id                                                       NaN
# retweeted_status_user_id                                                  NaN
# retweeted_status_timestamp                                                NaN
# expanded_urls               https://twitter.com/dog_rates/status/890240255...
# rating_numerator                                                           14
# rating_denominator                                                         10
# name                                                                   Cassie
# doggo                                                                   doggo
# floofer                                                                  None
# pupper                                                                   None
# puppo                                                                    None
#
#                             ...  \
# tweet_id                    ...
# in_reply_to_status_id       ...
# in_reply_to_user_id         ...
# timestamp                   ...
# source                      ...
# text                        ...
# retweeted_status_id         ...
# retweeted_status_user_id    ...
# retweeted_status_timestamp  ...
# expanded_urls               ...
# rating_numerator            ...
# rating_denominator          ...
# name                        ...
# doggo                       ...
# floofer                     ...
# pupper                      ...
# puppo                       ...
#
#                                                                          2346  \
# tweet_id                                                   666058600524156928
# in_reply_to_status_id                                                     NaN
# in_reply_to_user_id                                                       NaN
# timestamp                                           2015-11-16 01:01:59 +0000
# source                      <a href="http://twitter.com/download/iphone" r...
# text                        Here is the Rand Paul of retrievers folks! He'...
# retweeted_status_id                                                       NaN
# retweeted_status_user_id                                                  NaN
# retweeted_status_timestamp                                                NaN
# expanded_urls               https://twitter.com/dog_rates/status/666058600...
# rating_numerator                                                            8
# rating_denominator                                                         10
# name                                                                      the
# doggo                                                                    None
# floofer                                                                  None
# pupper                                                                   None
# puppo                                                                    None
#
#                                                                          2347  \
# tweet_id                                                   666057090499244032
# in_reply_to_status_id                                                     NaN
# in_reply_to_user_id                                                       NaN
# timestamp                                           2015-11-16 00:55:59 +0000
# source                      <a href="http://twitter.com/download/iphone" r...
# text                        My oh my. This is a rare blond Canadian terrie...
# retweeted_status_id                                                       NaN
# retweeted_status_user_id                                                  NaN
# retweeted_status_timestamp                                                NaN
# expanded_urls               https://twitter.com/dog_rates/status/666057090...
# rating_numerator                                                            9
# rating_denominator                                                         10
# name                                                                        a
# doggo                                                                    None
# floofer                                                                  None
# pupper                                                                   None
# puppo                                                                    None
#
#                                                                          2348  \
# tweet_id                                                   666055525042405380
# in_reply_to_status_id                                                     NaN
# in_reply_to_user_id                                                       NaN
# timestamp                                           2015-11-16 00:49:46 +0000
# source                      <a href="http://twitter.com/download/iphone" r...
# text                        Here is a Siberian heavily armored polar bear ...
# retweeted_status_id                                                       NaN
# retweeted_status_user_id                                                  NaN
# retweeted_status_timestamp                                                NaN
# expanded_urls               https://twitter.com/dog_rates/status/666055525...
# rating_numerator                                                           10
# rating_denominator                                                         10
# name                                                                        a
# doggo                                                                    None
# floofer                                                                  None
# pupper                                                                   None
# puppo                                                                    None
#
#                                                                          2349  \
# tweet_id                                                   666051853826850816
# in_reply_to_status_id                                                     NaN
# in_reply_to_user_id                                                       NaN
# timestamp                                           2015-11-16 00:35:11 +0000
# source                      <a href="http://twitter.com/download/iphone" r...
# text                        This is an odd dog. Hard on the outside but lo...
# retweeted_status_id                                                       NaN
# retweeted_status_user_id                                                  NaN
# retweeted_status_timestamp                                                NaN
# expanded_urls               https://twitter.com/dog_rates/status/666051853...
# rating_numerator                                                            2
# rating_denominator                                                         10
# name                                                                       an
# doggo                                                                    None
# floofer                                                                  None
# pupper                                                                   None
# puppo                                                                    None
#
#                                                                          2350  \
# tweet_id                                                   666050758794694657
# in_reply_to_status_id                                                     NaN
# in_reply_to_user_id                                                       NaN
# timestamp                                           2015-11-16 00:30:50 +0000
# source                      <a href="http://twitter.com/download/iphone" r...
# text                        This is a truly beautiful English Wilson Staff...
# retweeted_status_id                                                       NaN
# retweeted_status_user_id                                                  NaN
# retweeted_status_timestamp                                                NaN
# expanded_urls               https://twitter.com/dog_rates/status/666050758...
# rating_numerator                                                           10
# rating_denominator                                                         10
# name                                                                        a
# doggo                                                                    None
# floofer                                                                  None
# pupper                                                                   None
# puppo                                                                    None
#
#                                                                          2351  \
# tweet_id                                                   666049248165822465
# in_reply_to_status_id                                                     NaN
# in_reply_to_user_id                                                       NaN
# timestamp                                           2015-11-16 00:24:50 +0000
# source                      <a href="http://twitter.com/download/iphone" r...
# text                        Here we have a 1949 1st generation vulpix. Enj...
# retweeted_status_id                                                       NaN
# retweeted_status_user_id                                                  NaN
# retweeted_status_timestamp                                                NaN
# expanded_urls               https://twitter.com/dog_rates/status/666049248...
# rating_numerator                                                            5
# rating_denominator                                                         10
# name                                                                     None
# doggo                                                                    None
# floofer                                                                  None
# pupper                                                                   None
# puppo                                                                    None
#
#                                                                          2352  \
# tweet_id                                                   666044226329800704
# in_reply_to_status_id                                                     NaN
# in_reply_to_user_id                                                       NaN
# timestamp                                           2015-11-16 00:04:52 +0000
# source                      <a href="http://twitter.com/download/iphone" r...
# text                        This is a purebred Piers Morgan. Loves to Netf...
# retweeted_status_id                                                       NaN
# retweeted_status_user_id                                                  NaN
# retweeted_status_timestamp                                                NaN
# expanded_urls               https://twitter.com/dog_rates/status/666044226...
# rating_numerator                                                            6
# rating_denominator                                                         10
# name                                                                        a
# doggo                                                                    None
# floofer                                                                  None
# pupper                                                                   None
# puppo                                                                    None
#
#                                                                          2353  \
# tweet_id                                                   666033412701032449
# in_reply_to_status_id                                                     NaN
# in_reply_to_user_id                                                       NaN
# timestamp                                           2015-11-15 23:21:54 +0000
# source                      <a href="http://twitter.com/download/iphone" r...
# text                        Here is a very happy pup. Big fan of well-main...
# retweeted_status_id                                                       NaN
# retweeted_status_user_id                                                  NaN
# retweeted_status_timestamp                                                NaN
# expanded_urls               https://twitter.com/dog_rates/status/666033412...
# rating_numerator                                                            9
# rating_denominator                                                         10
# name                                                                        a
# doggo                                                                    None
# floofer                                                                  None
# pupper                                                                   None
# puppo                                                                    None
#
#                                                                          2354  \
# tweet_id                                                   666029285002620928
# in_reply_to_status_id                                                     NaN
# in_reply_to_user_id                                                       NaN
# timestamp                                           2015-11-15 23:05:30 +0000
# source                      <a href="http://twitter.com/download/iphone" r...
# text                        This is a western brown Mitsubishi terrier. Up...
# retweeted_status_id                                                       NaN
# retweeted_status_user_id                                                  NaN
# retweeted_status_timestamp                                                NaN
# expanded_urls               https://twitter.com/dog_rates/status/666029285...
# rating_numerator                                                            7
# rating_denominator                                                         10
# name                                                                        a
# doggo                                                                    None
# floofer                                                                  None
# pupper                                                                   None
# puppo                                                                    None
#
#                                                                          2355
# tweet_id                                                   666020888022790149
# in_reply_to_status_id                                                     NaN
# in_reply_to_user_id                                                       NaN
# timestamp                                           2015-11-15 22:32:08 +0000
# source                      <a href="http://twitter.com/download/iphone" r...
# text                        Here we have a Japanese Irish Setter. Lost eye...
# retweeted_status_id                                                       NaN
# retweeted_status_user_id                                                  NaN
# retweeted_status_timestamp                                                NaN
# expanded_urls               https://twitter.com/dog_rates/status/666020888...
# rating_numerator                                                            8
# rating_denominator                                                         10
# name                                                                     None
# doggo                                                                    None
# floofer                                                                  None
# pupper                                                                   None
# puppo                                                                    None
#
# [17 rows x 2297 columns]

# %%
# Assessing the content of twitter_archive_df["source"]
twitter_archive_df["source"].unique()
# Out:
# array(['<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#        '<a href="http://twitter.com" rel="nofollow">Twitter Web Client</a>',
#        '<a href="http://vine.co" rel="nofollow">Vine - Make a Scene</a>',
#        '<a href="https://about.twitter.com/products/tweetdeck" rel="nofollow">TweetDeck</a>'],
#       dtype=object)

# %%
# Looking at the content of tweets_df
tweets_df.head(3).T
# Out:
#                                                                                0  \
# created_at                                        Tue Aug 01 16:23:56 +0000 2017
# id                                                            892420643555336193
# id_str                                                        892420643555336193
# full_text                      This is Phineas. He's a mystical boy. Only eve...
# truncated                                                                  False
# display_text_range                                                       [0, 85]
# entities                       {'hashtags': [], 'symbols': [], 'user_mentions...
# extended_entities              {'media': [{'id': 892420639486877696, 'id_str'...
# source                         <a href="http://twitter.com/download/iphone" r...
# in_reply_to_status_id                                                        NaN
# in_reply_to_status_id_str                                                   None
# in_reply_to_user_id                                                          NaN
# in_reply_to_user_id_str                                                     None
# in_reply_to_screen_name                                                     None
# user                           {'id': 4196983835, 'id_str': '4196983835', 'na...
# geo                                                                         None
# coordinates                                                                 None
# place                                                                       None
# contributors                                                                None
# is_quote_status                                                            False
# retweet_count                                                               8853
# favorite_count                                                             39467
# favorited                                                                  False
# retweeted                                                                  False
# possibly_sensitive                                                         False
# possibly_sensitive_appealable                                              False
# lang                                                                          en
# retweeted_status                                                             NaN
# quoted_status_id                                                             NaN
# quoted_status_id_str                                                         NaN
# quoted_status                                                                NaN
#
#                                                                                1  \
# created_at                                        Tue Aug 01 00:17:27 +0000 2017
# id                                                            892177421306343426
# id_str                                                        892177421306343426
# full_text                      This is Tilly. She's just checking pup on you....
# truncated                                                                  False
# display_text_range                                                      [0, 138]
# entities                       {'hashtags': [], 'symbols': [], 'user_mentions...
# extended_entities              {'media': [{'id': 892177413194625024, 'id_str'...
# source                         <a href="http://twitter.com/download/iphone" r...
# in_reply_to_status_id                                                        NaN
# in_reply_to_status_id_str                                                   None
# in_reply_to_user_id                                                          NaN
# in_reply_to_user_id_str                                                     None
# in_reply_to_screen_name                                                     None
# user                           {'id': 4196983835, 'id_str': '4196983835', 'na...
# geo                                                                         None
# coordinates                                                                 None
# place                                                                       None
# contributors                                                                None
# is_quote_status                                                            False
# retweet_count                                                               6514
# favorite_count                                                             33819
# favorited                                                                  False
# retweeted                                                                  False
# possibly_sensitive                                                         False
# possibly_sensitive_appealable                                              False
# lang                                                                          en
# retweeted_status                                                             NaN
# quoted_status_id                                                             NaN
# quoted_status_id_str                                                         NaN
# quoted_status                                                                NaN
#
#                                                                                2
# created_at                                        Mon Jul 31 00:18:03 +0000 2017
# id                                                            891815181378084864
# id_str                                                        891815181378084864
# full_text                      This is Archie. He is a rare Norwegian Pouncin...
# truncated                                                                  False
# display_text_range                                                      [0, 121]
# entities                       {'hashtags': [], 'symbols': [], 'user_mentions...
# extended_entities              {'media': [{'id': 891815175371796480, 'id_str'...
# source                         <a href="http://twitter.com/download/iphone" r...
# in_reply_to_status_id                                                        NaN
# in_reply_to_status_id_str                                                   None
# in_reply_to_user_id                                                          NaN
# in_reply_to_user_id_str                                                     None
# in_reply_to_screen_name                                                     None
# user                           {'id': 4196983835, 'id_str': '4196983835', 'na...
# geo                                                                         None
# coordinates                                                                 None
# place                                                                       None
# contributors                                                                None
# is_quote_status                                                            False
# retweet_count                                                               4328
# favorite_count                                                             25461
# favorited                                                                  False
# retweeted                                                                  False
# possibly_sensitive                                                         False
# possibly_sensitive_appealable                                              False
# lang                                                                          en
# retweeted_status                                                             NaN
# quoted_status_id                                                             NaN
# quoted_status_id_str                                                         NaN
# quoted_status                                                                NaN

# %%
# Looking at the structure of tweets_df
tweets_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2354 entries, 0 to 2353
# Data columns (total 31 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   created_at                     2354 non-null   object
#  1   id                             2354 non-null   int64
#  2   id_str                         2354 non-null   object
#  3   full_text                      2354 non-null   object
#  4   truncated                      2354 non-null   bool
#  5   display_text_range             2354 non-null   object
#  6   entities                       2354 non-null   object
#  7   extended_entities              2073 non-null   object
#  8   source                         2354 non-null   object
#  9   in_reply_to_status_id          78 non-null     float64
#  10  in_reply_to_status_id_str      78 non-null     object
#  11  in_reply_to_user_id            78 non-null     float64
#  12  in_reply_to_user_id_str        78 non-null     object
#  13  in_reply_to_screen_name        78 non-null     object
#  14  user                           2354 non-null   object
#  15  geo                            0 non-null      object
#  16  coordinates                    0 non-null      object
#  17  place                          1 non-null      object
#  18  contributors                   0 non-null      object
#  19  is_quote_status                2354 non-null   bool
#  20  retweet_count                  2354 non-null   int64
#  21  favorite_count                 2354 non-null   int64
#  22  favorited                      2354 non-null   bool
#  23  retweeted                      2354 non-null   bool
#  24  possibly_sensitive             2211 non-null   object
#  25  possibly_sensitive_appealable  2211 non-null   object
#  26  lang                           2354 non-null   object
#  27  retweeted_status               179 non-null    object
#  28  quoted_status_id               29 non-null     float64
#  29  quoted_status_id_str           29 non-null     object
#  30  quoted_status                  28 non-null     object
# dtypes: bool(4), float64(3), int64(3), object(21)
# memory usage: 505.9+ KB

# %%
# Looking at the content of image_predictions_df
image_predictions_df.tail(3).T
# Out:
#                                                      2072  \
# tweet_id                               891815181378084864
# jpg_url   https://pbs.twimg.com/media/DGBdLU1WsAANxJ9.jpg
# img_num                                                 1
# p1                                              Chihuahua
# p1_conf                                          0.716012
# p1_dog                                               True
# p2                                               malamute
# p2_conf                                          0.078253
# p2_dog                                               True
# p3                                                 kelpie
# p3_conf                                          0.031379
# p3_dog                                               True
#
#                                                      2073  \
# tweet_id                               892177421306343426
# jpg_url   https://pbs.twimg.com/media/DGGmoV4XsAAUL6n.jpg
# img_num                                                 1
# p1                                              Chihuahua
# p1_conf                                          0.323581
# p1_dog                                               True
# p2                                               Pekinese
# p2_conf                                          0.090647
# p2_dog                                               True
# p3                                               papillon
# p3_conf                                          0.068957
# p3_dog                                               True
#
#                                                      2074
# tweet_id                               892420643555336193
# jpg_url   https://pbs.twimg.com/media/DGKD1-bXoAAIAUK.jpg
# img_num                                                 1
# p1                                                 orange
# p1_conf                                          0.097049
# p1_dog                                              False
# p2                                                  bagel
# p2_conf                                          0.085851
# p2_dog                                              False
# p3                                                 banana
# p3_conf                                           0.07611
# p3_dog                                              False

# %%
# Observing the structure of image_predictions_df
image_predictions_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2075 entries, 0 to 2074
# Data columns (total 12 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   tweet_id  2075 non-null   int64
#  1   jpg_url   2075 non-null   object
#  2   img_num   2075 non-null   int64
#  3   p1        2075 non-null   object
#  4   p1_conf   2075 non-null   float64
#  5   p1_dog    2075 non-null   bool
#  6   p2        2075 non-null   object
#  7   p2_conf   2075 non-null   float64
#  8   p2_dog    2075 non-null   bool
#  9   p3        2075 non-null   object
#  10  p3_conf   2075 non-null   float64
#  11  p3_dog    2075 non-null   bool
# dtypes: bool(3), float64(3), int64(2), object(4)
# memory usage: 152.1+ KB

# %%
# sum(tweets_df.duplicated())

# %% [markdown]
# **Checking if there are dogs with multiple stages**
# Since the "stages name as column" issue will be dealt with by pandas.melt(), it is good to make sure if there are dogs with more than one stage (in order to be aware of duplicate tweet id).

# %%
"""
TODO : 
 - create a new column named nb_stage, which will contain the number of stages associated with a dog
 - loop through each sample in the df, in order to count the number of its stage
 - retrieve and assess sample with nb_stage>1 
"""
# Out:
# '\nTODO : \n - create a new column named nb_stage, which will contain the number of stages associated with a dog\n - loop through each sample in the df, in order to count the number of its stage\n - retrieve and assess sample with nb_stage>1 \n'

# %%
twitter_archive_df["nb_stage"] = 0
twitter_archive_df["nb_stage"].unique()
# Out:
# array([0], dtype=int64)

# %%
twitter_archive_df.head(3).T
# Out:
#                                                                             0  \
# tweet_id                                                   892420643555336193
# in_reply_to_status_id                                                     NaN
# in_reply_to_user_id                                                       NaN
# timestamp                                           2017-08-01 16:23:56 +0000
# source                      <a href="http://twitter.com/download/iphone" r...
# text                        This is Phineas. He's a mystical boy. Only eve...
# retweeted_status_id                                                       NaN
# retweeted_status_user_id                                                  NaN
# retweeted_status_timestamp                                                NaN
# expanded_urls               https://twitter.com/dog_rates/status/892420643...
# rating_numerator                                                           13
# rating_denominator                                                         10
# name                                                                  Phineas
# doggo                                                                    None
# floofer                                                                  None
# pupper                                                                   None
# puppo                                                                    None
# nb_stage                                                                    0
#
#                                                                             1  \
# tweet_id                                                   892177421306343426
# in_reply_to_status_id                                                     NaN
# in_reply_to_user_id                                                       NaN
# timestamp                                           2017-08-01 00:17:27 +0000
# source                      <a href="http://twitter.com/download/iphone" r...
# text                        This is Tilly. She's just checking pup on you....
# retweeted_status_id                                                       NaN
# retweeted_status_user_id                                                  NaN
# retweeted_status_timestamp                                                NaN
# expanded_urls               https://twitter.com/dog_rates/status/892177421...
# rating_numerator                                                           13
# rating_denominator                                                         10
# name                                                                    Tilly
# doggo                                                                    None
# floofer                                                                  None
# pupper                                                                   None
# puppo                                                                    None
# nb_stage                                                                    0
#
#                                                                             2
# tweet_id                                                   891815181378084864
# in_reply_to_status_id                                                     NaN
# in_reply_to_user_id                                                       NaN
# timestamp                                           2017-07-31 00:18:03 +0000
# source                      <a href="http://twitter.com/download/iphone" r...
# text                        This is Archie. He is a rare Norwegian Pouncin...
# retweeted_status_id                                                       NaN
# retweeted_status_user_id                                                  NaN
# retweeted_status_timestamp                                                NaN
# expanded_urls               https://twitter.com/dog_rates/status/891815181...
# rating_numerator                                                           12
# rating_denominator                                                         10
# name                                                                   Archie
# doggo                                                                    None
# floofer                                                                  None
# pupper                                                                   None
# puppo                                                                    None
# nb_stage                                                                    0

# %%
# Counting the number of stage associated with each dog
stage_cols = ["doggo","floofer","pupper","puppo"]

for index,row in twitter_archive_df.iterrows(): 
    nb_stage=0
    for col in stage_cols:
        if row[col]!= "None":
            nb_stage+=1
    twitter_archive_df.loc[index,"nb_stage"] = nb_stage

twitter_archive_df["nb_stage"].unique()
# Out:
# array([0, 1, 2], dtype=int64)

# %% [markdown]
# We can see that some dogs are associated with more than one stage, which we should investigate.

# %%
tweets_with_many_stages = twitter_archive_df[ twitter_archive_df["nb_stage"]>1 ]
tweets_with_many_stages.shape
# Out:
# (14, 18)

# %% [markdown]
# We have 18 samples which have more than 1 stage. Let us take a look at their content.

# %%
tweets_with_many_stages.T
# Out:
#                                                                          191   \
# tweet_id                                                   855851453814013952
# in_reply_to_status_id                                                     NaN
# in_reply_to_user_id                                                       NaN
# timestamp                                           2017-04-22 18:31:02 +0000
# source                      <a href="http://twitter.com/download/iphone" r...
# text                        Here's a puppo participating in the #ScienceMa...
# retweeted_status_id                                                       NaN
# retweeted_status_user_id                                                  NaN
# retweeted_status_timestamp                                                NaN
# expanded_urls               https://twitter.com/dog_rates/status/855851453...
# rating_numerator                                                           13
# rating_denominator                                                         10
# name                                                                     None
# doggo                                                                   doggo
# floofer                                                                  None
# pupper                                                                   None
# puppo                                                                   puppo
# nb_stage                                                                    2
#
#                                                                          200   \
# tweet_id                                                   854010172552949760
# in_reply_to_status_id                                                     NaN
# in_reply_to_user_id                                                       NaN
# timestamp                                           2017-04-17 16:34:26 +0000
# source                      <a href="http://twitter.com/download/iphone" r...
# text                        At first I thought this was a shy doggo, but i...
# retweeted_status_id                                                       NaN
# retweeted_status_user_id                                                  NaN
# retweeted_status_timestamp                                                NaN
# expanded_urls               https://twitter.com/dog_rates/status/854010172...
# rating_numerator                                                           11
# rating_denominator                                                         10
# name                                                                     None
# doggo                                                                   doggo
# floofer                                                               floofer
# pupper                                                                   None
# puppo                                                                    None
# nb_stage                                                                    2
#
#                                                                          460   \
# tweet_id                                                   817777686764523521
# in_reply_to_status_id                                                     NaN
# in_reply_to_user_id                                                       NaN
# timestamp                                           2017-01-07 16:59:28 +0000
# source                      <a href="http://twitter.com/download/iphone" r...
# text                        This is Dido. She's playing the lead role in "...
# retweeted_status_id                                                       NaN
# retweeted_status_user_id                                                  NaN
# retweeted_status_timestamp                                                NaN
# expanded_urls               https://twitter.com/dog_rates/status/817777686...
# rating_numerator                                                           13
# rating_denominator                                                         10
# name                                                                     Dido
# doggo                                                                   doggo
# floofer                                                                  None
# pupper                                                                 pupper
# puppo                                                                    None
# nb_stage                                                                    2
#
#                                                                          531   \
# tweet_id                                                   808106460588765185
# in_reply_to_status_id                                                     NaN
# in_reply_to_user_id                                                       NaN
# timestamp                                           2016-12-12 00:29:28 +0000
# source                      <a href="http://twitter.com/download/iphone" r...
# text                        Here we have Burke (pupper) and Dexter (doggo)...
# retweeted_status_id                                                       NaN
# retweeted_status_user_id                                                  NaN
# retweeted_status_timestamp                                                NaN
# expanded_urls               https://twitter.com/dog_rates/status/808106460...
# rating_numerator                                                           12
# rating_denominator                                                         10
# name                                                                     None
# doggo                                                                   doggo
# floofer                                                                  None
# pupper                                                                 pupper
# puppo                                                                    None
# nb_stage                                                                    2
#
#                                                                          565   \
# tweet_id                                                   802265048156610565
# in_reply_to_status_id                                    733109485275860992.0
# in_reply_to_user_id                                              4196983835.0
# timestamp                                           2016-11-25 21:37:47 +0000
# source                      <a href="http://twitter.com/download/iphone" r...
# text                        Like doggo, like pupper version 2. Both 11/10 ...
# retweeted_status_id                                                       NaN
# retweeted_status_user_id                                                  NaN
# retweeted_status_timestamp                                                NaN
# expanded_urls               https://twitter.com/dog_rates/status/802265048...
# rating_numerator                                                           11
# rating_denominator                                                         10
# name                                                                     None
# doggo                                                                   doggo
# floofer                                                                  None
# pupper                                                                 pupper
# puppo                                                                    None
# nb_stage                                                                    2
#
#                                                                          575   \
# tweet_id                                                   801115127852503040
# in_reply_to_status_id                                                     NaN
# in_reply_to_user_id                                                       NaN
# timestamp                                           2016-11-22 17:28:25 +0000
# source                      <a href="http://twitter.com/download/iphone" r...
# text                        This is Bones. He's being haunted by another d...
# retweeted_status_id                                                       NaN
# retweeted_status_user_id                                                  NaN
# retweeted_status_timestamp                                                NaN
# expanded_urls               https://twitter.com/dog_rates/status/801115127...
# rating_numerator                                                           12
# rating_denominator                                                         10
# name                                                                    Bones
# doggo                                                                   doggo
# floofer                                                                  None
# pupper                                                                 pupper
# puppo                                                                    None
# nb_stage                                                                    2
#
#                                                                          705   \
# tweet_id                                                   785639753186217984
# in_reply_to_status_id                                                     NaN
# in_reply_to_user_id                                                       NaN
# timestamp                                           2016-10-11 00:34:48 +0000
# source                      <a href="http://twitter.com/download/iphone" r...
# text                        This is Pinot. He's a sophisticated doggo. You...
# retweeted_status_id                                                       NaN
# retweeted_status_user_id                                                  NaN
# retweeted_status_timestamp                                                NaN
# expanded_urls               https://twitter.com/dog_rates/status/785639753...
# rating_numerator                                                           10
# rating_denominator                                                         10
# name                                                                    Pinot
# doggo                                                                   doggo
# floofer                                                                  None
# pupper                                                                 pupper
# puppo                                                                    None
# nb_stage                                                                    2
#
#                                                                          733   \
# tweet_id                                                   781308096455073793
# in_reply_to_status_id                                                     NaN
# in_reply_to_user_id                                                       NaN
# timestamp                                           2016-09-29 01:42:20 +0000
# source                      <a href="http://vine.co" rel="nofollow">Vine -...
# text                        Pupper butt 1, Doggo 0. Both 12/10 https://t.c...
# retweeted_status_id                                                       NaN
# retweeted_status_user_id                                                  NaN
# retweeted_status_timestamp                                                NaN
# expanded_urls                                   https://vine.co/v/5rgu2Law2ut
# rating_numerator                                                           12
# rating_denominator                                                         10
# name                                                                     None
# doggo                                                                   doggo
# floofer                                                                  None
# pupper                                                                 pupper
# puppo                                                                    None
# nb_stage                                                                    2
#
#                                                                          778   \
# tweet_id                                                   775898661951791106
# in_reply_to_status_id                                                     NaN
# in_reply_to_user_id                                                       NaN
# timestamp                                           2016-09-14 03:27:11 +0000
# source                      <a href="http://twitter.com/download/iphone" r...
# text                        RT @dog_rates: Like father (doggo), like son (...
# retweeted_status_id                                      733109485275860992.0
# retweeted_status_user_id                                         4196983835.0
# retweeted_status_timestamp                          2016-05-19 01:38:16 +0000
# expanded_urls               https://twitter.com/dog_rates/status/733109485...
# rating_numerator                                                           12
# rating_denominator                                                         10
# name                                                                     None
# doggo                                                                   doggo
# floofer                                                                  None
# pupper                                                                 pupper
# puppo                                                                    None
# nb_stage                                                                    2
#
#                                                                          822   \
# tweet_id                                                   770093767776997377
# in_reply_to_status_id                                                     NaN
# in_reply_to_user_id                                                       NaN
# timestamp                                           2016-08-29 03:00:36 +0000
# source                      <a href="http://twitter.com/download/iphone" r...
# text                        RT @dog_rates: This is just downright precious...
# retweeted_status_id                                      741067306818797568.0
# retweeted_status_user_id                                         4196983835.0
# retweeted_status_timestamp                          2016-06-10 00:39:48 +0000
# expanded_urls               https://twitter.com/dog_rates/status/741067306...
# rating_numerator                                                           12
# rating_denominator                                                         10
# name                                                                     just
# doggo                                                                   doggo
# floofer                                                                  None
# pupper                                                                 pupper
# puppo                                                                    None
# nb_stage                                                                    2
#
#                                                                          889   \
# tweet_id                                                   759793422261743616
# in_reply_to_status_id                                                     NaN
# in_reply_to_user_id                                                       NaN
# timestamp                                           2016-07-31 16:50:42 +0000
# source                      <a href="http://twitter.com/download/iphone" r...
# text                        Meet Maggie &amp; Lila. Maggie is the doggo, L...
# retweeted_status_id                                                       NaN
# retweeted_status_user_id                                                  NaN
# retweeted_status_timestamp                                                NaN
# expanded_urls               https://twitter.com/dog_rates/status/759793422...
# rating_numerator                                                           12
# rating_denominator                                                         10
# name                                                                   Maggie
# doggo                                                                   doggo
# floofer                                                                  None
# pupper                                                                 pupper
# puppo                                                                    None
# nb_stage                                                                    2
#
#                                                                          956   \
# tweet_id                                                   751583847268179968
# in_reply_to_status_id                                                     NaN
# in_reply_to_user_id                                                       NaN
# timestamp                                           2016-07-09 01:08:47 +0000
# source                      <a href="http://twitter.com/download/iphone" r...
# text                        Please stop sending it pictures that don't eve...
# retweeted_status_id                                                       NaN
# retweeted_status_user_id                                                  NaN
# retweeted_status_timestamp                                                NaN
# expanded_urls               https://twitter.com/dog_rates/status/751583847...
# rating_numerator                                                            5
# rating_denominator                                                         10
# name                                                                     None
# doggo                                                                   doggo
# floofer                                                                  None
# pupper                                                                 pupper
# puppo                                                                    None
# nb_stage                                                                    2
#
#                                                                          1063  \
# tweet_id                                                   741067306818797568
# in_reply_to_status_id                                                     NaN
# in_reply_to_user_id                                                       NaN
# timestamp                                           2016-06-10 00:39:48 +0000
# source                      <a href="http://twitter.com/download/iphone" r...
# text                        This is just downright precious af. 12/10 for ...
# retweeted_status_id                                                       NaN
# retweeted_status_user_id                                                  NaN
# retweeted_status_timestamp                                                NaN
# expanded_urls               https://twitter.com/dog_rates/status/741067306...
# rating_numerator                                                           12
# rating_denominator                                                         10
# name                                                                     just
# doggo                                                                   doggo
# floofer                                                                  None
# pupper                                                                 pupper
# puppo                                                                    None
# nb_stage                                                                    2
#
#                                                                          1113
# tweet_id                                                   733109485275860992
# in_reply_to_status_id                                                     NaN
# in_reply_to_user_id                                                       NaN
# timestamp                                           2016-05-19 01:38:16 +0000
# source                      <a href="http://twitter.com/download/iphone" r...
# text                        Like father (doggo), like son (pupper). Both 1...
# retweeted_status_id                                                       NaN
# retweeted_status_user_id                                                  NaN
# retweeted_status_timestamp                                                NaN
# expanded_urls               https://twitter.com/dog_rates/status/733109485...
# rating_numerator                                                           12
# rating_denominator                                                         10
# name                                                                     None
# doggo                                                                   doggo
# floofer                                                                  None
# pupper                                                                 pupper
# puppo                                                                    None
# nb_stage                                                                    2

# %% [markdown]
# Those samples will require further assessment and manual cleaning later.

# %% [markdown]
# ### Tidiness issues
# 1. `twitter_archive_df` and `tweets_df` should form one dataframe instead being two different dataframes.
#
# 1. `twitter_archive_df` has values as columns for the stage of the dog.
#
# 1. `twitter_archive_df` has useless columns for our purpose, such as status_id, status_user_id, status_timestamp, ...
#
# 1. `tweets_df.user` should contains the id of another dataframe named `user`.
#
# 1. `twitter_archive_df` and `image_predictions_df` should form one dataframe instead being two different dataframes.

# %% [markdown]
# ### Quality issues
# 1. `twitter_archive_df['source']` has tag `a` as value instead of the value of `href` attribute
#
# 1. Wrong datatypes in `twitter_archive_df` in the following columns : `timestamp`
#
# 1. `twitter_archive_df` has retweet samples, which are useless for our purpose (according to the project instructions)
#
# 1. Null values in the following columns of `twitter_archive_df` : `in_reply_to_status_id, in_reply_to_user_id, retweeted_status_id, retweeted_status_user_id, retweeted_status_timestamp, expanded_urls`.
#
# 1. Useless columns in `tweet_df`
#
# 1. `tweets_df.created` has value beyond August 1st, 2017, which mean those sample will not have corresponding value in image_predictions_df
#
# 1. Some samples in `image_predictions_df` are not dog
#
# 1. In columns `p1`, `p2`, and `p3` of `image_predictions_df`, some values are capitalized while others are not
#
# 1. In `image_predictions_df`, only the most confident prediction is relevant
#
# 1. In `twitter_archive_df`, there are samples which have more than 1 stage

# %% [markdown]
# <a href="cleaning"> </a>
#
# ## Cleaning Data
# In this section, all issues documented while assessing will be cleaned. The cleaning order was defined according to how relevant each clean may be to the next one.

# %% [markdown]
# Made copies of original image_predictions_df. It is useless to make copy of the others dataframe since they will be merged.

# %%
# Make copies of original image_predictions_df

#tweets_clean = tweets_df.copy()
#twitter_archive_clean = twitter_archive_df.copy()
image_predictions_clean = image_predictions_df.copy()

# %% [markdown]
# ### Issue #5 (quality) : Useless columns in `tweets_df`

# %%
tweets_df.head(2).T
# Out:
#                                                                                0  \
# created_at                                        Tue Aug 01 16:23:56 +0000 2017
# id                                                            892420643555336193
# id_str                                                        892420643555336193
# full_text                      This is Phineas. He's a mystical boy. Only eve...
# truncated                                                                  False
# display_text_range                                                       [0, 85]
# entities                       {'hashtags': [], 'symbols': [], 'user_mentions...
# extended_entities              {'media': [{'id': 892420639486877696, 'id_str'...
# source                         <a href="http://twitter.com/download/iphone" r...
# in_reply_to_status_id                                                        NaN
# in_reply_to_status_id_str                                                   None
# in_reply_to_user_id                                                          NaN
# in_reply_to_user_id_str                                                     None
# in_reply_to_screen_name                                                     None
# user                           {'id': 4196983835, 'id_str': '4196983835', 'na...
# geo                                                                         None
# coordinates                                                                 None
# place                                                                       None
# contributors                                                                None
# is_quote_status                                                            False
# retweet_count                                                               8853
# favorite_count                                                             39467
# favorited                                                                  False
# retweeted                                                                  False
# possibly_sensitive                                                         False
# possibly_sensitive_appealable                                              False
# lang                                                                          en
# retweeted_status                                                             NaN
# quoted_status_id                                                             NaN
# quoted_status_id_str                                                         NaN
# quoted_status                                                                NaN
#
#                                                                                1
# created_at                                        Tue Aug 01 00:17:27 +0000 2017
# id                                                            892177421306343426
# id_str                                                        892177421306343426
# full_text                      This is Tilly. She's just checking pup on you....
# truncated                                                                  False
# display_text_range                                                      [0, 138]
# entities                       {'hashtags': [], 'symbols': [], 'user_mentions...
# extended_entities              {'media': [{'id': 892177413194625024, 'id_str'...
# source                         <a href="http://twitter.com/download/iphone" r...
# in_reply_to_status_id                                                        NaN
# in_reply_to_status_id_str                                                   None
# in_reply_to_user_id                                                          NaN
# in_reply_to_user_id_str                                                     None
# in_reply_to_screen_name                                                     None
# user                           {'id': 4196983835, 'id_str': '4196983835', 'na...
# geo                                                                         None
# coordinates                                                                 None
# place                                                                       None
# contributors                                                                None
# is_quote_status                                                            False
# retweet_count                                                               6514
# favorite_count                                                             33819
# favorited                                                                  False
# retweeted                                                                  False
# possibly_sensitive                                                         False
# possibly_sensitive_appealable                                              False
# lang                                                                          en
# retweeted_status                                                             NaN
# quoted_status_id                                                             NaN
# quoted_status_id_str                                                         NaN
# quoted_status                                                                NaN

# %% [markdown]
# #### Define
# In `tweets_df`, only keep `"id","retweet_count","favorite_count","user","retweeted"` as useful columns

# %% [markdown]
# #### Code

# %%
# Keep useful columns while discarding the others, as per the project instructions
tweets_df = tweets_df[ ["id","retweet_count","favorite_count","user","retweeted"] ]

# %% [markdown]
# #### Test

# %%
tweets_df.head(3)
# Out:
#                    id  retweet_count  favorite_count  \
# 0  892420643555336193           8853           39467
# 1  892177421306343426           6514           33819
# 2  891815181378084864           4328           25461
#
#                                                 user  retweeted
# 0  {'id': 4196983835, 'id_str': '4196983835', 'na...      False
# 1  {'id': 4196983835, 'id_str': '4196983835', 'na...      False
# 2  {'id': 4196983835, 'id_str': '4196983835', 'na...      False

# %% [markdown]
# ### Issue #10 (quality): `twitter_archive_df`, there are samples which have more than 1 stage

# %% [markdown]
# #### Define
# * Locate all samples with more than one stage.
# * Manually(visually) asses each of them and clean them according each case.
# * Drop column `twitter_archive_df["nb_stage"]` since it will no longer be useful.
#
# PS1. For the visual assessment, I will help myself with the following columns:
# * tweet_id
# * text
# * expanded_urls
#
# PS2. Since I have the project/nanodegree deadline drawing near, and that I have many samples to manually asses and clean, I will only clean the 1st one to demonstrate hability, and end the resting ones after graduating.

# %% [markdown]
# #### Code

# %%
# Retrieve tweets with more than one stage
tweets_with_many_stages = twitter_archive_df[ twitter_archive_df["nb_stage"]>1 ]
tweets_with_many_stages.shape
# Out:
# (14, 18)

# %%
tweets_with_many_stages.T
# Out:
#                                                                          191   \
# tweet_id                                                   855851453814013952
# in_reply_to_status_id                                                     NaN
# in_reply_to_user_id                                                       NaN
# timestamp                                           2017-04-22 18:31:02 +0000
# source                      <a href="http://twitter.com/download/iphone" r...
# text                        Here's a puppo participating in the #ScienceMa...
# retweeted_status_id                                                       NaN
# retweeted_status_user_id                                                  NaN
# retweeted_status_timestamp                                                NaN
# expanded_urls               https://twitter.com/dog_rates/status/855851453...
# rating_numerator                                                           13
# rating_denominator                                                         10
# name                                                                     None
# doggo                                                                   doggo
# floofer                                                                  None
# pupper                                                                   None
# puppo                                                                   puppo
# nb_stage                                                                    2
#
#                                                                          200   \
# tweet_id                                                   854010172552949760
# in_reply_to_status_id                                                     NaN
# in_reply_to_user_id                                                       NaN
# timestamp                                           2017-04-17 16:34:26 +0000
# source                      <a href="http://twitter.com/download/iphone" r...
# text                        At first I thought this was a shy doggo, but i...
# retweeted_status_id                                                       NaN
# retweeted_status_user_id                                                  NaN
# retweeted_status_timestamp                                                NaN
# expanded_urls               https://twitter.com/dog_rates/status/854010172...
# rating_numerator                                                           11
# rating_denominator                                                         10
# name                                                                     None
# doggo                                                                   doggo
# floofer                                                               floofer
# pupper                                                                   None
# puppo                                                                    None
# nb_stage                                                                    2
#
#                                                                          460   \
# tweet_id                                                   817777686764523521
# in_reply_to_status_id                                                     NaN
# in_reply_to_user_id                                                       NaN
# timestamp                                           2017-01-07 16:59:28 +0000
# source                      <a href="http://twitter.com/download/iphone" r...
# text                        This is Dido. She's playing the lead role in "...
# retweeted_status_id                                                       NaN
# retweeted_status_user_id                                                  NaN
# retweeted_status_timestamp                                                NaN
# expanded_urls               https://twitter.com/dog_rates/status/817777686...
# rating_numerator                                                           13
# rating_denominator                                                         10
# name                                                                     Dido
# doggo                                                                   doggo
# floofer                                                                  None
# pupper                                                                 pupper
# puppo                                                                    None
# nb_stage                                                                    2
#
#                                                                          531   \
# tweet_id                                                   808106460588765185
# in_reply_to_status_id                                                     NaN
# in_reply_to_user_id                                                       NaN
# timestamp                                           2016-12-12 00:29:28 +0000
# source                      <a href="http://twitter.com/download/iphone" r...
# text                        Here we have Burke (pupper) and Dexter (doggo)...
# retweeted_status_id                                                       NaN
# retweeted_status_user_id                                                  NaN
# retweeted_status_timestamp                                                NaN
# expanded_urls               https://twitter.com/dog_rates/status/808106460...
# rating_numerator                                                           12
# rating_denominator                                                         10
# name                                                                     None
# doggo                                                                   doggo
# floofer                                                                  None
# pupper                                                                 pupper
# puppo                                                                    None
# nb_stage                                                                    2
#
#                                                                          565   \
# tweet_id                                                   802265048156610565
# in_reply_to_status_id                                    733109485275860992.0
# in_reply_to_user_id                                              4196983835.0
# timestamp                                           2016-11-25 21:37:47 +0000
# source                      <a href="http://twitter.com/download/iphone" r...
# text                        Like doggo, like pupper version 2. Both 11/10 ...
# retweeted_status_id                                                       NaN
# retweeted_status_user_id                                                  NaN
# retweeted_status_timestamp                                                NaN
# expanded_urls               https://twitter.com/dog_rates/status/802265048...
# rating_numerator                                                           11
# rating_denominator                                                         10
# name                                                                     None
# doggo                                                                   doggo
# floofer                                                                  None
# pupper                                                                 pupper
# puppo                                                                    None
# nb_stage                                                                    2
#
#                                                                          575   \
# tweet_id                                                   801115127852503040
# in_reply_to_status_id                                                     NaN
# in_reply_to_user_id                                                       NaN
# timestamp                                           2016-11-22 17:28:25 +0000
# source                      <a href="http://twitter.com/download/iphone" r...
# text                        This is Bones. He's being haunted by another d...
# retweeted_status_id                                                       NaN
# retweeted_status_user_id                                                  NaN
# retweeted_status_timestamp                                                NaN
# expanded_urls               https://twitter.com/dog_rates/status/801115127...
# rating_numerator                                                           12
# rating_denominator                                                         10
# name                                                                    Bones
# doggo                                                                   doggo
# floofer                                                                  None
# pupper                                                                 pupper
# puppo                                                                    None
# nb_stage                                                                    2
#
#                                                                          705   \
# tweet_id                                                   785639753186217984
# in_reply_to_status_id                                                     NaN
# in_reply_to_user_id                                                       NaN
# timestamp                                           2016-10-11 00:34:48 +0000
# source                      <a href="http://twitter.com/download/iphone" r...
# text                        This is Pinot. He's a sophisticated doggo. You...
# retweeted_status_id                                                       NaN
# retweeted_status_user_id                                                  NaN
# retweeted_status_timestamp                                                NaN
# expanded_urls               https://twitter.com/dog_rates/status/785639753...
# rating_numerator                                                           10
# rating_denominator                                                         10
# name                                                                    Pinot
# doggo                                                                   doggo
# floofer                                                                  None
# pupper                                                                 pupper
# puppo                                                                    None
# nb_stage                                                                    2
#
#                                                                          733   \
# tweet_id                                                   781308096455073793
# in_reply_to_status_id                                                     NaN
# in_reply_to_user_id                                                       NaN
# timestamp                                           2016-09-29 01:42:20 +0000
# source                      <a href="http://vine.co" rel="nofollow">Vine -...
# text                        Pupper butt 1, Doggo 0. Both 12/10 https://t.c...
# retweeted_status_id                                                       NaN
# retweeted_status_user_id                                                  NaN
# retweeted_status_timestamp                                                NaN
# expanded_urls                                   https://vine.co/v/5rgu2Law2ut
# rating_numerator                                                           12
# rating_denominator                                                         10
# name                                                                     None
# doggo                                                                   doggo
# floofer                                                                  None
# pupper                                                                 pupper
# puppo                                                                    None
# nb_stage                                                                    2
#
#                                                                          778   \
# tweet_id                                                   775898661951791106
# in_reply_to_status_id                                                     NaN
# in_reply_to_user_id                                                       NaN
# timestamp                                           2016-09-14 03:27:11 +0000
# source                      <a href="http://twitter.com/download/iphone" r...
# text                        RT @dog_rates: Like father (doggo), like son (...
# retweeted_status_id                                      733109485275860992.0
# retweeted_status_user_id                                         4196983835.0
# retweeted_status_timestamp                          2016-05-19 01:38:16 +0000
# expanded_urls               https://twitter.com/dog_rates/status/733109485...
# rating_numerator                                                           12
# rating_denominator                                                         10
# name                                                                     None
# doggo                                                                   doggo
# floofer                                                                  None
# pupper                                                                 pupper
# puppo                                                                    None
# nb_stage                                                                    2
#
#                                                                          822   \
# tweet_id                                                   770093767776997377
# in_reply_to_status_id                                                     NaN
# in_reply_to_user_id                                                       NaN
# timestamp                                           2016-08-29 03:00:36 +0000
# source                      <a href="http://twitter.com/download/iphone" r...
# text                        RT @dog_rates: This is just downright precious...
# retweeted_status_id                                      741067306818797568.0
# retweeted_status_user_id                                         4196983835.0
# retweeted_status_timestamp                          2016-06-10 00:39:48 +0000
# expanded_urls               https://twitter.com/dog_rates/status/741067306...
# rating_numerator                                                           12
# rating_denominator                                                         10
# name                                                                     just
# doggo                                                                   doggo
# floofer                                                                  None
# pupper                                                                 pupper
# puppo                                                                    None
# nb_stage                                                                    2
#
#                                                                          889   \
# tweet_id                                                   759793422261743616
# in_reply_to_status_id                                                     NaN
# in_reply_to_user_id                                                       NaN
# timestamp                                           2016-07-31 16:50:42 +0000
# source                      <a href="http://twitter.com/download/iphone" r...
# text                        Meet Maggie &amp; Lila. Maggie is the doggo, L...
# retweeted_status_id                                                       NaN
# retweeted_status_user_id                                                  NaN
# retweeted_status_timestamp                                                NaN
# expanded_urls               https://twitter.com/dog_rates/status/759793422...
# rating_numerator                                                           12
# rating_denominator                                                         10
# name                                                                   Maggie
# doggo                                                                   doggo
# floofer                                                                  None
# pupper                                                                 pupper
# puppo                                                                    None
# nb_stage                                                                    2
#
#                                                                          956   \
# tweet_id                                                   751583847268179968
# in_reply_to_status_id                                                     NaN
# in_reply_to_user_id                                                       NaN
# timestamp                                           2016-07-09 01:08:47 +0000
# source                      <a href="http://twitter.com/download/iphone" r...
# text                        Please stop sending it pictures that don't eve...
# retweeted_status_id                                                       NaN
# retweeted_status_user_id                                                  NaN
# retweeted_status_timestamp                                                NaN
# expanded_urls               https://twitter.com/dog_rates/status/751583847...
# rating_numerator                                                            5
# rating_denominator                                                         10
# name                                                                     None
# doggo                                                                   doggo
# floofer                                                                  None
# pupper                                                                 pupper
# puppo                                                                    None
# nb_stage                                                                    2
#
#                                                                          1063  \
# tweet_id                                                   741067306818797568
# in_reply_to_status_id                                                     NaN
# in_reply_to_user_id                                                       NaN
# timestamp                                           2016-06-10 00:39:48 +0000
# source                      <a href="http://twitter.com/download/iphone" r...
# text                        This is just downright precious af. 12/10 for ...
# retweeted_status_id                                                       NaN
# retweeted_status_user_id                                                  NaN
# retweeted_status_timestamp                                                NaN
# expanded_urls               https://twitter.com/dog_rates/status/741067306...
# rating_numerator                                                           12
# rating_denominator                                                         10
# name                                                                     just
# doggo                                                                   doggo
# floofer                                                                  None
# pupper                                                                 pupper
# puppo                                                                    None
# nb_stage                                                                    2
#
#                                                                          1113
# tweet_id                                                   733109485275860992
# in_reply_to_status_id                                                     NaN
# in_reply_to_user_id                                                       NaN
# timestamp                                           2016-05-19 01:38:16 +0000
# source                      <a href="http://twitter.com/download/iphone" r...
# text                        Like father (doggo), like son (pupper). Both 1...
# retweeted_status_id                                                       NaN
# retweeted_status_user_id                                                  NaN
# retweeted_status_timestamp                                                NaN
# expanded_urls               https://twitter.com/dog_rates/status/733109485...
# rating_numerator                                                           12
# rating_denominator                                                         10
# name                                                                     None
# doggo                                                                   doggo
# floofer                                                                  None
# pupper                                                                 pupper
# puppo                                                                    None
# nb_stage                                                                    2

# %% [markdown]
# ##### Assessing tweet having id : 855851453814013952

# %%
# targeted_tweet_id = 854010172552949000
# twitter_archive_df[ twitter_archive_df["tweet_id"]==targeted_tweet_id ]

# %%
targeted_tweet_id = 855851453814013952
targeted_tweet = tweets_with_many_stages[ tweets_with_many_stages["tweet_id"]==targeted_tweet_id ]

targeted_tweet
# Out:
#                tweet_id  in_reply_to_status_id  in_reply_to_user_id  \
# 191  855851453814013952                    NaN                  NaN
#
#                      timestamp  \
# 191  2017-04-22 18:31:02 +0000
#
#                                                 source  \
# 191  <a href="http://twitter.com/download/iphone" r...
#
#                                                   text  retweeted_status_id  \
# 191  Here's a puppo participating in the #ScienceMa...                  NaN
#
#      retweeted_status_user_id retweeted_status_timestamp  \
# 191                       NaN                        NaN
#
#                                          expanded_urls  rating_numerator  \
# 191  https://twitter.com/dog_rates/status/855851453...                13
#
#      rating_denominator  name  doggo floofer pupper  puppo  nb_stage
# 191                  10  None  doggo    None   None  puppo         2

# %%
targeted_tweet_index = targeted_tweet.index[0]
targeted_tweet_index
# Out:
# 191

# %%
targeted_tweet.loc[targeted_tweet_index,"text"]
# Out:
# "Here's a puppo participating in the #ScienceMarch. Cleverly disguising her own doggo agenda. 13/10 would keep the planet habitable for https://t.co/cMhq16isel"

# %% [markdown]
# This dog is clearly is a puppo, not a doggo. We will consequently update `twitter_archive_df`

# %%
# Confirming that we are targeting the good sample
twitter_archive_df.loc[[targeted_tweet_index],:]
# Out:
#                tweet_id  in_reply_to_status_id  in_reply_to_user_id  \
# 191  855851453814013952                    NaN                  NaN
#
#                      timestamp  \
# 191  2017-04-22 18:31:02 +0000
#
#                                                 source  \
# 191  <a href="http://twitter.com/download/iphone" r...
#
#                                                   text  retweeted_status_id  \
# 191  Here's a puppo participating in the #ScienceMa...                  NaN
#
#      retweeted_status_user_id retweeted_status_timestamp  \
# 191                       NaN                        NaN
#
#                                          expanded_urls  rating_numerator  \
# 191  https://twitter.com/dog_rates/status/855851453...                13
#
#      rating_denominator  name  doggo floofer pupper  puppo  nb_stage
# 191                  10  None  doggo    None   None  puppo         2

# %%
# Update the targeted sample
twitter_archive_df.loc[targeted_tweet_index,"doggo"] = "None"
twitter_archive_df.loc[targeted_tweet_index,"nb_stage"] = 1


# Confirming that update was effective
twitter_archive_df.loc[[targeted_tweet_index],:]
# Out:
#                tweet_id  in_reply_to_status_id  in_reply_to_user_id  \
# 191  855851453814013952                    NaN                  NaN
#
#                      timestamp  \
# 191  2017-04-22 18:31:02 +0000
#
#                                                 source  \
# 191  <a href="http://twitter.com/download/iphone" r...
#
#                                                   text  retweeted_status_id  \
# 191  Here's a puppo participating in the #ScienceMa...                  NaN
#
#      retweeted_status_user_id retweeted_status_timestamp  \
# 191                       NaN                        NaN
#
#                                          expanded_urls  rating_numerator  \
# 191  https://twitter.com/dog_rates/status/855851453...                13
#
#      rating_denominator  name doggo floofer pupper  puppo  nb_stage
# 191                  10  None  None    None   None  puppo         1

# %% [markdown]
# ##### Assessing tweet having id : 854010172552949760
#
# TODO : finish this assessment after validating my project (since I have a deadline drawing near)

# %% [markdown]
# ### Test

# %% [markdown]
# ### Issue #1 (tidiness): `twitter_archive_df` and `tweets_df` should form one dataframe instead being two different dataframes.

# %%
twitter_archive_df.head(2).T
# Out:
#                                                                             0  \
# tweet_id                                                   892420643555336193
# in_reply_to_status_id                                                     NaN
# in_reply_to_user_id                                                       NaN
# timestamp                                           2017-08-01 16:23:56 +0000
# source                      <a href="http://twitter.com/download/iphone" r...
# text                        This is Phineas. He's a mystical boy. Only eve...
# retweeted_status_id                                                       NaN
# retweeted_status_user_id                                                  NaN
# retweeted_status_timestamp                                                NaN
# expanded_urls               https://twitter.com/dog_rates/status/892420643...
# rating_numerator                                                           13
# rating_denominator                                                         10
# name                                                                  Phineas
# doggo                                                                    None
# floofer                                                                  None
# pupper                                                                   None
# puppo                                                                    None
# nb_stage                                                                    0
#
#                                                                             1
# tweet_id                                                   892177421306343426
# in_reply_to_status_id                                                     NaN
# in_reply_to_user_id                                                       NaN
# timestamp                                           2017-08-01 00:17:27 +0000
# source                      <a href="http://twitter.com/download/iphone" r...
# text                        This is Tilly. She's just checking pup on you....
# retweeted_status_id                                                       NaN
# retweeted_status_user_id                                                  NaN
# retweeted_status_timestamp                                                NaN
# expanded_urls               https://twitter.com/dog_rates/status/892177421...
# rating_numerator                                                           13
# rating_denominator                                                         10
# name                                                                    Tilly
# doggo                                                                    None
# floofer                                                                  None
# pupper                                                                   None
# puppo                                                                    None
# nb_stage                                                                    0

# %%
twitter_archive_df.shape
# Out:
# (2356, 18)

# %%
tweets_df.head()
# Out:
#                    id  retweet_count  favorite_count  \
# 0  892420643555336193           8853           39467
# 1  892177421306343426           6514           33819
# 2  891815181378084864           4328           25461
# 3  891689557279858688           8964           42908
# 4  891327558926688256           9774           41048
#
#                                                 user  retweeted
# 0  {'id': 4196983835, 'id_str': '4196983835', 'na...      False
# 1  {'id': 4196983835, 'id_str': '4196983835', 'na...      False
# 2  {'id': 4196983835, 'id_str': '4196983835', 'na...      False
# 3  {'id': 4196983835, 'id_str': '4196983835', 'na...      False
# 4  {'id': 4196983835, 'id_str': '4196983835', 'na...      False

# %%
tweets_df.shape
# Out:
# (2354, 5)

# %% [markdown]
# #### Define
# Merge `twitter_archive_df` and `tweets_df` in one dataframe

# %% [markdown]
# #### Code

# %%
# All columns in the two datasets
# all_columns = pd.Series(list(twitter_archive_clean) + list(tweets_clean) )
# all_columns

# %%
# Find duplicated columns
# duplicated_columns = all_columns[all_columns.duplicated()]
# duplicated_columns

# %%
# Drop duplicated columns from tweets_clean
# tweets_clean.drop(duplicated_columns, axis=1, inplace=True)
# tweets_clean.head(2).T

# %%
# tweets_clean.shape

# %%
# Merging the two dataset

# https://stackoverflow.com/questions/43297589/merge-two-data-frames-based-on-common-column-values-in-pandas
twitter_df = twitter_archive_df.merge(tweets_df, how="inner",left_on="tweet_id", right_on="id")
twitter_df.shape
# Out:
# (2354, 23)

# %% [markdown]
# #### Test

# %%
twitter_df.head(2).T
# Out:
#                                                                             0  \
# tweet_id                                                   892420643555336193
# in_reply_to_status_id                                                     NaN
# in_reply_to_user_id                                                       NaN
# timestamp                                           2017-08-01 16:23:56 +0000
# source                      <a href="http://twitter.com/download/iphone" r...
# text                        This is Phineas. He's a mystical boy. Only eve...
# retweeted_status_id                                                       NaN
# retweeted_status_user_id                                                  NaN
# retweeted_status_timestamp                                                NaN
# expanded_urls               https://twitter.com/dog_rates/status/892420643...
# rating_numerator                                                           13
# rating_denominator                                                         10
# name                                                                  Phineas
# doggo                                                                    None
# floofer                                                                  None
# pupper                                                                   None
# puppo                                                                    None
# nb_stage                                                                    0
# id                                                         892420643555336193
# retweet_count                                                            8853
# favorite_count                                                          39467
# user                        {'id': 4196983835, 'id_str': '4196983835', 'na...
# retweeted                                                               False
#
#                                                                             1
# tweet_id                                                   892177421306343426
# in_reply_to_status_id                                                     NaN
# in_reply_to_user_id                                                       NaN
# timestamp                                           2017-08-01 00:17:27 +0000
# source                      <a href="http://twitter.com/download/iphone" r...
# text                        This is Tilly. She's just checking pup on you....
# retweeted_status_id                                                       NaN
# retweeted_status_user_id                                                  NaN
# retweeted_status_timestamp                                                NaN
# expanded_urls               https://twitter.com/dog_rates/status/892177421...
# rating_numerator                                                           13
# rating_denominator                                                         10
# name                                                                    Tilly
# doggo                                                                    None
# floofer                                                                  None
# pupper                                                                   None
# puppo                                                                    None
# nb_stage                                                                    0
# id                                                         892177421306343426
# retweet_count                                                            6514
# favorite_count                                                          33819
# user                        {'id': 4196983835, 'id_str': '4196983835', 'na...
# retweeted                                                               False

# %%
# Making sure the merge worked fine
twitter_df.shape[1] == twitter_archive_df.shape[1] + tweets_df.shape[1]
# Out:
# True

# %%
# Dropping redundant id column
twitter_df.drop(["id"],axis=1, inplace=True)
twitter_df.head(2).T
# Out:
#                                                                             0  \
# tweet_id                                                   892420643555336193
# in_reply_to_status_id                                                     NaN
# in_reply_to_user_id                                                       NaN
# timestamp                                           2017-08-01 16:23:56 +0000
# source                      <a href="http://twitter.com/download/iphone" r...
# text                        This is Phineas. He's a mystical boy. Only eve...
# retweeted_status_id                                                       NaN
# retweeted_status_user_id                                                  NaN
# retweeted_status_timestamp                                                NaN
# expanded_urls               https://twitter.com/dog_rates/status/892420643...
# rating_numerator                                                           13
# rating_denominator                                                         10
# name                                                                  Phineas
# doggo                                                                    None
# floofer                                                                  None
# pupper                                                                   None
# puppo                                                                    None
# nb_stage                                                                    0
# retweet_count                                                            8853
# favorite_count                                                          39467
# user                        {'id': 4196983835, 'id_str': '4196983835', 'na...
# retweeted                                                               False
#
#                                                                             1
# tweet_id                                                   892177421306343426
# in_reply_to_status_id                                                     NaN
# in_reply_to_user_id                                                       NaN
# timestamp                                           2017-08-01 00:17:27 +0000
# source                      <a href="http://twitter.com/download/iphone" r...
# text                        This is Tilly. She's just checking pup on you....
# retweeted_status_id                                                       NaN
# retweeted_status_user_id                                                  NaN
# retweeted_status_timestamp                                                NaN
# expanded_urls               https://twitter.com/dog_rates/status/892177421...
# rating_numerator                                                           13
# rating_denominator                                                         10
# name                                                                    Tilly
# doggo                                                                    None
# floofer                                                                  None
# pupper                                                                   None
# puppo                                                                    None
# nb_stage                                                                    0
# retweet_count                                                            6514
# favorite_count                                                          33819
# user                        {'id': 4196983835, 'id_str': '4196983835', 'na...
# retweeted                                                               False

# %% [markdown]
# ### Issue #2 (tidiness): `twitter_archive_df` has values as columns for the stage of the dog.
# Those columns are `doggo, floofer, pupper, puppo`

# %%
twitter_df.head(3).T
# Out:
#                                                                             0  \
# tweet_id                                                   892420643555336193
# in_reply_to_status_id                                                     NaN
# in_reply_to_user_id                                                       NaN
# timestamp                                           2017-08-01 16:23:56 +0000
# source                      <a href="http://twitter.com/download/iphone" r...
# text                        This is Phineas. He's a mystical boy. Only eve...
# retweeted_status_id                                                       NaN
# retweeted_status_user_id                                                  NaN
# retweeted_status_timestamp                                                NaN
# expanded_urls               https://twitter.com/dog_rates/status/892420643...
# rating_numerator                                                           13
# rating_denominator                                                         10
# name                                                                  Phineas
# doggo                                                                    None
# floofer                                                                  None
# pupper                                                                   None
# puppo                                                                    None
# nb_stage                                                                    0
# retweet_count                                                            8853
# favorite_count                                                          39467
# user                        {'id': 4196983835, 'id_str': '4196983835', 'na...
# retweeted                                                               False
#
#                                                                             1  \
# tweet_id                                                   892177421306343426
# in_reply_to_status_id                                                     NaN
# in_reply_to_user_id                                                       NaN
# timestamp                                           2017-08-01 00:17:27 +0000
# source                      <a href="http://twitter.com/download/iphone" r...
# text                        This is Tilly. She's just checking pup on you....
# retweeted_status_id                                                       NaN
# retweeted_status_user_id                                                  NaN
# retweeted_status_timestamp                                                NaN
# expanded_urls               https://twitter.com/dog_rates/status/892177421...
# rating_numerator                                                           13
# rating_denominator                                                         10
# name                                                                    Tilly
# doggo                                                                    None
# floofer                                                                  None
# pupper                                                                   None
# puppo                                                                    None
# nb_stage                                                                    0
# retweet_count                                                            6514
# favorite_count                                                          33819
# user                        {'id': 4196983835, 'id_str': '4196983835', 'na...
# retweeted                                                               False
#
#                                                                             2
# tweet_id                                                   891815181378084864
# in_reply_to_status_id                                                     NaN
# in_reply_to_user_id                                                       NaN
# timestamp                                           2017-07-31 00:18:03 +0000
# source                      <a href="http://twitter.com/download/iphone" r...
# text                        This is Archie. He is a rare Norwegian Pouncin...
# retweeted_status_id                                                       NaN
# retweeted_status_user_id                                                  NaN
# retweeted_status_timestamp                                                NaN
# expanded_urls               https://twitter.com/dog_rates/status/891815181...
# rating_numerator                                                           12
# rating_denominator                                                         10
# name                                                                   Archie
# doggo                                                                    None
# floofer                                                                  None
# pupper                                                                   None
# puppo                                                                    None
# nb_stage                                                                    0
# retweet_count                                                            4328
# favorite_count                                                          25461
# user                        {'id': 4196983835, 'id_str': '4196983835', 'na...
# retweeted                                                               False

# %% [markdown]
# #### Define
# Melt the dog stage columns into a column which name will be `stage` and which value will be the stage of the dog or NaN depending on weither the stage is known or not.

# %% [markdown]
# #### Code

# %%
id_vars = twitter_df.columns.tolist()
id_vars.remove("doggo")
id_vars.remove("floofer")
id_vars.remove("pupper")
id_vars.remove("puppo")
id_vars
# Out:
# ['tweet_id',
#  'in_reply_to_status_id',
#  'in_reply_to_user_id',
#  'timestamp',
#  'source',
#  'text',
#  'retweeted_status_id',
#  'retweeted_status_user_id',
#  'retweeted_status_timestamp',
#  'expanded_urls',
#  'rating_numerator',
#  'rating_denominator',
#  'name',
#  'nb_stage',
#  'retweet_count',
#  'favorite_count',
#  'user',
#  'retweeted']

# %%
melted = pd.melt(twitter_df, id_vars=id_vars, var_name="stage", value_name="stage_value")
melted.head(3).T
# Out:
#                                                                             0  \
# tweet_id                                                   892420643555336193
# in_reply_to_status_id                                                     NaN
# in_reply_to_user_id                                                       NaN
# timestamp                                           2017-08-01 16:23:56 +0000
# source                      <a href="http://twitter.com/download/iphone" r...
# text                        This is Phineas. He's a mystical boy. Only eve...
# retweeted_status_id                                                       NaN
# retweeted_status_user_id                                                  NaN
# retweeted_status_timestamp                                                NaN
# expanded_urls               https://twitter.com/dog_rates/status/892420643...
# rating_numerator                                                           13
# rating_denominator                                                         10
# name                                                                  Phineas
# nb_stage                                                                    0
# retweet_count                                                            8853
# favorite_count                                                          39467
# user                        {'id': 4196983835, 'id_str': '4196983835', 'na...
# retweeted                                                               False
# stage                                                                   doggo
# stage_value                                                              None
#
#                                                                             1  \
# tweet_id                                                   892177421306343426
# in_reply_to_status_id                                                     NaN
# in_reply_to_user_id                                                       NaN
# timestamp                                           2017-08-01 00:17:27 +0000
# source                      <a href="http://twitter.com/download/iphone" r...
# text                        This is Tilly. She's just checking pup on you....
# retweeted_status_id                                                       NaN
# retweeted_status_user_id                                                  NaN
# retweeted_status_timestamp                                                NaN
# expanded_urls               https://twitter.com/dog_rates/status/892177421...
# rating_numerator                                                           13
# rating_denominator                                                         10
# name                                                                    Tilly
# nb_stage                                                                    0
# retweet_count                                                            6514
# favorite_count                                                          33819
# user                        {'id': 4196983835, 'id_str': '4196983835', 'na...
# retweeted                                                               False
# stage                                                                   doggo
# stage_value                                                              None
#
#                                                                             2
# tweet_id                                                   891815181378084864
# in_reply_to_status_id                                                     NaN
# in_reply_to_user_id                                                       NaN
# timestamp                                           2017-07-31 00:18:03 +0000
# source                      <a href="http://twitter.com/download/iphone" r...
# text                        This is Archie. He is a rare Norwegian Pouncin...
# retweeted_status_id                                                       NaN
# retweeted_status_user_id                                                  NaN
# retweeted_status_timestamp                                                NaN
# expanded_urls               https://twitter.com/dog_rates/status/891815181...
# rating_numerator                                                           12
# rating_denominator                                                         10
# name                                                                   Archie
# nb_stage                                                                    0
# retweet_count                                                            4328
# favorite_count                                                          25461
# user                        {'id': 4196983835, 'id_str': '4196983835', 'na...
# retweeted                                                               False
# stage                                                                   doggo
# stage_value                                                              None

# %% [markdown]
# Looking at our dataframe, we don't need the `stage_value` column, so will drop it in a while after performing some tidiness cleaning.

# %%
melted.shape
# Out:
# (9416, 20)

# %%
# twitter_df.shape

# %% [markdown]
# **Analyzing the content of `melted` based on weither the stage of the dog is known or not**

# %%
# Visual assessement of the tweet which id is 892420643555336193 (this tweet dog stage is unknow)
melted[ melted["tweet_id"]==892420643555336193 ].T
# Out:
#                                                                          0     \
# tweet_id                                                   892420643555336193
# in_reply_to_status_id                                                     NaN
# in_reply_to_user_id                                                       NaN
# timestamp                                           2017-08-01 16:23:56 +0000
# source                      <a href="http://twitter.com/download/iphone" r...
# text                        This is Phineas. He's a mystical boy. Only eve...
# retweeted_status_id                                                       NaN
# retweeted_status_user_id                                                  NaN
# retweeted_status_timestamp                                                NaN
# expanded_urls               https://twitter.com/dog_rates/status/892420643...
# rating_numerator                                                           13
# rating_denominator                                                         10
# name                                                                  Phineas
# nb_stage                                                                    0
# retweet_count                                                            8853
# favorite_count                                                          39467
# user                        {'id': 4196983835, 'id_str': '4196983835', 'na...
# retweeted                                                               False
# stage                                                                   doggo
# stage_value                                                              None
#
#                                                                          2354  \
# tweet_id                                                   892420643555336193
# in_reply_to_status_id                                                     NaN
# in_reply_to_user_id                                                       NaN
# timestamp                                           2017-08-01 16:23:56 +0000
# source                      <a href="http://twitter.com/download/iphone" r...
# text                        This is Phineas. He's a mystical boy. Only eve...
# retweeted_status_id                                                       NaN
# retweeted_status_user_id                                                  NaN
# retweeted_status_timestamp                                                NaN
# expanded_urls               https://twitter.com/dog_rates/status/892420643...
# rating_numerator                                                           13
# rating_denominator                                                         10
# name                                                                  Phineas
# nb_stage                                                                    0
# retweet_count                                                            8853
# favorite_count                                                          39467
# user                        {'id': 4196983835, 'id_str': '4196983835', 'na...
# retweeted                                                               False
# stage                                                                 floofer
# stage_value                                                              None
#
#                                                                          4708  \
# tweet_id                                                   892420643555336193
# in_reply_to_status_id                                                     NaN
# in_reply_to_user_id                                                       NaN
# timestamp                                           2017-08-01 16:23:56 +0000
# source                      <a href="http://twitter.com/download/iphone" r...
# text                        This is Phineas. He's a mystical boy. Only eve...
# retweeted_status_id                                                       NaN
# retweeted_status_user_id                                                  NaN
# retweeted_status_timestamp                                                NaN
# expanded_urls               https://twitter.com/dog_rates/status/892420643...
# rating_numerator                                                           13
# rating_denominator                                                         10
# name                                                                  Phineas
# nb_stage                                                                    0
# retweet_count                                                            8853
# favorite_count                                                          39467
# user                        {'id': 4196983835, 'id_str': '4196983835', 'na...
# retweeted                                                               False
# stage                                                                  pupper
# stage_value                                                              None
#
#                                                                          7062
# tweet_id                                                   892420643555336193
# in_reply_to_status_id                                                     NaN
# in_reply_to_user_id                                                       NaN
# timestamp                                           2017-08-01 16:23:56 +0000
# source                      <a href="http://twitter.com/download/iphone" r...
# text                        This is Phineas. He's a mystical boy. Only eve...
# retweeted_status_id                                                       NaN
# retweeted_status_user_id                                                  NaN
# retweeted_status_timestamp                                                NaN
# expanded_urls               https://twitter.com/dog_rates/status/892420643...
# rating_numerator                                                           13
# rating_denominator                                                         10
# name                                                                  Phineas
# nb_stage                                                                    0
# retweet_count                                                            8853
# favorite_count                                                          39467
# user                        {'id': 4196983835, 'id_str': '4196983835', 'na...
# retweeted                                                               False
# stage                                                                   puppo
# stage_value                                                              None

# %% [markdown]
# We have 04 entries for the same tweet_id, each corresponding to one of the 04 melted columns.

# %% [markdown]
# Let's separate `melted` in two different dataframes for a better observation

# %%
# Retrieve the tweets with known dog stage
tweets_with_stage_df = melted[ melted["stage_value"] !="None" ]
tweets_with_stage_df.head(3).T
# Out:
#                                                                            9   \
# tweet_id                                                   890240255349198849
# in_reply_to_status_id                                                     NaN
# in_reply_to_user_id                                                       NaN
# timestamp                                           2017-07-26 15:59:51 +0000
# source                      <a href="http://twitter.com/download/iphone" r...
# text                        This is Cassie. She is a college pup. Studying...
# retweeted_status_id                                                       NaN
# retweeted_status_user_id                                                  NaN
# retweeted_status_timestamp                                                NaN
# expanded_urls               https://twitter.com/dog_rates/status/890240255...
# rating_numerator                                                           14
# rating_denominator                                                         10
# name                                                                   Cassie
# nb_stage                                                                    1
# retweet_count                                                            7711
# favorite_count                                                          32467
# user                        {'id': 4196983835, 'id_str': '4196983835', 'na...
# retweeted                                                               False
# stage                                                                   doggo
# stage_value                                                             doggo
#
#                                                                            42  \
# tweet_id                                                   884162670584377345
# in_reply_to_status_id                                                     NaN
# in_reply_to_user_id                                                       NaN
# timestamp                                           2017-07-09 21:29:42 +0000
# source                      <a href="http://twitter.com/download/iphone" r...
# text                        Meet Yogi. He doesn't have any important dog m...
# retweeted_status_id                                                       NaN
# retweeted_status_user_id                                                  NaN
# retweeted_status_timestamp                                                NaN
# expanded_urls               https://twitter.com/dog_rates/status/884162670...
# rating_numerator                                                           12
# rating_denominator                                                         10
# name                                                                     Yogi
# nb_stage                                                                    1
# retweet_count                                                            3128
# favorite_count                                                          20771
# user                        {'id': 4196983835, 'id_str': '4196983835', 'na...
# retweeted                                                               False
# stage                                                                   doggo
# stage_value                                                             doggo
#
#                                                                            98
# tweet_id                                                   872967104147763200
# in_reply_to_status_id                                                     NaN
# in_reply_to_user_id                                                       NaN
# timestamp                                           2017-06-09 00:02:31 +0000
# source                      <a href="http://twitter.com/download/iphone" r...
# text                        Here's a very large dog. He has a date later. ...
# retweeted_status_id                                                       NaN
# retweeted_status_user_id                                                  NaN
# retweeted_status_timestamp                                                NaN
# expanded_urls               https://twitter.com/dog_rates/status/872967104...
# rating_numerator                                                           12
# rating_denominator                                                         10
# name                                                                     None
# nb_stage                                                                    1
# retweet_count                                                            5669
# favorite_count                                                          28031
# user                        {'id': 4196983835, 'id_str': '4196983835', 'na...
# retweeted                                                               False
# stage                                                                   doggo
# stage_value                                                             doggo

# %%
# Visual assessement of a tweet with known dog stage
tweets_with_stage_df[ tweets_with_stage_df["tweet_id"]==890240255349198849 ].T
# Out:
#                                                                             9
# tweet_id                                                   890240255349198849
# in_reply_to_status_id                                                     NaN
# in_reply_to_user_id                                                       NaN
# timestamp                                           2017-07-26 15:59:51 +0000
# source                      <a href="http://twitter.com/download/iphone" r...
# text                        This is Cassie. She is a college pup. Studying...
# retweeted_status_id                                                       NaN
# retweeted_status_user_id                                                  NaN
# retweeted_status_timestamp                                                NaN
# expanded_urls               https://twitter.com/dog_rates/status/890240255...
# rating_numerator                                                           14
# rating_denominator                                                         10
# name                                                                   Cassie
# nb_stage                                                                    1
# retweet_count                                                            7711
# favorite_count                                                          32467
# user                        {'id': 4196983835, 'id_str': '4196983835', 'na...
# retweeted                                                               False
# stage                                                                   doggo
# stage_value                                                             doggo

# %% [markdown]
# We can confirm that there is only one entry for the tweets when dog stage is known.

# %%
# Retrieve the tweets with unknown dog stage
tweets_without_stage_df = melted[ melted["stage_value"] =="None" ]
tweets_without_stage_df.head(3).T
# Out:
#                                                                             0  \
# tweet_id                                                   892420643555336193
# in_reply_to_status_id                                                     NaN
# in_reply_to_user_id                                                       NaN
# timestamp                                           2017-08-01 16:23:56 +0000
# source                      <a href="http://twitter.com/download/iphone" r...
# text                        This is Phineas. He's a mystical boy. Only eve...
# retweeted_status_id                                                       NaN
# retweeted_status_user_id                                                  NaN
# retweeted_status_timestamp                                                NaN
# expanded_urls               https://twitter.com/dog_rates/status/892420643...
# rating_numerator                                                           13
# rating_denominator                                                         10
# name                                                                  Phineas
# nb_stage                                                                    0
# retweet_count                                                            8853
# favorite_count                                                          39467
# user                        {'id': 4196983835, 'id_str': '4196983835', 'na...
# retweeted                                                               False
# stage                                                                   doggo
# stage_value                                                              None
#
#                                                                             1  \
# tweet_id                                                   892177421306343426
# in_reply_to_status_id                                                     NaN
# in_reply_to_user_id                                                       NaN
# timestamp                                           2017-08-01 00:17:27 +0000
# source                      <a href="http://twitter.com/download/iphone" r...
# text                        This is Tilly. She's just checking pup on you....
# retweeted_status_id                                                       NaN
# retweeted_status_user_id                                                  NaN
# retweeted_status_timestamp                                                NaN
# expanded_urls               https://twitter.com/dog_rates/status/892177421...
# rating_numerator                                                           13
# rating_denominator                                                         10
# name                                                                    Tilly
# nb_stage                                                                    0
# retweet_count                                                            6514
# favorite_count                                                          33819
# user                        {'id': 4196983835, 'id_str': '4196983835', 'na...
# retweeted                                                               False
# stage                                                                   doggo
# stage_value                                                              None
#
#                                                                             2
# tweet_id                                                   891815181378084864
# in_reply_to_status_id                                                     NaN
# in_reply_to_user_id                                                       NaN
# timestamp                                           2017-07-31 00:18:03 +0000
# source                      <a href="http://twitter.com/download/iphone" r...
# text                        This is Archie. He is a rare Norwegian Pouncin...
# retweeted_status_id                                                       NaN
# retweeted_status_user_id                                                  NaN
# retweeted_status_timestamp                                                NaN
# expanded_urls               https://twitter.com/dog_rates/status/891815181...
# rating_numerator                                                           12
# rating_denominator                                                         10
# name                                                                   Archie
# nb_stage                                                                    0
# retweet_count                                                            4328
# favorite_count                                                          25461
# user                        {'id': 4196983835, 'id_str': '4196983835', 'na...
# retweeted                                                               False
# stage                                                                   doggo
# stage_value                                                              None

# %%
# Visual assessement of a tweet with unknown dog stage
tweets_without_stage_df[ tweets_without_stage_df["tweet_id"]==892420643555336193 ].T
# Out:
#                                                                          0     \
# tweet_id                                                   892420643555336193
# in_reply_to_status_id                                                     NaN
# in_reply_to_user_id                                                       NaN
# timestamp                                           2017-08-01 16:23:56 +0000
# source                      <a href="http://twitter.com/download/iphone" r...
# text                        This is Phineas. He's a mystical boy. Only eve...
# retweeted_status_id                                                       NaN
# retweeted_status_user_id                                                  NaN
# retweeted_status_timestamp                                                NaN
# expanded_urls               https://twitter.com/dog_rates/status/892420643...
# rating_numerator                                                           13
# rating_denominator                                                         10
# name                                                                  Phineas
# nb_stage                                                                    0
# retweet_count                                                            8853
# favorite_count                                                          39467
# user                        {'id': 4196983835, 'id_str': '4196983835', 'na...
# retweeted                                                               False
# stage                                                                   doggo
# stage_value                                                              None
#
#                                                                          2354  \
# tweet_id                                                   892420643555336193
# in_reply_to_status_id                                                     NaN
# in_reply_to_user_id                                                       NaN
# timestamp                                           2017-08-01 16:23:56 +0000
# source                      <a href="http://twitter.com/download/iphone" r...
# text                        This is Phineas. He's a mystical boy. Only eve...
# retweeted_status_id                                                       NaN
# retweeted_status_user_id                                                  NaN
# retweeted_status_timestamp                                                NaN
# expanded_urls               https://twitter.com/dog_rates/status/892420643...
# rating_numerator                                                           13
# rating_denominator                                                         10
# name                                                                  Phineas
# nb_stage                                                                    0
# retweet_count                                                            8853
# favorite_count                                                          39467
# user                        {'id': 4196983835, 'id_str': '4196983835', 'na...
# retweeted                                                               False
# stage                                                                 floofer
# stage_value                                                              None
#
#                                                                          4708  \
# tweet_id                                                   892420643555336193
# in_reply_to_status_id                                                     NaN
# in_reply_to_user_id                                                       NaN
# timestamp                                           2017-08-01 16:23:56 +0000
# source                      <a href="http://twitter.com/download/iphone" r...
# text                        This is Phineas. He's a mystical boy. Only eve...
# retweeted_status_id                                                       NaN
# retweeted_status_user_id                                                  NaN
# retweeted_status_timestamp                                                NaN
# expanded_urls               https://twitter.com/dog_rates/status/892420643...
# rating_numerator                                                           13
# rating_denominator                                                         10
# name                                                                  Phineas
# nb_stage                                                                    0
# retweet_count                                                            8853
# favorite_count                                                          39467
# user                        {'id': 4196983835, 'id_str': '4196983835', 'na...
# retweeted                                                               False
# stage                                                                  pupper
# stage_value                                                              None
#
#                                                                          7062
# tweet_id                                                   892420643555336193
# in_reply_to_status_id                                                     NaN
# in_reply_to_user_id                                                       NaN
# timestamp                                           2017-08-01 16:23:56 +0000
# source                      <a href="http://twitter.com/download/iphone" r...
# text                        This is Phineas. He's a mystical boy. Only eve...
# retweeted_status_id                                                       NaN
# retweeted_status_user_id                                                  NaN
# retweeted_status_timestamp                                                NaN
# expanded_urls               https://twitter.com/dog_rates/status/892420643...
# rating_numerator                                                           13
# rating_denominator                                                         10
# name                                                                  Phineas
# nb_stage                                                                    0
# retweet_count                                                            8853
# favorite_count                                                          39467
# user                        {'id': 4196983835, 'id_str': '4196983835', 'na...
# retweeted                                                               False
# stage                                                                   puppo
# stage_value                                                              None

# %% [markdown]
# We can observe that there is 04 entries (same number as the number of columns melted) for the tweets when dog stage is unknown.

# %% [markdown]
# Now we will :
# * replace the values in `tweets_without_stage_df["stage"]` by "others"
# * drop duplicate value by tweet_id in tweets_without_stage_df
# * concatenate `tweets_without_stage_df` to `tweets_with_stage_df`

# %%
# Giving a value to stage column in tweets_without_stage_df (NaN wasn't used in order to have these values ploted on chart)
tweets_without_stage_df["stage"] =  "others" # np.nan
tweets_without_stage_df.head(2).T
# Out:
# <ipython-input-66-3f0f5ad3b555>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tweets_without_stage_df["stage"] =  "others" # np.nan
#                                                                             0  \
# tweet_id                                                   892420643555336193
# in_reply_to_status_id                                                     NaN
# in_reply_to_user_id                                                       NaN
# timestamp                                           2017-08-01 16:23:56 +0000
# source                      <a href="http://twitter.com/download/iphone" r...
# text                        This is Phineas. He's a mystical boy. Only eve...
# retweeted_status_id                                                       NaN
# retweeted_status_user_id                                                  NaN
# retweeted_status_timestamp                                                NaN
# expanded_urls               https://twitter.com/dog_rates/status/892420643...
# rating_numerator                                                           13
# rating_denominator                                                         10
# name                                                                  Phineas
# nb_stage                                                                    0
# retweet_count                                                            8853
# favorite_count                                                          39467
# user                        {'id': 4196983835, 'id_str': '4196983835', 'na...
# retweeted                                                               False
# stage                                                                  others
# stage_value                                                              None
#
#                                                                             1
# tweet_id                                                   892177421306343426
# in_reply_to_status_id                                                     NaN
# in_reply_to_user_id                                                       NaN
# timestamp                                           2017-08-01 00:17:27 +0000
# source                      <a href="http://twitter.com/download/iphone" r...
# text                        This is Tilly. She's just checking pup on you....
# retweeted_status_id                                                       NaN
# retweeted_status_user_id                                                  NaN
# retweeted_status_timestamp                                                NaN
# expanded_urls               https://twitter.com/dog_rates/status/892177421...
# rating_numerator                                                           13
# rating_denominator                                                         10
# name                                                                    Tilly
# nb_stage                                                                    0
# retweet_count                                                            6514
# favorite_count                                                          33819
# user                        {'id': 4196983835, 'id_str': '4196983835', 'na...
# retweeted                                                               False
# stage                                                                  others
# stage_value                                                              None

# %%
tweets_without_stage_df.shape
# Out:
# (9024, 20)

# %%
# Drop duplicate value by tweet_id in tweets_without_stage_df
tweets_without_stage_df.drop_duplicates(subset="tweet_id",inplace=True)
tweets_without_stage_df.shape
# Out:
# <ipython-input-68-844b4621f32a>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tweets_without_stage_df.drop_duplicates(subset="tweet_id",inplace=True)
# (2354, 20)

# %%
# Concat tweets_without_stage_df and tweets_with_stage_df, in order to form a whole again
twitter_clean = pd.concat([tweets_with_stage_df,tweets_without_stage_df], axis=0, ignore_index=True)

# Shuffling the dataframe in order to eliminate an eventual bias
"""Reference : https://datagy.io/pandas-shuffle-dataframe/ """
random_state_seed = 5 # set seed for reproducibility
twitter_clean = twitter_clean.sample(frac=1, random_state=random_state_seed).reset_index()


twitter_clean.head(3).T
# Out:
#                                                                             0  \
# index                                                                    1435
# tweet_id                                                   728046963732717569
# in_reply_to_status_id                                                     NaN
# in_reply_to_user_id                                                       NaN
# timestamp                                           2016-05-05 02:21:37 +0000
# source                      <a href="http://twitter.com/download/iphone" r...
# text                        This is Raymond. He controls fountains with hi...
# retweeted_status_id                                                       NaN
# retweeted_status_user_id                                                  NaN
# retweeted_status_timestamp                                                NaN
# expanded_urls               https://twitter.com/dog_rates/status/728046963...
# rating_numerator                                                           11
# rating_denominator                                                         10
# name                                                                  Raymond
# nb_stage                                                                    0
# retweet_count                                                            1328
# favorite_count                                                           4722
# user                        {'id': 4196983835, 'id_str': '4196983835', 'na...
# retweeted                                                               False
# stage                                                                  others
# stage_value                                                              None
#
#                                                                             1  \
# index                                                                    1067
# tweet_id                                                   781661882474196992
# in_reply_to_status_id                                                     NaN
# in_reply_to_user_id                                                       NaN
# timestamp                                           2016-09-30 01:08:10 +0000
# source                      <a href="http://twitter.com/download/iphone" r...
# text                        Who keeps sending in pictures without dogs in ...
# retweeted_status_id                                                       NaN
# retweeted_status_user_id                                                  NaN
# retweeted_status_timestamp                                                NaN
# expanded_urls               https://twitter.com/dog_rates/status/781661882...
# rating_numerator                                                            5
# rating_denominator                                                         10
# name                                                                     None
# nb_stage                                                                    0
# retweet_count                                                            3129
# favorite_count                                                          11634
# user                        {'id': 4196983835, 'id_str': '4196983835', 'na...
# retweeted                                                               False
# stage                                                                  others
# stage_value                                                              None
#
#                                                                             2
# index                                                                    1340
# tweet_id                                                   745057283344719872
# in_reply_to_status_id                                                     NaN
# in_reply_to_user_id                                                       NaN
# timestamp                                           2016-06-21 00:54:33 +0000
# source                      <a href="http://twitter.com/download/iphone" r...
# text                        This is Oliver. He's downright gorgeous as hel...
# retweeted_status_id                                                       NaN
# retweeted_status_user_id                                                  NaN
# retweeted_status_timestamp                                                NaN
# expanded_urls               https://twitter.com/dog_rates/status/745057283...
# rating_numerator                                                           12
# rating_denominator                                                         10
# name                                                                   Oliver
# nb_stage                                                                    0
# retweet_count                                                            2585
# favorite_count                                                           7945
# user                        {'id': 4196983835, 'id_str': '4196983835', 'na...
# retweeted                                                               False
# stage                                                                  others
# stage_value                                                              None

# %% [markdown]
# Looking at our dataframe, we don't need the `stage_value` column anymore, so we will drop it. We will also drop `index` column, because it is the original index of the samples before they were shuffled.

# %%
twitter_df = twitter_clean.drop(["stage_value","index"],axis=1)
twitter_df.head(3).T
# Out:
#                                                                             0  \
# tweet_id                                                   728046963732717569
# in_reply_to_status_id                                                     NaN
# in_reply_to_user_id                                                       NaN
# timestamp                                           2016-05-05 02:21:37 +0000
# source                      <a href="http://twitter.com/download/iphone" r...
# text                        This is Raymond. He controls fountains with hi...
# retweeted_status_id                                                       NaN
# retweeted_status_user_id                                                  NaN
# retweeted_status_timestamp                                                NaN
# expanded_urls               https://twitter.com/dog_rates/status/728046963...
# rating_numerator                                                           11
# rating_denominator                                                         10
# name                                                                  Raymond
# nb_stage                                                                    0
# retweet_count                                                            1328
# favorite_count                                                           4722
# user                        {'id': 4196983835, 'id_str': '4196983835', 'na...
# retweeted                                                               False
# stage                                                                  others
#
#                                                                             1  \
# tweet_id                                                   781661882474196992
# in_reply_to_status_id                                                     NaN
# in_reply_to_user_id                                                       NaN
# timestamp                                           2016-09-30 01:08:10 +0000
# source                      <a href="http://twitter.com/download/iphone" r...
# text                        Who keeps sending in pictures without dogs in ...
# retweeted_status_id                                                       NaN
# retweeted_status_user_id                                                  NaN
# retweeted_status_timestamp                                                NaN
# expanded_urls               https://twitter.com/dog_rates/status/781661882...
# rating_numerator                                                            5
# rating_denominator                                                         10
# name                                                                     None
# nb_stage                                                                    0
# retweet_count                                                            3129
# favorite_count                                                          11634
# user                        {'id': 4196983835, 'id_str': '4196983835', 'na...
# retweeted                                                               False
# stage                                                                  others
#
#                                                                             2
# tweet_id                                                   745057283344719872
# in_reply_to_status_id                                                     NaN
# in_reply_to_user_id                                                       NaN
# timestamp                                           2016-06-21 00:54:33 +0000
# source                      <a href="http://twitter.com/download/iphone" r...
# text                        This is Oliver. He's downright gorgeous as hel...
# retweeted_status_id                                                       NaN
# retweeted_status_user_id                                                  NaN
# retweeted_status_timestamp                                                NaN
# expanded_urls               https://twitter.com/dog_rates/status/745057283...
# rating_numerator                                                           12
# rating_denominator                                                         10
# name                                                                   Oliver
# nb_stage                                                                    0
# retweet_count                                                            2585
# favorite_count                                                           7945
# user                        {'id': 4196983835, 'id_str': '4196983835', 'na...
# retweeted                                                               False
# stage                                                                  others

# %%
# the user column is (temporarly) removed from the duplicate checking in order to avoid "unhashable type: 'dict'" error
#   when using dataframe.duplicated()
twitter_df.drop(["user"],axis=1).duplicated().sum()
# Out:
# 0

# %%
# double-check the previous duplicate value search, by narowing down the search to the tweet_id
twitter_df["tweet_id"].duplicated().sum()
# Out:
# 392

# %% [markdown]
# There are many duplicated tweet id. I will investigate the issue.

# %%
duplicated_tweets_df = twitter_df[twitter_df["tweet_id"].duplicated() ]
duplicated_tweets_df.shape
# Out:
# (392, 19)

# %%
duplicated_tweets_df.head(3).T
# Out:
#                                                                           124  \
# tweet_id                                                   751456908746354688
# in_reply_to_status_id                                                     NaN
# in_reply_to_user_id                                                       NaN
# timestamp                                           2016-07-08 16:44:23 +0000
# source                      <a href="http://twitter.com/download/iphone" r...
# text                        Here's a pupper that's very hungry but too laz...
# retweeted_status_id                                                       NaN
# retweeted_status_user_id                                                  NaN
# retweeted_status_timestamp                                                NaN
# expanded_urls               https://twitter.com/dog_rates/status/751456908...
# rating_numerator                                                           12
# rating_denominator                                                         10
# name                                                                     None
# nb_stage                                                                    1
# retweet_count                                                            1127
# favorite_count                                                           3516
# user                        {'id': 4196983835, 'id_str': '4196983835', 'na...
# retweeted                                                               False
# stage                                                                  pupper
#
#                                                                           131  \
# tweet_id                                                   834574053763584002
# in_reply_to_status_id                                                     NaN
# in_reply_to_user_id                                                       NaN
# timestamp                                           2017-02-23 01:22:14 +0000
# source                      <a href="http://twitter.com/download/iphone" r...
# text                        Here's a doggo fully pupared for a shower. H*c...
# retweeted_status_id                                                       NaN
# retweeted_status_user_id                                                  NaN
# retweeted_status_timestamp                                                NaN
# expanded_urls               https://twitter.com/dog_rates/status/834574053...
# rating_numerator                                                           13
# rating_denominator                                                         10
# name                                                                     None
# nb_stage                                                                    1
# retweet_count                                                            2882
# favorite_count                                                          14993
# user                        {'id': 4196983835, 'id_str': '4196983835', 'na...
# retweeted                                                               False
# stage                                                                  others
#
#                                                                           208
# tweet_id                                                   751583847268179968
# in_reply_to_status_id                                                     NaN
# in_reply_to_user_id                                                       NaN
# timestamp                                           2016-07-09 01:08:47 +0000
# source                      <a href="http://twitter.com/download/iphone" r...
# text                        Please stop sending it pictures that don't eve...
# retweeted_status_id                                                       NaN
# retweeted_status_user_id                                                  NaN
# retweeted_status_timestamp                                                NaN
# expanded_urls               https://twitter.com/dog_rates/status/751583847...
# rating_numerator                                                            5
# rating_denominator                                                         10
# name                                                                     None
# nb_stage                                                                    2
# retweet_count                                                            1265
# favorite_count                                                           4849
# user                        {'id': 4196983835, 'id_str': '4196983835', 'na...
# retweeted                                                               False
# stage                                                                  others

# %% [markdown]
# *TODO : After graduating from my nanodedree, investigate the origin of those duplicate tweet id, and clean the issue*

# %% [markdown]
# #### Test

# %%
# Checking the occurences in twitter_df["stage"]
twitter_df["stage"].unique()
# Out:
# array(['others', 'pupper', 'doggo', 'puppo', 'floofer'], dtype=object)

# %%
# Checking the repartition of the dog per their stage
twitter_df["stage"].value_counts()
# Out:
# others     2354
# pupper      256
# doggo        96
# puppo        30
# floofer      10
# Name: stage, dtype: int64

# %%
# Checking for duplicate 

# the user column is (temporarly) removed from the duplicate checking in order to avoid "unhashable type: 'dict'" error
#   when using dataframe.duplicated()
twitter_df.drop(["user"],axis=1).duplicated().sum()
# Out:
# 0

# %% [markdown]
# <!-- Now we will check the number of column in each of our twitter dataset (the original, and the new) -->

# %% [markdown]
# ### Issue #3 (tidiness): `twitter_archive_df` has useless columns for our purpose
# Those columns are `status_id, status_user_id, status_timestamp`.
#
# Our cleaning is to be performed in `twitter_df`

# %%
# Recalling the content of our df
twitter_df.head(2).T
# Out:
#                                                                             0  \
# tweet_id                                                   728046963732717569
# in_reply_to_status_id                                                     NaN
# in_reply_to_user_id                                                       NaN
# timestamp                                           2016-05-05 02:21:37 +0000
# source                      <a href="http://twitter.com/download/iphone" r...
# text                        This is Raymond. He controls fountains with hi...
# retweeted_status_id                                                       NaN
# retweeted_status_user_id                                                  NaN
# retweeted_status_timestamp                                                NaN
# expanded_urls               https://twitter.com/dog_rates/status/728046963...
# rating_numerator                                                           11
# rating_denominator                                                         10
# name                                                                  Raymond
# nb_stage                                                                    0
# retweet_count                                                            1328
# favorite_count                                                           4722
# user                        {'id': 4196983835, 'id_str': '4196983835', 'na...
# retweeted                                                               False
# stage                                                                  others
#
#                                                                             1
# tweet_id                                                   781661882474196992
# in_reply_to_status_id                                                     NaN
# in_reply_to_user_id                                                       NaN
# timestamp                                           2016-09-30 01:08:10 +0000
# source                      <a href="http://twitter.com/download/iphone" r...
# text                        Who keeps sending in pictures without dogs in ...
# retweeted_status_id                                                       NaN
# retweeted_status_user_id                                                  NaN
# retweeted_status_timestamp                                                NaN
# expanded_urls               https://twitter.com/dog_rates/status/781661882...
# rating_numerator                                                            5
# rating_denominator                                                         10
# name                                                                     None
# nb_stage                                                                    0
# retweet_count                                                            3129
# favorite_count                                                          11634
# user                        {'id': 4196983835, 'id_str': '4196983835', 'na...
# retweeted                                                               False
# stage                                                                  others

# %% [markdown]
# #### Define
#
# Remove columns deemed useless for our purpose from `twitter_df` : `in_reply_to_status_id, in_reply_to_user_id, expanded_urls`.

# %% [markdown]
# #### Code

# %%
useless_columns = ["in_reply_to_status_id","in_reply_to_user_id","expanded_urls"]
twitter_df.drop(useless_columns, axis=1, inplace=True)

# %% [markdown]
# #### Test

# %%
# Making sure the dropped columns no longer exist
twitter_df.head(2).T
# Out:
#                                                                             0  \
# tweet_id                                                   728046963732717569
# timestamp                                           2016-05-05 02:21:37 +0000
# source                      <a href="http://twitter.com/download/iphone" r...
# text                        This is Raymond. He controls fountains with hi...
# retweeted_status_id                                                       NaN
# retweeted_status_user_id                                                  NaN
# retweeted_status_timestamp                                                NaN
# rating_numerator                                                           11
# rating_denominator                                                         10
# name                                                                  Raymond
# nb_stage                                                                    0
# retweet_count                                                            1328
# favorite_count                                                           4722
# user                        {'id': 4196983835, 'id_str': '4196983835', 'na...
# retweeted                                                               False
# stage                                                                  others
#
#                                                                             1
# tweet_id                                                   781661882474196992
# timestamp                                           2016-09-30 01:08:10 +0000
# source                      <a href="http://twitter.com/download/iphone" r...
# text                        Who keeps sending in pictures without dogs in ...
# retweeted_status_id                                                       NaN
# retweeted_status_user_id                                                  NaN
# retweeted_status_timestamp                                                NaN
# rating_numerator                                                            5
# rating_denominator                                                         10
# name                                                                     None
# nb_stage                                                                    0
# retweet_count                                                            3129
# favorite_count                                                          11634
# user                        {'id': 4196983835, 'id_str': '4196983835', 'na...
# retweeted                                                               False
# stage                                                                  others

# %% [markdown]
# ### Issue #4 (tidiness): `tweets_df.user` should contains the id of another dataframe named `user`
#
# The cleaning it to be performed in `twitter_df`

# %%
twitter_df.head(3).T
# Out:
#                                                                             0  \
# tweet_id                                                   728046963732717569
# timestamp                                           2016-05-05 02:21:37 +0000
# source                      <a href="http://twitter.com/download/iphone" r...
# text                        This is Raymond. He controls fountains with hi...
# retweeted_status_id                                                       NaN
# retweeted_status_user_id                                                  NaN
# retweeted_status_timestamp                                                NaN
# rating_numerator                                                           11
# rating_denominator                                                         10
# name                                                                  Raymond
# nb_stage                                                                    0
# retweet_count                                                            1328
# favorite_count                                                           4722
# user                        {'id': 4196983835, 'id_str': '4196983835', 'na...
# retweeted                                                               False
# stage                                                                  others
#
#                                                                             1  \
# tweet_id                                                   781661882474196992
# timestamp                                           2016-09-30 01:08:10 +0000
# source                      <a href="http://twitter.com/download/iphone" r...
# text                        Who keeps sending in pictures without dogs in ...
# retweeted_status_id                                                       NaN
# retweeted_status_user_id                                                  NaN
# retweeted_status_timestamp                                                NaN
# rating_numerator                                                            5
# rating_denominator                                                         10
# name                                                                     None
# nb_stage                                                                    0
# retweet_count                                                            3129
# favorite_count                                                          11634
# user                        {'id': 4196983835, 'id_str': '4196983835', 'na...
# retweeted                                                               False
# stage                                                                  others
#
#                                                                             2
# tweet_id                                                   745057283344719872
# timestamp                                           2016-06-21 00:54:33 +0000
# source                      <a href="http://twitter.com/download/iphone" r...
# text                        This is Oliver. He's downright gorgeous as hel...
# retweeted_status_id                                                       NaN
# retweeted_status_user_id                                                  NaN
# retweeted_status_timestamp                                                NaN
# rating_numerator                                                           12
# rating_denominator                                                         10
# name                                                                   Oliver
# nb_stage                                                                    0
# retweet_count                                                            2585
# favorite_count                                                           7945
# user                        {'id': 4196983835, 'id_str': '4196983835', 'na...
# retweeted                                                               False
# stage                                                                  others

# %% [markdown]
# #### Define
# * Extract values from `twitter_df["user"]`, and use them to populate a new `user_df` dataframe
# * Replace each value from `twitter_df["user"]` by the user_id
# * Remove duplicated samples from `user_df`

# %% [markdown]
# #### Code

# %%
# Retrieve users data from twitter_df["user"]
user_list = twitter_df["user"].values.tolist()
user_list[1]
# Out:
# {'id': 4196983835,
#  'id_str': '4196983835',
#  'name': 'WeRateDogs™ (author)',
#  'screen_name': 'dog_rates',
#  'location': 'DM YOUR DOGS, WE WILL RATE',
#  'description': '#1 Source for Professional Dog Ratings | STORE: @ShopWeRateDogs | IG, FB & SC: WeRateDogs MOBILE APP: @GoodDogsGame | Business: dogratingtwitter@gmail.com',
#  'url': 'https://t.co/N7sNNHAEXS',
#  'entities': {'url': {'urls': [{'url': 'https://t.co/N7sNNHAEXS',
#      'expanded_url': 'http://weratedogs.com',
#      'display_url': 'weratedogs.com',
#      'indices': [0, 23]}]},
#   'description': {'urls': []}},
#  'protected': False,
#  'followers_count': 3200901,
#  'friends_count': 104,
#  'listed_count': 2789,
#  'created_at': 'Sun Nov 15 21:41:29 +0000 2015',
#  'favourites_count': 114031,
#  'utc_offset': None,
#  'time_zone': None,
#  'geo_enabled': True,
#  'verified': True,
#  'statuses_count': 5288,
#  'lang': 'en',
#  'contributors_enabled': False,
#  'is_translator': False,
#  'is_translation_enabled': False,
#  'profile_background_color': '000000',
#  'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#  'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#  'profile_background_tile': False,
#  'profile_image_url': 'http://pbs.twimg.com/profile_images/861415328504569856/R2xOOfwe_normal.jpg',
#  'profile_image_url_https': 'https://pbs.twimg.com/profile_images/861415328504569856/R2xOOfwe_normal.jpg',
#  'profile_banner_url': 'https://pbs.twimg.com/profile_banners/4196983835/1501129017',
#  'profile_link_color': 'F5ABB5',
#  'profile_sidebar_border_color': '000000',
#  'profile_sidebar_fill_color': '000000',
#  'profile_text_color': '000000',
#  'profile_use_background_image': False,
#  'has_extended_profile': True,
#  'default_profile': False,
#  'default_profile_image': False,
#  'following': True,
#  'follow_request_sent': False,
#  'notifications': False,
#  'translator_type': 'none'}

# %%
# Create user dataframe
user_df = pd.DataFrame(user_list)
user_df.head(2).T
# Out:
#                                                                                     0  \
# id                                                                         4196983835
# id_str                                                                     4196983835
# name                                                             WeRateDogs™ (author)
# screen_name                                                                 dog_rates
# location                                                   DM YOUR DOGS, WE WILL RATE
# description                         #1 Source for Professional Dog Ratings | STORE...
# url                                                           https://t.co/N7sNNHAEXS
# entities                            {'url': {'urls': [{'url': 'https://t.co/N7sNNH...
# protected                                                                       False
# followers_count                                                               3200944
# friends_count                                                                     104
# listed_count                                                                     2803
# created_at                                             Sun Nov 15 21:41:29 +0000 2015
# favourites_count                                                               114031
# utc_offset                                                                       None
# time_zone                                                                        None
# geo_enabled                                                                      True
# verified                                                                         True
# statuses_count                                                                   5288
# lang                                                                               en
# contributors_enabled                                                            False
# is_translator                                                                   False
# is_translation_enabled                                                          False
# profile_background_color                                                       000000
# profile_background_image_url         http://abs.twimg.com/images/themes/theme1/bg.png
# profile_background_image_url_https  https://abs.twimg.com/images/themes/theme1/bg.png
# profile_background_tile                                                         False
# profile_image_url                   http://pbs.twimg.com/profile_images/8614153285...
# profile_image_url_https             https://pbs.twimg.com/profile_images/861415328...
# profile_banner_url                  https://pbs.twimg.com/profile_banners/41969838...
# profile_link_color                                                             F5ABB5
# profile_sidebar_border_color                                                   000000
# profile_sidebar_fill_color                                                     000000
# profile_text_color                                                             000000
# profile_use_background_image                                                    False
# has_extended_profile                                                             True
# default_profile                                                                 False
# default_profile_image                                                           False
# following                                                                        True
# follow_request_sent                                                             False
# notifications                                                                   False
# translator_type                                                                  none
#
#                                                                                     1
# id                                                                         4196983835
# id_str                                                                     4196983835
# name                                                             WeRateDogs™ (author)
# screen_name                                                                 dog_rates
# location                                                   DM YOUR DOGS, WE WILL RATE
# description                         #1 Source for Professional Dog Ratings | STORE...
# url                                                           https://t.co/N7sNNHAEXS
# entities                            {'url': {'urls': [{'url': 'https://t.co/N7sNNH...
# protected                                                                       False
# followers_count                                                               3200901
# friends_count                                                                     104
# listed_count                                                                     2789
# created_at                                             Sun Nov 15 21:41:29 +0000 2015
# favourites_count                                                               114031
# utc_offset                                                                       None
# time_zone                                                                        None
# geo_enabled                                                                      True
# verified                                                                         True
# statuses_count                                                                   5288
# lang                                                                               en
# contributors_enabled                                                            False
# is_translator                                                                   False
# is_translation_enabled                                                          False
# profile_background_color                                                       000000
# profile_background_image_url         http://abs.twimg.com/images/themes/theme1/bg.png
# profile_background_image_url_https  https://abs.twimg.com/images/themes/theme1/bg.png
# profile_background_tile                                                         False
# profile_image_url                   http://pbs.twimg.com/profile_images/8614153285...
# profile_image_url_https             https://pbs.twimg.com/profile_images/861415328...
# profile_banner_url                  https://pbs.twimg.com/profile_banners/41969838...
# profile_link_color                                                             F5ABB5
# profile_sidebar_border_color                                                   000000
# profile_sidebar_fill_color                                                     000000
# profile_text_color                                                             000000
# profile_use_background_image                                                    False
# has_extended_profile                                                             True
# default_profile                                                                 False
# default_profile_image                                                           False
# following                                                                        True
# follow_request_sent                                                             False
# notifications                                                                   False
# translator_type                                                                  none

# %%
user_df.drop(["entities"],axis=1,inplace=True)

# %%
user_df.shape
# Out:
# (2746, 41)

# %%
user_df.drop_duplicates(inplace=True)

# %%
user_df.shape
# Out:
# (79, 41)

# %%
user_df["id"].unique()
# Out:
# array([4196983835], dtype=int64)

# %% [markdown]
# We are noticing that all entries in `user_df` are about one user. This should be related to the fact it is additionnal data describing the state, and not the attributes, of the users which were stored in `twitter_df["user"]`; this can be explained by how NoSQL databases are usually designed.
# Given the situation, `user_df` is of no more use to use, so we will discard it.
# Given the situation `twitter_df["user"]` should contain data related to only one user_id. We cannot help but wondering if it is useful to us as a column, and if user mean a person or something like a terminal/source ip.

# %%
twitter_df.head(2).T
# Out:
#                                                                             0  \
# tweet_id                                                   728046963732717569
# timestamp                                           2016-05-05 02:21:37 +0000
# source                      <a href="http://twitter.com/download/iphone" r...
# text                        This is Raymond. He controls fountains with hi...
# retweeted_status_id                                                       NaN
# retweeted_status_user_id                                                  NaN
# retweeted_status_timestamp                                                NaN
# rating_numerator                                                           11
# rating_denominator                                                         10
# name                                                                  Raymond
# nb_stage                                                                    0
# retweet_count                                                            1328
# favorite_count                                                           4722
# user                        {'id': 4196983835, 'id_str': '4196983835', 'na...
# retweeted                                                               False
# stage                                                                  others
#
#                                                                             1
# tweet_id                                                   781661882474196992
# timestamp                                           2016-09-30 01:08:10 +0000
# source                      <a href="http://twitter.com/download/iphone" r...
# text                        Who keeps sending in pictures without dogs in ...
# retweeted_status_id                                                       NaN
# retweeted_status_user_id                                                  NaN
# retweeted_status_timestamp                                                NaN
# rating_numerator                                                            5
# rating_denominator                                                         10
# name                                                                     None
# nb_stage                                                                    0
# retweet_count                                                            3129
# favorite_count                                                          11634
# user                        {'id': 4196983835, 'id_str': '4196983835', 'na...
# retweeted                                                               False
# stage                                                                  others

# %%
# Forming a new column containing the user_id
twitter_df["user_id"] = twitter_df["user"].apply(lambda x: x["id"])
twitter_df.sample(10).T
# Out:
#                                                                          1663  \
# tweet_id                                                   719704490224398336
# timestamp                                           2016-04-12 01:51:36 +0000
# source                      <a href="http://twitter.com/download/iphone" r...
# text                        This is Clyde. He's making sure you're having ...
# retweeted_status_id                                                       NaN
# retweeted_status_user_id                                                  NaN
# retweeted_status_timestamp                                                NaN
# rating_numerator                                                           12
# rating_denominator                                                         10
# name                                                                    Clyde
# nb_stage                                                                    1
# retweet_count                                                            1645
# favorite_count                                                           4974
# user                        {'id': 4196983835, 'id_str': '4196983835', 'na...
# retweeted                                                               False
# stage                                                                  others
# user_id                                                            4196983835
#
#                                                                          1891  \
# tweet_id                                                   780192070812196864
# timestamp                                           2016-09-25 23:47:39 +0000
# source                      <a href="http://twitter.com/download/iphone" r...
# text                        We only rate dogs. Pls stop sending in non-can...
# retweeted_status_id                                                       NaN
# retweeted_status_user_id                                                  NaN
# retweeted_status_timestamp                                                NaN
# rating_numerator                                                           11
# rating_denominator                                                         10
# name                                                                     None
# nb_stage                                                                    0
# retweet_count                                                            2589
# favorite_count                                                           9712
# user                        {'id': 4196983835, 'id_str': '4196983835', 'na...
# retweeted                                                               False
# stage                                                                  others
# user_id                                                            4196983835
#
#                                                                          2193  \
# tweet_id                                                   808106460588765185
# timestamp                                           2016-12-12 00:29:28 +0000
# source                      <a href="http://twitter.com/download/iphone" r...
# text                        Here we have Burke (pupper) and Dexter (doggo)...
# retweeted_status_id                                                       NaN
# retweeted_status_user_id                                                  NaN
# retweeted_status_timestamp                                                NaN
# rating_numerator                                                           12
# rating_denominator                                                         10
# name                                                                     None
# nb_stage                                                                    2
# retweet_count                                                            2525
# favorite_count                                                           9701
# user                        {'id': 4196983835, 'id_str': '4196983835', 'na...
# retweeted                                                               False
# stage                                                                  pupper
# user_id                                                            4196983835
#
#                                                                          2191  \
# tweet_id                                                   681679526984871937
# timestamp                                           2015-12-29 03:33:58 +0000
# source                      <a href="http://twitter.com/download/iphone" r...
# text                        Can you spot Toby the guilty pupper? 7/10 woul...
# retweeted_status_id                                                       NaN
# retweeted_status_user_id                                                  NaN
# retweeted_status_timestamp                                                NaN
# rating_numerator                                                            7
# rating_denominator                                                         10
# name                                                                     None
# nb_stage                                                                    1
# retweet_count                                                             499
# favorite_count                                                           1923
# user                        {'id': 4196983835, 'id_str': '4196983835', 'na...
# retweeted                                                               False
# stage                                                                  others
# user_id                                                            4196983835
#
#                                                                          158   \
# tweet_id                                                   694206574471057408
# timestamp                                           2016-02-01 17:11:59 +0000
# source                      <a href="http://twitter.com/download/iphone" r...
# text                        "Martha come take a look at this. I'm so fed u...
# retweeted_status_id                                                       NaN
# retweeted_status_user_id                                                  NaN
# retweeted_status_timestamp                                                NaN
# rating_numerator                                                           10
# rating_denominator                                                         10
# name                                                                     None
# nb_stage                                                                    0
# retweet_count                                                            2297
# favorite_count                                                           4582
# user                        {'id': 4196983835, 'id_str': '4196983835', 'na...
# retweeted                                                               False
# stage                                                                  others
# user_id                                                            4196983835
#
#                                                                          1913  \
# tweet_id                                                   753026973505581056
# timestamp                                           2016-07-13 00:43:15 +0000
# source                      <a href="http://twitter.com/download/iphone" r...
# text                        Say hello to Tayzie. She's a Barbadian Bugaboo...
# retweeted_status_id                                                       NaN
# retweeted_status_user_id                                                  NaN
# retweeted_status_timestamp                                                NaN
# rating_numerator                                                           10
# rating_denominator                                                         10
# name                                                                   Tayzie
# nb_stage                                                                    0
# retweet_count                                                            1109
# favorite_count                                                           4283
# user                        {'id': 4196983835, 'id_str': '4196983835', 'na...
# retweeted                                                               False
# stage                                                                  others
# user_id                                                            4196983835
#
#                                                                          1049  \
# tweet_id                                                   889665388333682689
# timestamp                                           2017-07-25 01:55:32 +0000
# source                      <a href="http://twitter.com/download/iphone" r...
# text                        Here's a puppo that seems to be on the fence a...
# retweeted_status_id                                                       NaN
# retweeted_status_user_id                                                  NaN
# retweeted_status_timestamp                                                NaN
# rating_numerator                                                           13
# rating_denominator                                                         10
# name                                                                     None
# nb_stage                                                                    1
# retweet_count                                                            8538
# favorite_count                                                          38818
# user                        {'id': 4196983835, 'id_str': '4196983835', 'na...
# retweeted                                                               False
# stage                                                                   puppo
# user_id                                                            4196983835
#
#                                                                          1235  \
# tweet_id                                                   667453023279554560
# timestamp                                           2015-11-19 21:22:56 +0000
# source                      <a href="http://twitter.com" rel="nofollow">Tw...
# text                        Meet Cupcake. I would do unspeakable things fo...
# retweeted_status_id                                                       NaN
# retweeted_status_user_id                                                  NaN
# retweeted_status_timestamp                                                NaN
# rating_numerator                                                           11
# rating_denominator                                                         10
# name                                                                  Cupcake
# nb_stage                                                                    0
# retweet_count                                                              96
# favorite_count                                                            327
# user                        {'id': 4196983835, 'id_str': '4196983835', 'na...
# retweeted                                                               False
# stage                                                                  others
# user_id                                                            4196983835
#
#                                                                          2043  \
# tweet_id                                                   883482846933004288
# timestamp                                           2017-07-08 00:28:19 +0000
# source                      <a href="http://twitter.com/download/iphone" r...
# text                        This is Bella. She hopes her smile made you sm...
# retweeted_status_id                                                       NaN
# retweeted_status_user_id                                                  NaN
# retweeted_status_timestamp                                                NaN
# rating_numerator                                                            5
# rating_denominator                                                         10
# name                                                                    Bella
# nb_stage                                                                    0
# retweet_count                                                           10407
# favorite_count                                                          46860
# user                        {'id': 4196983835, 'id_str': '4196983835', 'na...
# retweeted                                                               False
# stage                                                                  others
# user_id                                                            4196983835
#
#                                                                          1112
# tweet_id                                                   797165961484890113
# timestamp                                           2016-11-11 19:55:50 +0000
# source                      <a href="http://twitter.com/download/iphone" r...
# text                        @JODYHiGHROLLER it may be an 11/10 but what do...
# retweeted_status_id                                                       NaN
# retweeted_status_user_id                                                  NaN
# retweeted_status_timestamp                                                NaN
# rating_numerator                                                           11
# rating_denominator                                                         10
# name                                                                     None
# nb_stage                                                                    0
# retweet_count                                                              32
# favorite_count                                                            256
# user                        {'id': 4196983835, 'id_str': '4196983835', 'na...
# retweeted                                                               False
# stage                                                                  others
# user_id                                                            4196983835

# %%
# Confirming that we have the same user_id in our dataframe
twitter_df["user_id"].unique()
# Out:
# array([4196983835], dtype=int64)

# %% [markdown]
# Since we have the same user_id in `twitter_df["user_id"]`, this column is no more useful in our analysis. We will drop it.

# %%
# def extract_keysvalue_from_json(json_data:dict, dict_key:str):
#     """
#         Retrieve the value of a given key from a json data
        
#         @param json_data:str : the json from which to extract the given key's value
#         @param dict_key:str : the key which value we wish to extract from the dictionnary 
#     """
#     return json_data[dict_key] #json.loads(json_data)[dict_key]

# %%
# Drop user columns, since their content make them useless
twitter_df.drop(["user","user_id"],axis=1,inplace=True)

# %% [markdown]
# #### Test

# %%
twitter_df.head(2).T
# Out:
#                                                                             0  \
# tweet_id                                                   728046963732717569
# timestamp                                           2016-05-05 02:21:37 +0000
# source                      <a href="http://twitter.com/download/iphone" r...
# text                        This is Raymond. He controls fountains with hi...
# retweeted_status_id                                                       NaN
# retweeted_status_user_id                                                  NaN
# retweeted_status_timestamp                                                NaN
# rating_numerator                                                           11
# rating_denominator                                                         10
# name                                                                  Raymond
# nb_stage                                                                    0
# retweet_count                                                            1328
# favorite_count                                                           4722
# retweeted                                                               False
# stage                                                                  others
#
#                                                                             1
# tweet_id                                                   781661882474196992
# timestamp                                           2016-09-30 01:08:10 +0000
# source                      <a href="http://twitter.com/download/iphone" r...
# text                        Who keeps sending in pictures without dogs in ...
# retweeted_status_id                                                       NaN
# retweeted_status_user_id                                                  NaN
# retweeted_status_timestamp                                                NaN
# rating_numerator                                                            5
# rating_denominator                                                         10
# name                                                                     None
# nb_stage                                                                    0
# retweet_count                                                            3129
# favorite_count                                                          11634
# retweeted                                                               False
# stage                                                                  others

# %% [markdown]
# ### Issue #1 (quality issue) : `twitter_archive_df['source']` has tag `a` as value instead of the value of `href` attribute
#
# The cleaning is to be performed in `twitter_df`

# %% [markdown]
# #### Define
# Extract href value from `twitter_df["source"]` occurences, and use it to replace tag `a`

# %% [markdown]
# #### Code

# %%
# Recalling the content of our dataset
twitter_df.head(2).T
# Out:
#                                                                             0  \
# tweet_id                                                   728046963732717569
# timestamp                                           2016-05-05 02:21:37 +0000
# source                      <a href="http://twitter.com/download/iphone" r...
# text                        This is Raymond. He controls fountains with hi...
# retweeted_status_id                                                       NaN
# retweeted_status_user_id                                                  NaN
# retweeted_status_timestamp                                                NaN
# rating_numerator                                                           11
# rating_denominator                                                         10
# name                                                                  Raymond
# nb_stage                                                                    0
# retweet_count                                                            1328
# favorite_count                                                           4722
# retweeted                                                               False
# stage                                                                  others
#
#                                                                             1
# tweet_id                                                   781661882474196992
# timestamp                                           2016-09-30 01:08:10 +0000
# source                      <a href="http://twitter.com/download/iphone" r...
# text                        Who keeps sending in pictures without dogs in ...
# retweeted_status_id                                                       NaN
# retweeted_status_user_id                                                  NaN
# retweeted_status_timestamp                                                NaN
# rating_numerator                                                            5
# rating_denominator                                                         10
# name                                                                     None
# nb_stage                                                                    0
# retweet_count                                                            3129
# favorite_count                                                          11634
# retweeted                                                               False
# stage                                                                  others

# %%
twitter_df["source"][0]
# Out:
# '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>'

# %%
twitter_df.loc[1,"source"]
# Out:
# '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>'

# %%
twitter_df["source"].unique()
# Out:
# array(['<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#        '<a href="http://vine.co" rel="nofollow">Vine - Make a Scene</a>',
#        '<a href="http://twitter.com" rel="nofollow">Twitter Web Client</a>',
#        '<a href="https://about.twitter.com/products/tweetdeck" rel="nofollow">TweetDeck</a>'],
#       dtype=object)

# %%
# Clean source column
twitter_df["source"] = twitter_df["source"].apply(extract_urls_from_str)
twitter_df.head(2).T
# Out:
#                                                                             0  \
# tweet_id                                                   728046963732717569
# timestamp                                           2016-05-05 02:21:37 +0000
# source                                     http://twitter.com/download/iphone
# text                        This is Raymond. He controls fountains with hi...
# retweeted_status_id                                                       NaN
# retweeted_status_user_id                                                  NaN
# retweeted_status_timestamp                                                NaN
# rating_numerator                                                           11
# rating_denominator                                                         10
# name                                                                  Raymond
# nb_stage                                                                    0
# retweet_count                                                            1328
# favorite_count                                                           4722
# retweeted                                                               False
# stage                                                                  others
#
#                                                                             1
# tweet_id                                                   781661882474196992
# timestamp                                           2016-09-30 01:08:10 +0000
# source                                     http://twitter.com/download/iphone
# text                        Who keeps sending in pictures without dogs in ...
# retweeted_status_id                                                       NaN
# retweeted_status_user_id                                                  NaN
# retweeted_status_timestamp                                                NaN
# rating_numerator                                                            5
# rating_denominator                                                         10
# name                                                                     None
# nb_stage                                                                    0
# retweet_count                                                            3129
# favorite_count                                                          11634
# retweeted                                                               False
# stage                                                                  others

# %% [markdown]
# #### Test

# %%
# Checking that the values of twitter_archive_clean["source"] are links (and no more tags)
twitter_df["source"].unique()
# Out:
# array(['http://twitter.com/download/iphone', 'http://vine.co',
#        'http://twitter.com',
#        'https://about.twitter.com/products/tweetdeck'], dtype=object)

# %% [markdown]
# ### Issue #2 (quality issue): Wrong datatypes in `twitter_archive_df["timestamp"]`
# The datatypes in `twitter_archive_df["timestamp"]` should be datetime, not object(string).
#
# This cleaning is to be performed in `twitter_df`.

# %%
# Recalling the structure of twitter_df
twitter_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2746 entries, 0 to 2745
# Data columns (total 15 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   tweet_id                    2746 non-null   int64
#  1   timestamp                   2746 non-null   object
#  2   source                      2746 non-null   object
#  3   text                        2746 non-null   object
#  4   retweeted_status_id         216 non-null    float64
#  5   retweeted_status_user_id    216 non-null    float64
#  6   retweeted_status_timestamp  216 non-null    object
#  7   rating_numerator            2746 non-null   int64
#  8   rating_denominator          2746 non-null   int64
#  9   name                        2746 non-null   object
#  10  nb_stage                    2746 non-null   int64
#  11  retweet_count               2746 non-null   int64
#  12  favorite_count              2746 non-null   int64
#  13  retweeted                   2746 non-null   bool
#  14  stage                       2746 non-null   object
# dtypes: bool(1), float64(2), int64(6), object(6)
# memory usage: 303.2+ KB

# %% [markdown]
# #### Define
# Convert `twitter_df["timestamp"]` to datetime.

# %% [markdown]
# #### Code

# %%
twitter_df["timestamp"] = pd.to_datetime(twitter_df["timestamp"])

# %% [markdown]
# #### Test

# %%
# Confirming that timestamp column was converted to datetime
twitter_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2746 entries, 0 to 2745
# Data columns (total 15 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   tweet_id                    2746 non-null   int64
#  1   timestamp                   2746 non-null   datetime64[ns, UTC]
#  2   source                      2746 non-null   object
#  3   text                        2746 non-null   object
#  4   retweeted_status_id         216 non-null    float64
#  5   retweeted_status_user_id    216 non-null    float64
#  6   retweeted_status_timestamp  216 non-null    object
#  7   rating_numerator            2746 non-null   int64
#  8   rating_denominator          2746 non-null   int64
#  9   name                        2746 non-null   object
#  10  nb_stage                    2746 non-null   int64
#  11  retweet_count               2746 non-null   int64
#  12  favorite_count              2746 non-null   int64
#  13  retweeted                   2746 non-null   bool
#  14  stage                       2746 non-null   object
# dtypes: bool(1), datetime64[ns, UTC](1), float64(2), int64(6), object(5)
# memory usage: 303.2+ KB

# %% [markdown]
# ### Issue #3 (quality issue): `twitter_archive_df` has retweet samples
#
# Those sample are useless for our purpose (according to the project instructions).
# The cleaning is to be performed in `twitter_df`

# %%
# Taking a look at the retweeted samples
retweeted_mask = ~ twitter_df["retweeted_status_id"].isnull()
twitter_df[ retweeted_mask ].head(2).T
# Out:
#                                                                             6  \
# tweet_id                                                   775898661951791106
# timestamp                                           2016-09-14 03:27:11+00:00
# source                                     http://twitter.com/download/iphone
# text                        RT @dog_rates: Like father (doggo), like son (...
# retweeted_status_id                                      733109485275860992.0
# retweeted_status_user_id                                         4196983835.0
# retweeted_status_timestamp                          2016-05-19 01:38:16 +0000
# rating_numerator                                                           12
# rating_denominator                                                         10
# name                                                                     None
# nb_stage                                                                    2
# retweet_count                                                           17621
# favorite_count                                                              0
# retweeted                                                               False
# stage                                                                  others
#
#                                                                             8
# tweet_id                                                   799308762079035393
# timestamp                                           2016-11-17 17:50:33+00:00
# source                                     http://twitter.com/download/iphone
# text                        RT @dog_rates: I WAS SENT THE ACTUAL DOG IN TH...
# retweeted_status_id                                      774314403806253056.0
# retweeted_status_user_id                                         4196983835.0
# retweeted_status_timestamp                          2016-09-09 18:31:54 +0000
# rating_numerator                                                           14
# rating_denominator                                                         10
# name                                                                     None
# nb_stage                                                                    0
# retweet_count                                                            6478
# favorite_count                                                              0
# retweeted                                                               False
# stage                                                                  others

# %% [markdown]
# #### Define
# * Retrieve retweeted samples in a `retweeted_df` dataframe
# * Drop from `twitter_df` indexes of the samples coming from `retweeted_df`

# %%
retweeted_df = twitter_df[ retweeted_mask ]
retweeted_df.head(5).T
# Out:
#                                                                            6   \
# tweet_id                                                   775898661951791106
# timestamp                                           2016-09-14 03:27:11+00:00
# source                                     http://twitter.com/download/iphone
# text                        RT @dog_rates: Like father (doggo), like son (...
# retweeted_status_id                                      733109485275860992.0
# retweeted_status_user_id                                         4196983835.0
# retweeted_status_timestamp                          2016-05-19 01:38:16 +0000
# rating_numerator                                                           12
# rating_denominator                                                         10
# name                                                                     None
# nb_stage                                                                    2
# retweet_count                                                           17621
# favorite_count                                                              0
# retweeted                                                               False
# stage                                                                  others
#
#                                                                            8   \
# tweet_id                                                   799308762079035393
# timestamp                                           2016-11-17 17:50:33+00:00
# source                                     http://twitter.com/download/iphone
# text                        RT @dog_rates: I WAS SENT THE ACTUAL DOG IN TH...
# retweeted_status_id                                      774314403806253056.0
# retweeted_status_user_id                                         4196983835.0
# retweeted_status_timestamp                          2016-09-09 18:31:54 +0000
# rating_numerator                                                           14
# rating_denominator                                                         10
# name                                                                     None
# nb_stage                                                                    0
# retweet_count                                                            6478
# favorite_count                                                              0
# retweeted                                                               False
# stage                                                                  others
#
#                                                                            14  \
# tweet_id                                                   776249906839351296
# timestamp                                           2016-09-15 02:42:54+00:00
# source                                     http://twitter.com/download/iphone
# text                        RT @dog_rates: We only rate dogs. Pls stop sen...
# retweeted_status_id                                      700747788515020800.0
# retweeted_status_user_id                                         4196983835.0
# retweeted_status_timestamp                          2016-02-19 18:24:26 +0000
# rating_numerator                                                           11
# rating_denominator                                                         10
# name                                                                     very
# nb_stage                                                                    0
# retweet_count                                                           10673
# favorite_count                                                              0
# retweeted                                                               False
# stage                                                                  others
#
#                                                                            17  \
# tweet_id                                                   840728873075638272
# timestamp                                           2017-03-12 00:59:17+00:00
# source                                     http://twitter.com/download/iphone
# text                        RT @dog_rates: This is Pipsy. He is a fluffbal...
# retweeted_status_id                                      667152164079423488.0
# retweeted_status_user_id                                         4196983835.0
# retweeted_status_timestamp                          2015-11-19 01:27:25 +0000
# rating_numerator                                                           12
# rating_denominator                                                         10
# name                                                                    Pipsy
# nb_stage                                                                    0
# retweet_count                                                           18285
# favorite_count                                                              0
# retweeted                                                               False
# stage                                                                  others
#
#                                                                            18
# tweet_id                                                   817181837579653120
# timestamp                                           2017-01-06 01:31:47+00:00
# source                                     http://twitter.com/download/iphone
# text                        RT @dog_rates: Here's a pupper with squeaky hi...
# retweeted_status_id                                      815966073409433600.0
# retweeted_status_user_id                                         4196983835.0
# retweeted_status_timestamp                          2017-01-02 17:00:46 +0000
# rating_numerator                                                           13
# rating_denominator                                                         10
# name                                                                     None
# nb_stage                                                                    1
# retweet_count                                                            9907
# favorite_count                                                              0
# retweeted                                                               False
# stage                                                                  others

# %%
retweeted_indexes = retweeted_df.index
retweeted_indexes
# Out:
# Int64Index([   6,    8,   14,   17,   18,   26,   31,   55,   67,   77,
#             ...
#             2591, 2593, 2599, 2630, 2632, 2635, 2675, 2706, 2710, 2714],
#            dtype='int64', length=216)

# %%
twitter_df.shape
# Out:
# (2746, 15)

# %%
# Drop samples which are retweets
twitter_df.drop(retweeted_indexes, axis=0,inplace=True)

# %%
twitter_df.shape
# Out:
# (2530, 15)

# %% [markdown]
# We also have a `retweeted` column, which is no more useful.

# %%
twitter_df["retweeted"].unique()
# Out:
# array([False])

# %% [markdown]
# We will drop `retweeted` column, because it become useless since we know that we don't have any retweeted sample.

# %%
twitter_df.drop(["retweeted"], axis=1,inplace=True)

# %%
twitter_df.shape
# Out:
# (2530, 14)

# %% [markdown]
# #### Test

# %%
# Making sure there is no more retweet samples
twitter_df[ retweeted_mask ]
# Out:
# <ipython-input-113-e327e61058bd>:2: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   twitter_df[ retweeted_mask ]
# Empty DataFrame
# Columns: [tweet_id, timestamp, source, text, retweeted_status_id, retweeted_status_user_id, retweeted_status_timestamp, rating_numerator, rating_denominator, name, nb_stage, retweet_count, favorite_count, stage]
# Index: []

# %% [markdown]
# ### Issue #4 (quality issue): Null values in many columns in `twitter_archive_df`
#
# Null values in the `retweeted_XXXX` columns following columns of `twitter_archive_df`
#
# The cleaning is to be performed in `twitter_df`.

# %%
# Recalling the structure of twitter_archive_clean
twitter_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2530 entries, 0 to 2745
# Data columns (total 14 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   tweet_id                    2530 non-null   int64
#  1   timestamp                   2530 non-null   datetime64[ns, UTC]
#  2   source                      2530 non-null   object
#  3   text                        2530 non-null   object
#  4   retweeted_status_id         0 non-null      float64
#  5   retweeted_status_user_id    0 non-null      float64
#  6   retweeted_status_timestamp  0 non-null      object
#  7   rating_numerator            2530 non-null   int64
#  8   rating_denominator          2530 non-null   int64
#  9   name                        2530 non-null   object
#  10  nb_stage                    2530 non-null   int64
#  11  retweet_count               2530 non-null   int64
#  12  favorite_count              2530 non-null   int64
#  13  stage                       2530 non-null   object
# dtypes: datetime64[ns, UTC](1), float64(2), int64(6), object(5)
# memory usage: 296.5+ KB

# %% [markdown]
# #### Define
# Drop the `retweeted_XXXX` columns

# %% [markdown]
# #### Code

# %%
useless_columns=["retweeted_status_id","retweeted_status_user_id","retweeted_status_timestamp"]
twitter_df.drop(useless_columns, axis=1, inplace=True)

# %% [markdown]
# #### Test

# %%
twitter_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2530 entries, 0 to 2745
# Data columns (total 11 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   tweet_id            2530 non-null   int64
#  1   timestamp           2530 non-null   datetime64[ns, UTC]
#  2   source              2530 non-null   object
#  3   text                2530 non-null   object
#  4   rating_numerator    2530 non-null   int64
#  5   rating_denominator  2530 non-null   int64
#  6   name                2530 non-null   object
#  7   nb_stage            2530 non-null   int64
#  8   retweet_count       2530 non-null   int64
#  9   favorite_count      2530 non-null   int64
#  10  stage               2530 non-null   object
# dtypes: datetime64[ns, UTC](1), int64(6), object(4)
# memory usage: 237.2+ KB

# %% [markdown]
# ### Issue #6 (quality issue): Date beyond August 1st, 2017, in `tweets_df`
#
# We will drop the samples with those dates, based on the project specification.
#
#
# The cleaning is to be performed in `twitter_df`.

# %%
twitter_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2530 entries, 0 to 2745
# Data columns (total 11 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   tweet_id            2530 non-null   int64
#  1   timestamp           2530 non-null   datetime64[ns, UTC]
#  2   source              2530 non-null   object
#  3   text                2530 non-null   object
#  4   rating_numerator    2530 non-null   int64
#  5   rating_denominator  2530 non-null   int64
#  6   name                2530 non-null   object
#  7   nb_stage            2530 non-null   int64
#  8   retweet_count       2530 non-null   int64
#  9   favorite_count      2530 non-null   int64
#  10  stage               2530 non-null   object
# dtypes: datetime64[ns, UTC](1), int64(6), object(4)
# memory usage: 237.2+ KB

# %%
# Observing the samples beyond August 1st, 2017
beyond_date_mask = twitter_df["timestamp"] >= "2017-08-01"
useless_tweets = twitter_df[ beyond_date_mask ]
useless_tweets.shape
# Out:
# (2, 11)

# %%
useless_tweets.T
# Out:
#                                                                  781   \
# tweet_id                                           892420643555336193
# timestamp                                   2017-08-01 16:23:56+00:00
# source                             http://twitter.com/download/iphone
# text                This is Phineas. He's a mystical boy. Only eve...
# rating_numerator                                                   13
# rating_denominator                                                 10
# name                                                          Phineas
# nb_stage                                                            0
# retweet_count                                                    8853
# favorite_count                                                  39467
# stage                                                          others
#
#                                                                  2533
# tweet_id                                           892177421306343426
# timestamp                                   2017-08-01 00:17:27+00:00
# source                             http://twitter.com/download/iphone
# text                This is Tilly. She's just checking pup on you....
# rating_numerator                                                   13
# rating_denominator                                                 10
# name                                                            Tilly
# nb_stage                                                            0
# retweet_count                                                    6514
# favorite_count                                                  33819
# stage                                                          others

# %% [markdown]
# #### Define
#
# Drop the samples beyond August 1st, 2017

# %% [markdown]
# #### Code

# %%
useless_tweets.index
# Out:
# Int64Index([781, 2533], dtype='int64')

# %%
twitter_df.shape
# Out:
# (2530, 11)

# %%
twitter_df.drop(useless_tweets.index, axis=0,inplace=True)
twitter_df.shape
# Out:
# (2528, 11)

# %% [markdown]
# #### Test

# %%
twitter_df[ beyond_date_mask ]
# Out:
# <ipython-input-123-984fc2dbf993>:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   twitter_df[ beyond_date_mask ]
# Empty DataFrame
# Columns: [tweet_id, timestamp, source, text, rating_numerator, rating_denominator, name, nb_stage, retweet_count, favorite_count, stage]
# Index: []

# %% [markdown]
# ### Issue #7 (quality issue) : Some samples in `image_predictions_df` are not dog

# %%
image_predictions_clean.head(2).T
# Out:
#                                                         0  \
# tweet_id                               666020888022790149
# jpg_url   https://pbs.twimg.com/media/CT4udn0WwAA0aMy.jpg
# img_num                                                 1
# p1                                 Welsh_springer_spaniel
# p1_conf                                          0.465074
# p1_dog                                               True
# p2                                                 collie
# p2_conf                                          0.156665
# p2_dog                                               True
# p3                                      Shetland_sheepdog
# p3_conf                                          0.061428
# p3_dog                                               True
#
#                                                         1
# tweet_id                               666029285002620928
# jpg_url   https://pbs.twimg.com/media/CT42GRgUYAA5iDo.jpg
# img_num                                                 1
# p1                                                redbone
# p1_conf                                          0.506826
# p1_dog                                               True
# p2                                     miniature_pinscher
# p2_conf                                          0.074192
# p2_dog                                               True
# p3                                    Rhodesian_ridgeback
# p3_conf                                           0.07201
# p3_dog                                               True

# %%
image_predictions_clean.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2075 entries, 0 to 2074
# Data columns (total 12 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   tweet_id  2075 non-null   int64
#  1   jpg_url   2075 non-null   object
#  2   img_num   2075 non-null   int64
#  3   p1        2075 non-null   object
#  4   p1_conf   2075 non-null   float64
#  5   p1_dog    2075 non-null   bool
#  6   p2        2075 non-null   object
#  7   p2_conf   2075 non-null   float64
#  8   p2_dog    2075 non-null   bool
#  9   p3        2075 non-null   object
#  10  p3_conf   2075 non-null   float64
#  11  p3_dog    2075 non-null   bool
# dtypes: bool(3), float64(3), int64(2), object(4)
# memory usage: 152.1+ KB

# %%
image_predictions_clean["p1_dog"].unique()
# Out:
# array([ True, False])

# %% [markdown]
# #### Define
# Only keep samples which has True as value in `p1_dog` (the prediction with the highest confidence)

# %% [markdown]
# #### Code

# %%
image_predictions_clean.shape
# Out:
# (2075, 12)

# %%
image_predictions_clean = image_predictions_clean[ image_predictions_clean["p1_dog"]==True ]
image_predictions_clean.shape
# Out:
# (1532, 12)

# %% [markdown]
# #### Test

# %% [markdown]
# We will make sure that all predictions are True, in `p1_dog`

# %%
image_predictions_clean["p1_dog"].unique()
# Out:
# array([ True])

# %% [markdown]
# ### Issue #8 (quality issue) : Some values are capitalized while others are not in columns `p1`, `p2`, and `p3` of `image_predictions_df`

# %%
image_predictions_clean.head().T
# Out:
#                                                         0  \
# tweet_id                               666020888022790149
# jpg_url   https://pbs.twimg.com/media/CT4udn0WwAA0aMy.jpg
# img_num                                                 1
# p1                                 Welsh_springer_spaniel
# p1_conf                                          0.465074
# p1_dog                                               True
# p2                                                 collie
# p2_conf                                          0.156665
# p2_dog                                               True
# p3                                      Shetland_sheepdog
# p3_conf                                          0.061428
# p3_dog                                               True
#
#                                                         1  \
# tweet_id                               666029285002620928
# jpg_url   https://pbs.twimg.com/media/CT42GRgUYAA5iDo.jpg
# img_num                                                 1
# p1                                                redbone
# p1_conf                                          0.506826
# p1_dog                                               True
# p2                                     miniature_pinscher
# p2_conf                                          0.074192
# p2_dog                                               True
# p3                                    Rhodesian_ridgeback
# p3_conf                                           0.07201
# p3_dog                                               True
#
#                                                         2  \
# tweet_id                               666033412701032449
# jpg_url   https://pbs.twimg.com/media/CT4521TWwAEvMyu.jpg
# img_num                                                 1
# p1                                        German_shepherd
# p1_conf                                          0.596461
# p1_dog                                               True
# p2                                               malinois
# p2_conf                                          0.138584
# p2_dog                                               True
# p3                                             bloodhound
# p3_conf                                          0.116197
# p3_dog                                               True
#
#                                                         3  \
# tweet_id                               666044226329800704
# jpg_url   https://pbs.twimg.com/media/CT5Dr8HUEAA-lEu.jpg
# img_num                                                 1
# p1                                    Rhodesian_ridgeback
# p1_conf                                          0.408143
# p1_dog                                               True
# p2                                                redbone
# p2_conf                                          0.360687
# p2_dog                                               True
# p3                                     miniature_pinscher
# p3_conf                                          0.222752
# p3_dog                                               True
#
#                                                         4
# tweet_id                               666049248165822465
# jpg_url   https://pbs.twimg.com/media/CT5IQmsXIAAKY4A.jpg
# img_num                                                 1
# p1                                     miniature_pinscher
# p1_conf                                          0.560311
# p1_dog                                               True
# p2                                             Rottweiler
# p2_conf                                          0.243682
# p2_dog                                               True
# p3                                               Doberman
# p3_conf                                          0.154629
# p3_dog                                               True

# %% [markdown]
# #### Define
#
# Capitalize the first letter of each value in `p1`, `p2` and `p3`.

# %%
image_predictions_clean["p1"] = image_predictions_clean["p1"].str.capitalize()
image_predictions_clean["p2"] = image_predictions_clean["p2"].str.capitalize()
image_predictions_clean["p3"] = image_predictions_clean["p3"].str.capitalize()

# %% [markdown]
# #### Test

# %%
image_predictions_clean.head().T
# Out:
#                                                         0  \
# tweet_id                               666020888022790149
# jpg_url   https://pbs.twimg.com/media/CT4udn0WwAA0aMy.jpg
# img_num                                                 1
# p1                                 Welsh_springer_spaniel
# p1_conf                                          0.465074
# p1_dog                                               True
# p2                                                 Collie
# p2_conf                                          0.156665
# p2_dog                                               True
# p3                                      Shetland_sheepdog
# p3_conf                                          0.061428
# p3_dog                                               True
#
#                                                         1  \
# tweet_id                               666029285002620928
# jpg_url   https://pbs.twimg.com/media/CT42GRgUYAA5iDo.jpg
# img_num                                                 1
# p1                                                Redbone
# p1_conf                                          0.506826
# p1_dog                                               True
# p2                                     Miniature_pinscher
# p2_conf                                          0.074192
# p2_dog                                               True
# p3                                    Rhodesian_ridgeback
# p3_conf                                           0.07201
# p3_dog                                               True
#
#                                                         2  \
# tweet_id                               666033412701032449
# jpg_url   https://pbs.twimg.com/media/CT4521TWwAEvMyu.jpg
# img_num                                                 1
# p1                                        German_shepherd
# p1_conf                                          0.596461
# p1_dog                                               True
# p2                                               Malinois
# p2_conf                                          0.138584
# p2_dog                                               True
# p3                                             Bloodhound
# p3_conf                                          0.116197
# p3_dog                                               True
#
#                                                         3  \
# tweet_id                               666044226329800704
# jpg_url   https://pbs.twimg.com/media/CT5Dr8HUEAA-lEu.jpg
# img_num                                                 1
# p1                                    Rhodesian_ridgeback
# p1_conf                                          0.408143
# p1_dog                                               True
# p2                                                Redbone
# p2_conf                                          0.360687
# p2_dog                                               True
# p3                                     Miniature_pinscher
# p3_conf                                          0.222752
# p3_dog                                               True
#
#                                                         4
# tweet_id                               666049248165822465
# jpg_url   https://pbs.twimg.com/media/CT5IQmsXIAAKY4A.jpg
# img_num                                                 1
# p1                                     Miniature_pinscher
# p1_conf                                          0.560311
# p1_dog                                               True
# p2                                             Rottweiler
# p2_conf                                          0.243682
# p2_dog                                               True
# p3                                               Doberman
# p3_conf                                          0.154629
# p3_dog                                               True

# %% [markdown]
# ### Issue #9 (quality) : only the most confident prediction is relevant in `image_predictions_df`

# %% [markdown]
# #### Define
# * In `image_predictions_df`, only keep the following columns : `tweet_id, jpg_url, img_num, p1`
# * Rename `p1` to `breed`

# %% [markdown]
# #### Code

# %%
image_predictions_clean = image_predictions_clean[ ["tweet_id","jpg_url","img_num","p1"] ]

image_predictions_clean.rename(columns={
    "p1":"breed"
},inplace=True)

# %% [markdown]
# #### Test

# %%
image_predictions_clean.head()
# Out:
#              tweet_id                                          jpg_url  \
# 0  666020888022790149  https://pbs.twimg.com/media/CT4udn0WwAA0aMy.jpg
# 1  666029285002620928  https://pbs.twimg.com/media/CT42GRgUYAA5iDo.jpg
# 2  666033412701032449  https://pbs.twimg.com/media/CT4521TWwAEvMyu.jpg
# 3  666044226329800704  https://pbs.twimg.com/media/CT5Dr8HUEAA-lEu.jpg
# 4  666049248165822465  https://pbs.twimg.com/media/CT5IQmsXIAAKY4A.jpg
#
#    img_num                   breed
# 0        1  Welsh_springer_spaniel
# 1        1                 Redbone
# 2        1         German_shepherd
# 3        1     Rhodesian_ridgeback
# 4        1      Miniature_pinscher

# %% [markdown]
# ### Issue #5 (tidiness) : `twitter_archive_df` and `image_predictions_df` should form one dataframe instead being two different dataframes

# %% [markdown]
# #### Define
# Merge `twitter_df` to `image_predictions_df`

# %% [markdown]
# #### Code

# %%
twitter_df.shape
# Out:
# (2528, 11)

# %%
image_predictions_clean.shape
# Out:
# (1532, 4)

# %%
# https://stackoverflow.com/questions/43297589/merge-two-data-frames-based-on-common-column-values-in-pandas

tweets_master_df = twitter_df.merge(image_predictions_clean, how="left", left_on="tweet_id", right_on="tweet_id")
tweets_master_df.shape
# Out:
# (2528, 14)

# %% [markdown]
# #### Test

# %%
tweets_master_df.head(3).T
# Out:
#                                                                     0  \
# tweet_id                                           728046963732717569
# timestamp                                   2016-05-05 02:21:37+00:00
# source                             http://twitter.com/download/iphone
# text                This is Raymond. He controls fountains with hi...
# rating_numerator                                                   11
# rating_denominator                                                 10
# name                                                          Raymond
# nb_stage                                                            0
# retweet_count                                                    1328
# favorite_count                                                   4722
# stage                                                          others
# jpg_url               https://pbs.twimg.com/media/ChqK2cVWMAAE5Zj.jpg
# img_num                                                           1.0
# breed                                                    Newfoundland
#
#                                                                     1  \
# tweet_id                                           781661882474196992
# timestamp                                   2016-09-30 01:08:10+00:00
# source                             http://twitter.com/download/iphone
# text                Who keeps sending in pictures without dogs in ...
# rating_numerator                                                    5
# rating_denominator                                                 10
# name                                                             None
# nb_stage                                                            0
# retweet_count                                                    3129
# favorite_count                                                  11634
# stage                                                          others
# jpg_url               https://pbs.twimg.com/media/CtkFS72WcAAiUrs.jpg
# img_num                                                           1.0
# breed                                                        Pembroke
#
#                                                                     2
# tweet_id                                           745057283344719872
# timestamp                                   2016-06-21 00:54:33+00:00
# source                             http://twitter.com/download/iphone
# text                This is Oliver. He's downright gorgeous as hel...
# rating_numerator                                                   12
# rating_denominator                                                 10
# name                                                           Oliver
# nb_stage                                                            0
# retweet_count                                                    2585
# favorite_count                                                   7945
# stage                                                          others
# jpg_url               https://pbs.twimg.com/media/Clb5pLJWMAE-QS1.jpg
# img_num                                                           2.0
# breed                                               Shetland_sheepdog

# %% [markdown]
# <a href="storing"> </a>
#
# ## Storing Data
# Save gathered, assessed, and cleaned master dataset to a CSV file named "twitter_archive_master.csv".

# %%
tweets_master_df.to_csv("twitter_archive_master.csv",index=False)
#image_predictions_clean.to_csv("image_predictions_master.csv")

# %% [markdown]
# <a href="analyzing-visualizing"> </a>
#
# ## Analyzing and Visualizing Data
#
# I am going to explore the dataset to gain some insights to understand how the dogs are usually rated in [WeRateDogs](https://en.wikipedia.org/wiki/WeRateDogs). In particular, I will be interested to know :
#
# 1. How does the popularity of WeRateDogs evolved over the years ?
# 1. If a particular dog's stage is more likely to raise higher level of interest ?
# 1. If a particular dog's stage is more likely to be loved ?
# 1. If there is a relationship between the level of interest and the score ?
# 1. If the ratings are influenced by the posting period (morning, miday, evening, afternoon, ...) ?
# 1. If the number of images associated wih a post help increase its rating ?
# 1. If a particular dog's breed is more likely to be loved ?

# %% [markdown]
# ### Getting an overview of our data

# %%
# Taking a look at our dataframe
tweets_master_df.head(3).T
# Out:
#                                                                     0  \
# tweet_id                                           728046963732717569
# timestamp                                   2016-05-05 02:21:37+00:00
# source                             http://twitter.com/download/iphone
# text                This is Raymond. He controls fountains with hi...
# rating_numerator                                                   11
# rating_denominator                                                 10
# name                                                          Raymond
# nb_stage                                                            0
# retweet_count                                                    1328
# favorite_count                                                   4722
# stage                                                          others
# jpg_url               https://pbs.twimg.com/media/ChqK2cVWMAAE5Zj.jpg
# img_num                                                           1.0
# breed                                                    Newfoundland
#
#                                                                     1  \
# tweet_id                                           781661882474196992
# timestamp                                   2016-09-30 01:08:10+00:00
# source                             http://twitter.com/download/iphone
# text                Who keeps sending in pictures without dogs in ...
# rating_numerator                                                    5
# rating_denominator                                                 10
# name                                                             None
# nb_stage                                                            0
# retweet_count                                                    3129
# favorite_count                                                  11634
# stage                                                          others
# jpg_url               https://pbs.twimg.com/media/CtkFS72WcAAiUrs.jpg
# img_num                                                           1.0
# breed                                                        Pembroke
#
#                                                                     2
# tweet_id                                           745057283344719872
# timestamp                                   2016-06-21 00:54:33+00:00
# source                             http://twitter.com/download/iphone
# text                This is Oliver. He's downright gorgeous as hel...
# rating_numerator                                                   12
# rating_denominator                                                 10
# name                                                           Oliver
# nb_stage                                                            0
# retweet_count                                                    2585
# favorite_count                                                   7945
# stage                                                          others
# jpg_url               https://pbs.twimg.com/media/Clb5pLJWMAE-QS1.jpg
# img_num                                                           2.0
# breed                                               Shetland_sheepdog

# %%
tweets_master_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2528 entries, 0 to 2527
# Data columns (total 14 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   tweet_id            2528 non-null   int64
#  1   timestamp           2528 non-null   datetime64[ns, UTC]
#  2   source              2528 non-null   object
#  3   text                2528 non-null   object
#  4   rating_numerator    2528 non-null   int64
#  5   rating_denominator  2528 non-null   int64
#  6   name                2528 non-null   object
#  7   nb_stage            2528 non-null   int64
#  8   retweet_count       2528 non-null   int64
#  9   favorite_count      2528 non-null   int64
#  10  stage               2528 non-null   object
#  11  jpg_url             1713 non-null   object
#  12  img_num             1713 non-null   float64
#  13  breed               1713 non-null   object
# dtypes: datetime64[ns, UTC](1), float64(1), int64(6), object(6)
# memory usage: 296.2+ KB

# %%
# Making sure there is no duplicate tweet
tweets_master_df["tweet_id"].value_counts()
# Out:
# 785639753186217984    3
# 802265048156610565    3
# 733109485275860992    3
# 741067306818797568    3
# 751583847268179968    3
#                      ..
# 838476387338051585    1
# 808838249661788160    1
# 667073648344346624    1
# 707610948723478529    1
# 676146341966438401    1
# Name: tweet_id, Length: 2173, dtype: int64

# %%
# #### Feature engineering

# We will extract relevant features for our analysis below

# %% [markdown]
# <a href="eda"> </a>
#
# ### Exploratory Data Analysis

# %% [markdown]
# #### How does the popularity of WeRateDogs evolved over the years ?
#
# We will explore how the post's count evolved over the years.

# %%
# Extracting the year for each tweet

# Reference : https://www.interviewqs.com/ddi-code-snippets/extract-month-year-pandas

tweets_master_df["year"] = pd.DatetimeIndex(tweets_master_df["timestamp"]).year
tweets_master_df.sample(3).T
# Out:
#                                                                  2523  \
# tweet_id                                           787322443945877504
# timestamp                                   2016-10-15 16:01:13+00:00
# source                             http://twitter.com/download/iphone
# text                This is Lincoln. He forgot to use his blinker ...
# rating_numerator                                                   10
# rating_denominator                                                 10
# name                                                          Lincoln
# nb_stage                                                            0
# retweet_count                                                    2032
# favorite_count                                                   8726
# stage                                                          others
# jpg_url                                                           NaN
# img_num                                                           NaN
# breed                                                             NaN
# year                                                             2016
#
#                                                                  427   \
# tweet_id                                           749417653287129088
# timestamp                                   2016-07-03 01:41:06+00:00
# source                             http://twitter.com/download/iphone
# text                This is Finn. He's the most unphotogenic puppe...
# rating_numerator                                                   11
# rating_denominator                                                 10
# name                                                             Finn
# nb_stage                                                            1
# retweet_count                                                    1904
# favorite_count                                                   6721
# stage                                                          others
# jpg_url               https://pbs.twimg.com/media/CmZ3YH9WEAAowi3.jpg
# img_num                                                           2.0
# breed                                                        Papillon
# year                                                             2016
#
#                                                                  484
# tweet_id                                           881633300179243008
# timestamp                                   2017-07-02 21:58:53+00:00
# source                             http://twitter.com/download/iphone
# text                @roushfenway These are good dogs but 17/10 is ...
# rating_numerator                                                   17
# rating_denominator                                                 10
# name                                                             None
# nb_stage                                                            0
# retweet_count                                                       7
# favorite_count                                                    129
# stage                                                          others
# jpg_url                                                           NaN
# img_num                                                           NaN
# breed                                                             NaN
# year                                                             2017

# %%
# Taking a look at the years in our dataframe
tweets_master_df["year"].unique()
# Out:
# array([2016, 2015, 2017], dtype=int64)

# %%
# Counting the number of post per year
tweets_count_per_year = tweets_master_df["year"].value_counts().sort_index()
tweets_count_per_year
# Out:
# 2015     754
# 2016    1310
# 2017     464
# Name: year, dtype: int64

# %%
tweets_count_per_year.plot(kind="bar",figsize=(8,6))

plt.xlabel("Tweet's years")
plt.ylabel("Tweet's count")
plt.title("Tweet's count per years");

# %% [markdown]
# Our dataset span over to little years to make a good observation about how the tweets evolved over the years, so we cannot know how the interest generated by [@dog_rates](https://twitter.com/dog_rates) account evolved over the year .
# But we can still observe that [@WeRateDogs](https://twitter.com/dog_rates) have a high increase of tweets in 2016 compared to 2015 and 2017. This can be explained by the viral tweet [they're good dogs Brent](http://knowyourmeme.com/memes/theyre-good-dogs-brent) which happen on September 2016.

# %% [markdown]
# #### Is a particular dog's stage more likely to raise higher level of interest ?
#
# In order to have an answer for this question, we will explore the relationship between the dog's stages and the retweets count's mean.
#
# We will first be interested in total number of retweet count of each stage.

# %%
# Number of retweets count per dog's stage
retweets_per_stage_count = tweets_master_df[ ["stage","retweet_count"] ].groupby("stage").sum() \
                                                                    .loc[:,"retweet_count"]  \
                                                                    .sort_values(ascending=False)
retweets_per_stage_count
# Out:
# stage
# others     5983255
# pupper      590242
# doggo       519304
# puppo       171176
# floofer      40836
# Name: retweet_count, dtype: int64

# %%
# Plot the number of retweets count per dog's stage
retweets_per_stage_count.plot(kind="bar", figsize=(8,6))

plt.xlabel("Dog's stages")
plt.ylabel("Retweets count")
plt.title("Retweets count per dog's stages");

# %% [markdown]
# Putting aside the dogs of unknown stage, we can observe that dogs with higher retweets count are either pupper or doggo, while puppo and floofer are not represented as much as the first two stages.
#
# In order to make an objective comparison between stages, we will use the mean as a metric chart. For a better observation, we will drop the results of unknown dog's stages.

# %%
retweets_per_stage_count.drop("others").plot(kind="pie", 
                                             autopct='%1.1f%%',
                                             explode=[0.01, 0.01,0.01,0.01,],
                                             figsize=(8,8),
                                             legend=True
                                            )

plt.ylabel("Retweets count")
plt.title("Level of interested raised by each dog's stages");

# %% [markdown]
# The above chart let us easily confirm that majority of interest are raised either by doggo or pupper.

# %% [markdown]
# We will now analyze the proportion in order to confirm our finding, since our previous result may have be misleaded by the fact that there is more post on a specific dog's stage.

# %%
# Retweets count's mean per dog's stage
retweets_per_stage = tweets_master_df[ ["stage","retweet_count"] ].groupby("stage").mean() \
                                                                    .loc[:,"retweet_count"]  \
                                                                    .sort_values(ascending=False)
retweets_per_stage
# Out:
# stage
# puppo      6847.040000
# doggo      6038.418605
# floofer    4083.600000
# others     2753.453751
# pupper     2522.401709
# Name: retweet_count, dtype: float64

# %%
retweets_per_stage.plot(kind="pie", 
                        autopct='%1.1f%%',
                        explode=[0.01, 0.01,0.01,0.01,0.01],
                        figsize=(8,8),
                        legend=True
                        )

plt.ylabel("Retweets count's mean")
plt.title("Level of interested raised by each dog's stages");

# %% [markdown]
# We can safely conclude that puppo and doggo raise a larger level of interest, followed by floofer.

# %% [markdown]
# #### Is a particular dog's stage most likely to be loved ?
#
# We will explore the relationship between the dog's stages and the score.

# %%
tweets_master_df.sample(3).T
# Out:
#                                                                  52    \
# tweet_id                                           879862464715927552
# timestamp                                   2017-06-28 00:42:13+00:00
# source                             http://twitter.com/download/iphone
# text                This is Romeo. He would like to do an entrance...
# rating_numerator                                                   13
# rating_denominator                                                 10
# name                                                            Romeo
# nb_stage                                                            0
# retweet_count                                                    3642
# favorite_count                                                  22667
# stage                                                          others
# jpg_url               https://pbs.twimg.com/media/DDXmPrbWAAEKMvy.jpg
# img_num                                                           3.0
# breed                                                          Basset
# year                                                             2017
#
#                                                                  2137  \
# tweet_id                                           674764817387900928
# timestamp                                   2015-12-10 01:37:23+00:00
# source                             http://twitter.com/download/iphone
# text                These two pups are masters of camouflage. Very...
# rating_numerator                                                   10
# rating_denominator                                                 10
# name                                                             None
# nb_stage                                                            0
# retweet_count                                                     263
# favorite_count                                                    852
# stage                                                          others
# jpg_url               https://pbs.twimg.com/media/CV0_BSuWIAIvE9k.jpg
# img_num                                                           2.0
# breed                                                         Samoyed
# year                                                             2015
#
#                                                                  17
# tweet_id                                           674638615994089473
# timestamp                                   2015-12-09 17:15:54+00:00
# source                             http://twitter.com/download/iphone
# text                This pupper is fed up with being tickled. 12/1...
# rating_numerator                                                   12
# rating_denominator                                                 10
# name                                                             None
# nb_stage                                                            1
# retweet_count                                                     650
# favorite_count                                                   1806
# stage                                                          others
# jpg_url               https://pbs.twimg.com/media/CVzMPh1UsAELQ_p.jpg
# img_num                                                           1.0
# breed                                                      Pomeranian
# year                                                             2015

# %%
tweets_master_df["rating_denominator"].unique()
# Out:
# array([ 10,  50,   2, 120,   7, 110,  40,  80,  70,  16,   0,  20,  90,
#         11, 170, 150,  15, 130], dtype=int64)

# %%
tweets_master_df["rating_denominator"].value_counts()
# Out:
# 10     2506
# 50        3
# 11        2
# 20        2
# 80        2
# 0         1
# 120       1
# 7         1
# 170       1
# 150       1
# 130       1
# 90        1
# 110       1
# 2         1
# 70        1
# 40        1
# 16        1
# 15        1
# Name: rating_denominator, dtype: int64

# %% [markdown]
# We can observe that nearly all ratings denominator are 10.

# %%
tweets_master_df["rating_numerator"].unique()
# Out:
# array([  11,    5,   12,   10,   13,    6,    8,    7,    9,    3,   45,
#           1,   27,   14,    0,    4,  666,  144,    2, 1776,   75,   17,
#          24,   26,  121,   44,   88,   84,   15,   20,   80,  960,   99,
#         182,  204,  165,   60,  420,   50,  143], dtype=int64)

# %%
tweets_master_df["rating_numerator"].value_counts()
# Out:
# 12      592
# 10      508
# 11      506
# 13      360
# 9       173
# 8       113
# 7        62
# 14       59
# 5        39
# 6        33
# 3        20
# 4        17
# 2         9
# 1         8
# 0         2
# 27        2
# 420       2
# 144       1
# 26        1
# 143       1
# 121       1
# 99        1
# 75        1
# 45        1
# 20        1
# 17        1
# 15        1
# 24        1
# 44        1
# 182       1
# 50        1
# 60        1
# 80        1
# 84        1
# 1776      1
# 960       1
# 666       1
# 88        1
# 204       1
# 165       1
# Name: rating_numerator, dtype: int64

# %% [markdown]
# Our quick search over the net to understand the meaning behing the dogs rating was unsuccessful. So we will not work on the meaning behind the numerator/denomitor, but on the basis of the rating value itself.

# %%
tweets_master_df["rating"] = tweets_master_df["rating_numerator"] / tweets_master_df["rating_denominator"]
tweets_master_df.sample(3).T
# Out:
#                                                                  1438  \
# tweet_id                                           710117014656950272
# timestamp                                   2016-03-16 14:54:24+00:00
# source                             http://twitter.com/download/iphone
# text                This pupper got her hair chalked for her birth...
# rating_numerator                                                   11
# rating_denominator                                                 10
# name                                                             None
# nb_stage                                                            1
# retweet_count                                                    2233
# favorite_count                                                   5999
# stage                                                          pupper
# jpg_url               https://pbs.twimg.com/media/CdrXp9dWoAAcRfn.jpg
# img_num                                                           2.0
# breed                                                      Toy_poodle
# year                                                             2016
# rating                                                            1.1
#
#                                                                  2414  \
# tweet_id                                           757741869644341248
# timestamp                                   2016-07-26 00:58:34+00:00
# source                             http://twitter.com/download/iphone
# text                This is Leonard. He hides in bushes to escape ...
# rating_numerator                                                   10
# rating_denominator                                                 10
# name                                                          Leonard
# nb_stage                                                            0
# retweet_count                                                    3710
# favorite_count                                                   7613
# stage                                                          others
# jpg_url                                                           NaN
# img_num                                                           NaN
# breed                                                             NaN
# year                                                             2016
# rating                                                            1.0
#
#                                                                  1644
# tweet_id                                           684147889187209216
# timestamp                                   2016-01-04 23:02:22+00:00
# source                                                 http://vine.co
# text                This is Sweets the English Bulldog. Waves back...
# rating_numerator                                                   12
# rating_denominator                                                 10
# name                                                           Sweets
# nb_stage                                                            1
# retweet_count                                                    1703
# favorite_count                                                   3265
# stage                                                          pupper
# jpg_url                                                           NaN
# img_num                                                           NaN
# breed                                                             NaN
# year                                                             2016
# rating                                                            1.2

# %% [markdown]
# Let's observe the rating we have in our dataset

# %%
tweets_master_df["rating"].unique()
# Out:
# array([1.10000000e+00, 5.00000000e-01, 1.20000000e+00, 1.00000000e+00,
#        1.30000000e+00, 6.00000000e-01, 8.00000000e-01, 7.00000000e-01,
#        9.00000000e-01, 3.00000000e-01, 2.70000000e+00, 1.40000000e+00,
#        0.00000000e+00, 4.00000000e-01, 6.66000000e+01, 1.00000000e-01,
#        2.00000000e-01, 1.77600000e+02, 7.50000000e+00, 1.70000000e+00,
#        3.42857143e+00, 2.60000000e+00, 1.50000000e+00, 1.25000000e+00,
#                   inf, 8.18181818e-01, 1.82000000e+01, 7.33333333e-01,
#        4.20000000e+01, 6.36363636e-01])

# %%
tweets_master_df["rating"].value_counts()
# Out:
# 1.200000      596
# 1.100000      511
# 1.000000      510
# 1.300000      360
# 0.900000      173
# 0.800000      113
# 0.700000       61
# 1.400000       59
# 0.500000       40
# 0.600000       33
# 0.300000       20
# 0.400000       15
# 0.200000       11
# 0.100000        7
# 2.700000        2
# 0.000000        2
# 42.000000       2
# 3.428571        1
# 0.818182        1
# 66.600000       1
# inf             1
# 2.600000        1
# 18.200000       1
# 1.500000        1
# 7.500000        1
# 1.700000        1
# 177.600000      1
# 0.733333        1
# 1.250000        1
# 0.636364        1
# Name: rating, dtype: int64

# %% [markdown]
# We have `inf` as value in our rating, which mean some of our `rating_denomitor` is 0. We will drop those samples in order to not be stuck when we will do some analysis

# %%
tweets_master_df["rating"].nunique()
# Out:
# 30

# %%
# Drop sample with 0 as value in rating_denomitor
tweets_master_df = tweets_master_df[ tweets_master_df["rating_denominator"]!=0 ]

# %%
# Making sure we don't have inf value anymore
tweets_master_df["rating"].unique()
# Out:
# array([1.10000000e+00, 5.00000000e-01, 1.20000000e+00, 1.00000000e+00,
#        1.30000000e+00, 6.00000000e-01, 8.00000000e-01, 7.00000000e-01,
#        9.00000000e-01, 3.00000000e-01, 2.70000000e+00, 1.40000000e+00,
#        0.00000000e+00, 4.00000000e-01, 6.66000000e+01, 1.00000000e-01,
#        2.00000000e-01, 1.77600000e+02, 7.50000000e+00, 1.70000000e+00,
#        3.42857143e+00, 2.60000000e+00, 1.50000000e+00, 1.25000000e+00,
#        8.18181818e-01, 1.82000000e+01, 7.33333333e-01, 4.20000000e+01,
#        6.36363636e-01])

# %% [markdown]
# Now we will observe how the ratings are distributed based on the dog's stages.

# %%
# Mean rating per dog's stage
mean_rating_per_stage = tweets_master_df.groupby("stage") \
                                         .mean() \
                                         .drop("others")  \
                                        .loc[:,"rating"]  \
                                       .sort_values(ascending=False)

mean_rating_per_stage
# Out:
# stage
# puppo      1.208000
# floofer    1.180000
# doggo      1.175581
# pupper     1.082051
# Name: rating, dtype: float64

# %%
# Plot the mean rating per dog's stage 
mean_rating_per_stage.plot(kind="bar", figsize=(8,4))

plt.xlabel("Dog's stages")
plt.ylabel("Mean rating")
plt.title("Favoritism in rating of a given stage compared to others");

# %% [markdown]
# From this plot, we can observe that the ratings per stage are nearly the same. We can conclude that there is no bias for/against a particular dog stage.
# However, we can see that Puppo tend to a have higher rating compared to other stages, closely followed by Floofer and Doggo.

# %% [markdown]
# #### Is the score influenced by the level of interest ?
#
# We will be interested here by the relationship between the rating and the retweet count.

# %%
tweets_master_df.plot(kind="scatter",x="retweet_count",y="rating")
plt.xlabel("Retweets count")
plt.ylabel("Ratings")
plt.title("Relationship between retweets count and rating");

# %% [markdown]
# There is little linear correlation between the retweets count and the rating. So the ones is not (linearly) influenced by the other.
# We will also check the relationship between favorites count and the rating, to see if the rating is influenced by how much the dog was loved.

# %%
tweets_master_df.plot(kind="scatter",x="favorite_count",y="rating")
plt.xlabel("Favorites count")
plt.ylabel("Ratings")
plt.title("Relationship between favorites count and rating");

# %% [markdown]
# We can also notice that there is no (linear) relationship between the rating and the favorites count.

# %% [markdown]
# Based on the above two plots, we can safely conclude that the rating is not influenced by neither the favorites count nor the retweets count.

# %% [markdown]
# #### Is the ratings influenced by the day period ?
#
# Here, we are trying to determine if the day period (morning, miday, evening, afternoon, ...) somehow has an impact on the ratings.

# %% [markdown]
# Since we are going to work with day periods, we will create a new feature based on our available datas.

# %%
tweets_master_df.head(3).T
# Out:
#                                                                     0  \
# tweet_id                                           728046963732717569
# timestamp                                   2016-05-05 02:21:37+00:00
# source                             http://twitter.com/download/iphone
# text                This is Raymond. He controls fountains with hi...
# rating_numerator                                                   11
# rating_denominator                                                 10
# name                                                          Raymond
# nb_stage                                                            0
# retweet_count                                                    1328
# favorite_count                                                   4722
# stage                                                          others
# jpg_url               https://pbs.twimg.com/media/ChqK2cVWMAAE5Zj.jpg
# img_num                                                           1.0
# breed                                                    Newfoundland
# year                                                             2016
# rating                                                            1.1
#
#                                                                     1  \
# tweet_id                                           781661882474196992
# timestamp                                   2016-09-30 01:08:10+00:00
# source                             http://twitter.com/download/iphone
# text                Who keeps sending in pictures without dogs in ...
# rating_numerator                                                    5
# rating_denominator                                                 10
# name                                                             None
# nb_stage                                                            0
# retweet_count                                                    3129
# favorite_count                                                  11634
# stage                                                          others
# jpg_url               https://pbs.twimg.com/media/CtkFS72WcAAiUrs.jpg
# img_num                                                           1.0
# breed                                                        Pembroke
# year                                                             2016
# rating                                                            0.5
#
#                                                                     2
# tweet_id                                           745057283344719872
# timestamp                                   2016-06-21 00:54:33+00:00
# source                             http://twitter.com/download/iphone
# text                This is Oliver. He's downright gorgeous as hel...
# rating_numerator                                                   12
# rating_denominator                                                 10
# name                                                           Oliver
# nb_stage                                                            0
# retweet_count                                                    2585
# favorite_count                                                   7945
# stage                                                          others
# jpg_url               https://pbs.twimg.com/media/Clb5pLJWMAE-QS1.jpg
# img_num                                                           2.0
# breed                                               Shetland_sheepdog
# year                                                             2016
# rating                                                            1.2

# %%
# tweets_master_df["timestamp"].value_counts()

# %%
tweets_master_df = operate_datetime_feature_engineering(tweets_master_df, datetime_column="timestamp")
tweets_master_df.sample(3).T
# Out:
#                                                                  276   \
# tweet_id                                           719367763014393856
# timestamp                                   2016-04-11 03:33:34+00:00
# source                             http://twitter.com/download/iphone
# text                Meet Sid &amp; Murphy. Murphy floats alongside...
# rating_numerator                                                   11
# rating_denominator                                                 10
# name                                                              Sid
# nb_stage                                                            0
# retweet_count                                                     827
# favorite_count                                                   3022
# stage                                                          others
# jpg_url                                                           NaN
# img_num                                                           NaN
# breed                                                             NaN
# year                                                             2016
# rating                                                            1.1
# month                                                             Apr
# day                                                              Mon
# period                                         Night (after midnight)
#
#                                                                  476   \
# tweet_id                                           699370870310113280
# timestamp                                   2016-02-15 23:13:03+00:00
# source                             http://twitter.com/download/iphone
# text                Say hello to Calbert. He doesn't have enough l...
# rating_numerator                                                   11
# rating_denominator                                                 10
# name                                                          Calbert
# nb_stage                                                            0
# retweet_count                                                     497
# favorite_count                                                   2053
# stage                                                          others
# jpg_url               https://pbs.twimg.com/media/CbSqE0rVIAEOPE4.jpg
# img_num                                                           1.0
# breed                                                           Cairn
# year                                                             2016
# rating                                                            1.1
# month                                                             Feb
# day                                                              Mon
# period                                                  Near Midnight
#
#                                                                  1625
# tweet_id                                           690021994562220032
# timestamp                                   2016-01-21 04:03:58+00:00
# source                             http://twitter.com/download/iphone
# text                Say hello to Geoff (pronounced "Kyle"). He acc...
# rating_numerator                                                   10
# rating_denominator                                                 10
# name                                                            Geoff
# nb_stage                                                            0
# retweet_count                                                    1180
# favorite_count                                                   3056
# stage                                                          others
# jpg_url                                                           NaN
# img_num                                                           NaN
# breed                                                             NaN
# year                                                             2016
# rating                                                            1.0
# month                                                             Jan
# day                                                              Thu
# period                                         Night (after midnight)

# %%
mean_rating_per_period = tweets_master_df.groupby("period")  \
                                         .mean()   \
                                         .loc[:,"rating"]  \
                                         .sort_values(ascending=False)

mean_rating_per_period
# Out:
# period
# Morning                   2.115278
# Afternoon                 1.595168
# Night (start)             1.394315
# Near Midnight             1.153887
# Day Time                  1.111148
# Evening                   1.110914
# Night (after midnight)    1.024976
# Name: rating, dtype: float64

# %% [markdown]
# We can already observe that theoretically, the best period to tweet a dog's post in order to maximize the chance of having a high rating is the Morning, followed by the Afternoon; worst case scenario, the post should be done at the start of Night. A chart will help us better observe the situation.

# %%
mean_rating_per_period.plot(kind="bar", figsize=(8,4))

plt.xlabel("Day period")
plt.ylabel("Mean rating")

plt.title("Mean rating per day period");

# %% [markdown]
# The difference in ratings based on the day period may be related to the availability of the rater, that is to say how much time and care the rater can devote to evaluate the dog before providing a rating.
#
# We have deduced that the day period have impact on the rating. Now we will investigate if the number of images is likely to have an impact on the rating.
#
# <!-- Now we will push our investigation further to see how ratings vary based not only on day period but also the breed. -->

# %% [markdown]
# #### Is the number of images associated wih a post help increase its rating ?
#
# We will investigate the mean rating based on the number of images per tweet.

# %%
# Mean rating per dog images
mean_rating_per_images = tweets_master_df.groupby("img_num")  \
                                         .mean()   \
                                         .loc[:,"rating"]  \
                                         .sort_values(ascending=False)

mean_rating_per_images
# Out:
# img_num
# 4.0    1.240000
# 3.0    1.194781
# 2.0    1.147283
# 1.0    1.092546
# Name: rating, dtype: float64

# %%
# Plot mean rating per dog images
mean_rating_per_images.plot(kind="bar", figsize=(8,4))

plt.xlabel("Tweet images count")
plt.ylabel("Mean rating")
plt.title("Mean rating per tweet images count")
# Out:
# Text(0.5, 1.0, 'Mean rating per tweet images count')

# %% [markdown]
# The number of images doesn't have a **major** impact in the rating given. But they do however have some little effect, since we can observe a slight increase in the mean rating each time the number of images is incremented. So when sending a post on WeRateDog, it is better to join 3-4 good images.

# %% [markdown]
# #### Is a particular breed favored in ratings compared to others ?
#
# We will investigate the mean rating based on the breed in our dataset.

# %%
# Mean rating per breed
mean_rating_per_breed = tweets_master_df.groupby("breed")  \
                                        .mean()  \
                                        .loc[:,"rating"] \
                                        .sort_values(ascending=False)

mean_rating_per_breed
# Out:
# breed
# Clumber                   2.700000
# Pomeranian                1.259574
# Saluki                    1.250000
# Tibetan_mastiff           1.240000
# Briard                    1.240000
#                             ...
# Scotch_terrier            0.900000
# Welsh_springer_spaniel    0.900000
# Ibizan_hound              0.900000
# Walker_hound              0.900000
# Japanese_spaniel          0.500000
# Name: rating, Length: 111, dtype: float64

# %%
# Plot the mean rating per breed
mean_rating_per_breed.plot(kind="bar",figsize=(16,6))

plt.xlabel("Breed")
plt.ylabel("Mean rating")
plt.title("Mean rating per breed");

# %% [markdown]
# The mean ratings per dog breed are nearly the same, except for `Clumber` and `Japanese_spaniel`. We will take a look at the data of those breeds in our dataset.

# %%
targeted_breed = ["Clumber","Japanese_spaniel"]

tweets_master_df.query("breed in {}".format(targeted_breed)).T
# Out:
#                                                                  71    \
# tweet_id                                           778027034220126208
# timestamp                                   2016-09-20 00:24:34+00:00
# source                             http://twitter.com/download/iphone
# text                This is Sophie. She's a Jubilant Bush Pupper. ...
# rating_numerator                                                   27
# rating_denominator                                                 10
# name                                                           Sophie
# nb_stage                                                            1
# retweet_count                                                    1885
# favorite_count                                                   7320
# stage                                                          others
# jpg_url               https://pbs.twimg.com/media/Cswbc2yWcAAVsCJ.jpg
# img_num                                                           1.0
# breed                                                         Clumber
# year                                                             2016
# rating                                                            2.7
# month                                                             Sep
# day                                                              Tue
# period                                                       Day Time
#
#                                                                  1414  \
# tweet_id                                           778027034220126208
# timestamp                                   2016-09-20 00:24:34+00:00
# source                             http://twitter.com/download/iphone
# text                This is Sophie. She's a Jubilant Bush Pupper. ...
# rating_numerator                                                   27
# rating_denominator                                                 10
# name                                                           Sophie
# nb_stage                                                            1
# retweet_count                                                    1885
# favorite_count                                                   7320
# stage                                                          pupper
# jpg_url               https://pbs.twimg.com/media/Cswbc2yWcAAVsCJ.jpg
# img_num                                                           1.0
# breed                                                         Clumber
# year                                                             2016
# rating                                                            2.7
# month                                                             Sep
# day                                                              Tue
# period                                                       Day Time
#
#                                                                  1935
# tweet_id                                           677301033169788928
# timestamp                                   2015-12-17 01:35:24+00:00
# source                             http://twitter.com/download/iphone
# text                This is Juckson. He's totally on his way to a ...
# rating_numerator                                                    5
# rating_denominator                                                 10
# name                                                          Juckson
# nb_stage                                                            0
# retweet_count                                                     471
# favorite_count                                                   1362
# stage                                                          others
# jpg_url               https://pbs.twimg.com/media/CWZBsjPWsAAZFFl.jpg
# img_num                                                           1.0
# breed                                                Japanese_spaniel
# year                                                             2015
# rating                                                            0.5
# month                                                             Dec
# day                                                              Thu
# period                                         Night (after midnight)

# %% [markdown]
# We have only one entry for each of the breeds `Clumber` and `Japanese_spaniel`. So we can safely consider these ratings as exception that happen once in a while, a rating that cannot be generalise to the rest of our dataset.
#
# *TODO : remember to check that the tweet having id 778027034220126208 is no more duplicated after dealing with tweet having multiple stages in the clean step*

# %% [markdown]
# Based on the above observations, we can deduce that the Reviewer has no bias toward a particular breed. As for the little difference in ratings for each breed, it should be related to how each breed usually take a pose on its photo.

# %% [markdown]
# <a href="conclusion"> </a>
#
# ## Conclusion
#
# The dog's rating system on [WeRateDogs](https://twitter.com/dog_rates) is relatively fair. There is no to little bias when evaluating a dog.
# We have identified some factors that can help score higher rating :
# * The best day's period to submit a dog's tweet are the morning and the afternoon.
# * The number of pictures to join to the tweet should be 03 or 04
#
# We have also seen that the majority of dogs are the stage of `puppo, doggo, or floofer`.
